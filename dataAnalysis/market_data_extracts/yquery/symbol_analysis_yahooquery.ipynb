# %%
import pandas as pd
from yahooquery import Ticker
from datetime import datetime

data_path = r'C:\Users\pthon\anaconda3\envs\pyfin_env\data'
today = datetime.today().strftime('%Y-%m-%d')
stocklist =['FSR','RIVN','TSLA','DIS','GM','HD','BABA','AAPL','APPS','PLTR','EXPR','MARA','BABA','SPCE','GME','RIOT','BB','RKT','HD','NIO']
file_name_read = data_path + "\\option_data_multiple_tickers.csv"
file_name_write = data_path + "\\summary1_option_data_multiple_tickers.csv"

# %%
symbol = 'WKSP'
tk = Ticker(symbol)
sp_dict = tk.asset_profile
overall_risk = sp_dict[symbol]['overallRisk']
num_employees = sp_dict[symbol]['fullTimeEmployees']

print("Overall Risk:", overall_risk)
print("Number of Employees:", num_employees)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[75], line 4
#       2 tk = Ticker(symbol)
#       3 sp_dict = tk.asset_profile
# ----> 4 overall_risk = sp_dict[symbol]['overallRisk']
#       5 num_employees = sp_dict[symbol]['fullTimeEmployees']
#       7 print("Overall Risk:", overall_risk)
#
# KeyError: 'overallRisk'

# %%
tk.key_stats
# Out:
# {'WKSP': {'maxAge': 1,
#   'priceHint': 4,
#   'enterpriseValue': 29059492,
#   'profitMargins': 0.0,
#   'floatShares': 15941865,
#   'sharesOutstanding': 20320700,
#   'sharesShort': 200465,
#   'sharesShortPriorMonth': 297288,
#   'sharesShortPreviousMonthDate': '2023-11-14 19:00:00',
#   'dateShortInterest': '2023-12-14 19:00:00',
#   'sharesPercentSharesOut': 0.010299999,
#   'heldPercentInsiders': 0.17945999,
#   'heldPercentInstitutions': 0.085,
#   'shortRatio': 1.7,
#   'shortPercentOfFloat': 0.0119,
#   'beta': 1.39,
#   'impliedSharesOutstanding': 20320700,
#   'category': None,
#   'bookValue': 0.941,
#   'priceToBook': 1.4453773,
#   'fundFamily': None,
#   'legalType': None,
#   'lastFiscalYearEnd': '2022-12-30 19:00:00',
#   'nextFiscalYearEnd': '2023-12-30 19:00:00',
#   'mostRecentQuarter': '2023-09-29 20:00:00',
#   'netIncomeToCommon': -14736849,
#   'trailingEps': -0.85,
#   'forwardEps': -0.58,
#   'lastSplitFactor': '1:20',
#   'lastSplitDate': '2021-08-03 20:00:00',
#   'enterpriseToRevenue': 39.845,
#   'enterpriseToEbitda': -2.085,
#   '52WeekChange': 0.27522933,
#   'SandP52WeekChange': 0.20000207}}

# %%
tk.calendar_events
# Out:
# {'WKSP': {'maxAge': 1,
#   'earnings': {'earningsDate': ['2023-11-14 16:00:S'],
#    'revenueAverage': 458000,
#    'revenueLow': 1600000,
#    'revenueHigh': 1600000},
#   'dividendDate': '2019-03-28 20:00:00'}}

# %%
tk.company_officers
# Out:
#             maxAge                                        name  age  \
# symbol row
# WKSP   0         1                         Mr. Steven F. Rossi   38
#        1         1  Mr. Michael D. Johnston C.A., CPA, CA, CPA   42
#
#                                            title  yearBorn  fiscalYear  \
# symbol row
# WKSP   0    Chairman, President, CEO & Secretary      1985        2016
#        1                 Chief Financial Officer      1981        2016
#
#             totalPay  exercisedValue  unexercisedValue
# symbol row
# WKSP   0    323667.0               0                 0
#        1         NaN               0                 0

# %%
tk.earning_history
# Out:
#             maxAge  epsActual  epsEstimate  epsDifference  surprisePercent  \
# symbol row
# WKSP   0         1      -0.17        -0.22           0.05            0.227
#        1         1      -0.20        -0.18          -0.02           -0.111
#        2         1      -0.21        -0.24           0.03            0.125
#        3         1      -0.22        -0.25           0.03            0.120
#
#                quarter period
# symbol row
# WKSP   0    2022-09-30    -4q
#        1    2022-12-31    -3q
#        2    2023-03-31    -2q
#        3    2023-06-30    -1q

# %%
tk.earnings_trend
# Out:
# {'RIVN': {'trend': [{'maxAge': 1,
#     'period': '0q',
#     'endDate': '2023-12-31',
#     'growth': 0.24299999,
#     'earningsEstimate': {'avg': -1.31,
#      'low': -1.53,
#      'high': -1.04,
#      'yearAgoEps': -1.73,
#      'numberOfAnalysts': 17,
#      'growth': 0.24299999},
#     'revenueEstimate': {'avg': 1276950000,
#      'low': 1102800000,
#      'high': 1612000000,
#      'numberOfAnalysts': 19,
#      'yearAgoRevenue': 663000000,
#      'growth': 0.926},
#     'epsTrend': {'current': -1.31,
#      '7daysAgo': -1.31,
#      '30daysAgo': -1.32,
#      '60daysAgo': -1.3,
#      '90daysAgo': -1.25},
#     'epsRevisions': {'upLast7days': 1,
#      'upLast30days': 1,
#      'downLast30days': 2,
#      'downLast90days': {}}},
#    {'maxAge': 1,
#     'period': '+1q',
#     'endDate': '2024-03-31',
#     'growth': 0.136,
#     'earningsEstimate': {'avg': -1.08,
#      'low': -1.43,
#      'high': -0.67,
#      'yearAgoEps': -1.25,
#      'numberOfAnalysts': 11,
#      'growth': 0.136},
#     'revenueEstimate': {'avg': 1451070000,
#      'low': 833000000,
#      'high': 2069600000,
#      'numberOfAnalysts': 12,
#      'yearAgoRevenue': 661000000,
#      'growth': 1.195},
#     'epsTrend': {'current': -1.08,
#      '7daysAgo': -1.08,
#      '30daysAgo': -1.08,
#      '60daysAgo': -1.08,
#      '90daysAgo': -0.99},
#     'epsRevisions': {'upLast7days': 0,
#      'upLast30days': 0,
#      'downLast30days': 0,
#      'downLast90days': {}}},
#    {'maxAge': 1,
#     'period': '0y',
#     'endDate': '2023-12-31',
#     'growth': 0.219,
#     'earningsEstimate': {'avg': -4.95,
#      'low': -5.74,
#      'high': -4.57,
#      'yearAgoEps': -6.34,
#      'numberOfAnalysts': 17,
#      'growth': 0.219},
#     'revenueEstimate': {'avg': 4388380000,
#      'low': 4107000000,
#      'high': 4731000000,
#      'numberOfAnalysts': 23,
#      'yearAgoRevenue': 1658000000,
#      'growth': 1.647},
#     'epsTrend': {'current': -4.95,
#      '7daysAgo': -4.91,
#      '30daysAgo': -4.91,
#      '60daysAgo': -4.95,
#      '90daysAgo': -5.01},
#     'epsRevisions': {'upLast7days': 1,
#      'upLast30days': 1,
#      'downLast30days': 3,
#      'downLast90days': {}}},
#    {'maxAge': 1,
#     'period': '+1y',
#     'endDate': '2024-12-31',
#     'growth': 0.283,
#     'earningsEstimate': {'avg': -3.55,
#      'low': -5.65,
#      'high': -2.25,
#      'yearAgoEps': -4.95,
#      'numberOfAnalysts': 17,
#      'growth': 0.283},
#     'revenueEstimate': {'avg': 6244530000,
#      'low': 5031100000,
#      'high': 7768000000,
#      'numberOfAnalysts': 23,
#      'yearAgoRevenue': 4388380000,
#      'growth': 0.42299998},
#     'epsTrend': {'current': -3.55,
#      '7daysAgo': -3.52,
#      '30daysAgo': -3.48,
#      '60daysAgo': -3.45,
#      '90daysAgo': -3.31},
#     'epsRevisions': {'upLast7days': 0,
#      'upLast30days': 0,
#      'downLast30days': 2,
#      'downLast90days': {}}},
#    {'maxAge': 1,
#     'period': '+5y',
#     'endDate': None,
#     'growth': -0.3196,
#     'earningsEstimate': {'avg': {},
#      'low': {},
#      'high': {},
#      'yearAgoEps': {},
#      'numberOfAnalysts': {},
#      'growth': {}},
#     'revenueEstimate': {'avg': {},
#      'low': {},
#      'high': {},
#      'numberOfAnalysts': {},
#      'yearAgoRevenue': {},
#      'growth': {}},
#     'epsTrend': {'current': {},
#      '7daysAgo': {},
#      '30daysAgo': {},
#      '60daysAgo': {},
#      '90daysAgo': {}},
#     'epsRevisions': {'upLast7days': {},
#      'upLast30days': {},
#      'downLast30days': {},
#      'downLast90days': {}}},
#    {'maxAge': 1,
#     'period': '-5y',
#     'endDate': None,
#     'growth': {},
#     'earningsEstimate': {'avg': {},
#      'low': {},
#      'high': {},
#      'yearAgoEps': {},
#      'numberOfAnalysts': {},
#      'growth': {}},
#     'revenueEstimate': {'avg': {},
#      'low': {},
#      'high': {},
#      'numberOfAnalysts': {},
#      'yearAgoRevenue': {},
#      'growth': {}},
#     'epsTrend': {'current': {},
#      '7daysAgo': {},
#      '30daysAgo': {},
#      '60daysAgo': {},
#      '90daysAgo': {}},
#     'epsRevisions': {'upLast7days': {},
#      'upLast30days': {},
#      'downLast30days': {},
#      'downLast90days': {}}}],
#   'maxAge': 1}}

# %%
tk.esg_scores
# Out:
# {'RIVN': 'No fundamentals data found for any of the summaryTypes=esgScores'}

# %%
tk.financial_data
# Out:
# {'RIVN': {'maxAge': 86400,
#   'currentPrice': 19.25,
#   'targetHighPrice': 40.0,
#   'targetLowPrice': 15.0,
#   'targetMeanPrice': 25.96,
#   'targetMedianPrice': 26.0,
#   'recommendationMean': 2.1,
#   'recommendationKey': 'buy',
#   'numberOfAnalystOpinions': 25,
#   'totalCash': 9132999680,
#   'totalCashPerShare': 9.536,
#   'ebitda': -5087000064,
#   'totalDebt': 3246000128,
#   'quickRatio': 3.571,
#   'currentRatio': 4.606,
#   'totalRevenue': 3782000128,
#   'debtToEquity': 30.762,
#   'revenuePerShare': 4.033,
#   'returnOnAssets': -0.20974001,
#   'returnOnEquity': -0.43523997,
#   'grossProfits': -3123000000,
#   'freeCashflow': -4486125056,
#   'operatingCashflow': -5205000192,
#   'revenueGrowth': 1.494,
#   'grossMargins': -0.64093,
#   'ebitdaMargins': -1.34506,
#   'operatingMargins': -1.0770401,
#   'profitMargins': -1.48969,
#   'financialCurrency': 'USD'}}

# %%
tk.fund_bond_holdings
# Out:
# {'RIVN': 'No fundamentals data found for any of the summaryTypes=topHoldings'}

# %%
tk.fund_equity_holdings
# Out:
# {'RIVN': 'No fundamentals data found for any of the summaryTypes=topHoldings'}

# %%
tk.fund_holding_info
# Out:
# {'RIVN': 'No fundamentals data found for any of the summaryTypes=topHoldings'}

# %%
tk.fund_ownership
# Out:
#             maxAge  reportDate  \
# symbol row
# RIVN   0         1  2023-09-30
#        1         1  2023-09-30
#        2         1  2023-09-30
#        3         1  2023-09-30
#        4         1  2023-09-30
#        5         1  2023-10-31
#        6         1  2023-10-31
#        7         1  2023-10-31
#        8         1  2023-09-30
#        9         1  2023-09-30
#
#                                                 organization  pctHeld  \
# symbol row
# RIVN   0               Price (T.Rowe) Growth Stock Fund Inc.   0.0269
#        1              Vanguard Total Stock Market Index Fund   0.0228
#        2                   Price (T.Rowe) Growth Stock Trust   0.0169
#        3                         Vanguard Mid-Cap Index Fund   0.0167
#        4                 Vanguard Extended Market Index Fund   0.0097
#        5                        Fidelity Growth Company Fund   0.0078
#        6    Global X Fds-Global X Lithium & Battery Tech ETF   0.0075
#        7                      Fidelity Blue Chip Growth Fund   0.0074
#        8                   Vanguard Mid-Cap Value Index Fund   0.0060
#        9                Capital World Growth and Income Fund   0.0059
#
#             position      value  pctChange
# symbol row
# RIVN   0    25738844  495472747    -0.0620
#        1    21852400  420658700    -0.0087
#        2    16177214  311411369    -0.0149
#        3    15970539  307432875    -0.0137
#        4     9327112  179546906     0.2181
#        5     7498530  144346702     0.0165
#        6     7224748  139076399    -0.0533
#        7     7104302  136757813    -0.0017
#        8     5750957  110705922    -0.0427
#        9     5678978  109320326     0.0000

# %%
tk.fund_performance
# Out:
# {'RIVN': 'No fundamentals data found for any of the summaryTypes=fundPerformance'}

# %%
tk.grading_history.head(50)
# Out:
#                  epochGradeDate                firm         toGrade  \
# symbol row
# RIVN   0    2024-01-04 08:14:08      Wolfe Research    Peer Perform
#        1    2023-12-07 05:11:40              Stifel             Buy
#        2    2023-12-04 09:09:02       Goldman Sachs         Neutral
#        3    2023-11-08 12:04:22   Cantor Fitzgerald      Overweight
#        4    2023-11-08 09:25:32         Wells Fargo    Equal-Weight
#        5    2023-10-27 05:06:20   Cantor Fitzgerald      Overweight
#        6    2023-10-10 06:41:04             Needham             Buy
#        7    2023-10-10 04:29:37                 UBS             Buy
#        8    2023-10-09 08:18:42             Wedbush      Outperform
#        9    2023-10-02 05:52:08  Evercore ISI Group      Outperform
#        10   2023-09-13 06:14:30                 UBS         Neutral
#        11   2023-08-24 05:32:06             Needham             Buy
#        12   2023-08-11 09:18:19   Exane BNP Paribas      Outperform
#        13   2023-08-10 12:59:10         DA Davidson         Neutral
#        14   2023-08-10 09:33:59       Goldman Sachs         Neutral
#        15   2023-08-09 16:24:24   Canaccord Genuity             Buy
#        16   2023-08-09 12:11:56       Deutsche Bank             Buy
#        17   2023-08-09 11:54:16       Goldman Sachs         Neutral
#        18   2023-08-09 11:32:05         Wells Fargo    Equal-Weight
#        19   2023-08-09 11:03:46         RBC Capital  Sector Perform
#        20   2023-08-09 07:26:52             Needham             Buy
#        21   2023-08-08 11:21:07   Truist Securities             Buy
#        22   2023-08-01 06:27:52   Cantor Fitzgerald         Neutral
#        23   2023-07-27 09:37:46   Tigress Financial             Buy
#        24   2023-07-27 05:40:33             Needham             Buy
#        25   2023-07-11 08:40:40            Barclays      Overweight
#        26   2023-07-07 08:59:35             Wedbush      Outperform
#        27   2023-07-06 08:20:54       Goldman Sachs         Neutral
#        28   2023-07-05 07:23:59         DA Davidson         Neutral
#        29   2023-07-05 05:41:17             Needham             Buy
#        30   2023-06-20 11:14:17   Truist Securities             Buy
#        31   2023-06-20 08:54:55   Canaccord Genuity             Buy
#        32   2023-05-11 08:59:56       Goldman Sachs         Neutral
#        33   2023-05-10 09:56:12         DA Davidson    Underperform
#        34   2023-05-10 08:27:38       Goldman Sachs         Neutral
#        35   2023-05-10 07:10:39              Mizuho             Buy
#        36   2023-05-10 06:19:06            Barclays      Overweight
#        37   2023-05-09 08:52:25   Truist Securities             Buy
#        38   2023-05-08 08:12:22         Wells Fargo    Equal-Weight
#        39   2023-04-19 04:53:02         RBC Capital  Sector Perform
#        40   2023-04-18 09:54:28      Morgan Stanley      Overweight
#        41   2023-04-14 05:58:40       Piper Sandler         Neutral
#        42   2023-03-29 06:09:17             Needham             Buy
#        43   2023-03-09 06:54:38              Mizuho             Buy
#        44   2023-03-02 09:57:38      Morgan Stanley      Overweight
#        45   2023-03-01 10:20:29               Baird      Outperform
#        46   2023-03-01 09:02:40   Cantor Fitzgerald      Overweight
#        47   2023-03-01 08:58:24         RBC Capital      Outperform
#        48   2023-03-01 08:26:25              Mizuho             Buy
#        49   2023-03-01 06:32:06   Truist Securities             Buy
#
#                  fromGrade action
# symbol row
# RIVN   0        Outperform   down
#        1                     init
#        2           Neutral   main
#        3        Overweight   main
#        4      Equal-Weight   main
#        5           Neutral     up
#        6               Buy   reit
#        7           Neutral     up
#        8        Outperform   main
#        9           In-Line     up
#        10                    init
#        11              Buy   reit
#        12          Neutral     up
#        13          Neutral   main
#        14          Neutral   main
#        15              Buy   main
#        16              Buy   main
#        17          Neutral   main
#        18     Equal-Weight   main
#        19   Sector Perform   main
#        20              Buy   reit
#        21              Buy   main
#        22       Overweight   down
#        23                    reit
#        24              Buy   main
#        25       Overweight   main
#        26       Outperform   main
#        27          Neutral   main
#        28     Underperform     up
#        29              Buy   main
#        30              Buy   reit
#        31              Buy   reit
#        32          Neutral   main
#        33     Underperform   main
#        34                    main
#        35                    main
#        36                    main
#        37                    main
#        38                    main
#        39       Outperform   down
#        40                    main
#        41       Overweight   down
#        42                    reit
#        43                    main
#        44                    main
#        45                    main
#        46                    main
#        47                    main
#        48                    main
#        49                    main

# %%
tk.insider_transactions
# Out:
#             maxAge     shares        value filerUrl  \
# symbol row
# RIVN   0         1       3265      55766.0
#        1         1        815          0.0
#        2         1        806          0.0
#        3         1       1196          0.0
#        4         1        842          0.0
# ...            ...        ...          ...      ...
#        96        1    2564102  199999956.0
#        97        1  155799732          NaN
#        98        1      20000          NaN
#        99        1       7791     250013.0
#        100       1      66812          NaN
#
#                                          transactionText  \
# symbol row
# RIVN   0                  Sale at price 17.08 per share.
#        1     Stock Award(Grant) at price 0.00 per share.
#        2     Stock Award(Grant) at price 0.00 per share.
#        3     Stock Award(Grant) at price 0.00 per share.
#        4     Stock Award(Grant) at price 0.00 per share.
# ...                                                  ...
#        96   Stock Award(Grant) at price 78.00 per share.
#        97
#        98
#        99   Stock Award(Grant) at price 32.09 per share.
#        100
#
#                           filerName  \
# symbol row
# RIVN   0         MCDONOUGH CLAIRE D
#        1           MARCARIO ROSE M.
#        2       THOMAS-GRAHAM PAMELA
#        3                BOONE KAREN
#        4    SCHWARTZ SANFORD HAROLD
# ...                             ...
#        96           AMAZON.COM INC.
#        97           AMAZON.COM INC.
#        98                BEHL JITEN
#        99      THOMAS-GRAHAM PAMELA
#        100          BAKER JEFFREY R
#
#                                                 filerRelation moneyText  \
# symbol row
# RIVN   0                              Chief Financial Officer
#        1                                             Director
#        2                                             Director
#        3                                             Director
#        4                                             Director
# ...                                                       ...       ...
#        96   Beneficial Owner of more than 10% of a Class o...
#        97   Beneficial Owner of more than 10% of a Class o...
#        98                                             Officer
#        99                                            Director
#        100                                            Officer
#
#              startDate ownership
# symbol row
# RIVN   0    2023-11-16         D
#        1    2023-10-20         D
#        2    2023-10-20         D
#        3    2023-10-20         D
#        4    2023-10-20         D
# ...                ...       ...
#        96   2021-11-10         I
#        97   2021-11-10         I
#        98   2021-10-29         D
#        99   2021-08-12         D
#        100  2021-06-08         D
#
# [101 rows x 10 columns]

# %%
tk.institution_ownership
# Out:
#             maxAge  reportDate                       organization  pctHeld  \
# symbol row
# RIVN   0         1  2023-09-30                   Amazon.com, Inc.   0.1654
#        1         1  2023-09-30      Price (T.Rowe) Associates Inc   0.0747
#        2         1  2023-09-30                 Vanguard Group Inc   0.0667
#        3         1  2023-09-30                     Blackrock Inc.   0.0482
#        4         1  2023-09-30                           FMR, LLC   0.0375
#        5         1  2023-09-30           State Street Corporation   0.0142
#        6         1  2023-09-30            D1 Capital Partners, LP   0.0141
#        7         1  2023-09-30  Capital Research Global Investors   0.0108
#        8         1  2023-09-30      Geode Capital Management, LLC   0.0107
#        9         1  2023-09-30          Janus Henderson Group PLC   0.0102
#
#              position       value  pctChange
# symbol row
# RIVN   0    158363834  3048503804     0.0000
#        1     71521250  1376784062    -0.0242
#        2     63845364  1229023257     0.0064
#        3     46140882   888211978    -0.1735
#        4     35884755   690781533    -0.0100
#        5     13616983   262126922     0.1634
#        6     13483880   259564690    -0.0306
#        7     10311478   198495951    -0.2267
#        8     10204755   196441533     0.2133
#        9      9764750   187971437     0.2167

# %%
tk.major_holders
# Out:
# {'RIVN': {'maxAge': 1,
#   'insidersPercentHeld': 0.28525,
#   'institutionsPercentHeld': 0.47974,
#   'institutionsFloatPercentHeld': 0.67120004,
#   'institutionsCount': 894}}

# %%
tk.page_views
# Out:
# {'RIVN': {'shortTermTrend': 'UP',
#   'midTermTrend': 'UP',
#   'longTermTrend': 'UP',
#   'maxAge': 1}}

# %%
tk.price
# Out:
# {'RIVN': {'maxAge': 1,
#   'preMarketChangePercent': 0.0015322099,
#   'preMarketChange': 0.0300007,
#   'preMarketTime': '2024-01-09 09:29:49',
#   'preMarketPrice': 19.61,
#   'preMarketSource': 'FREE_REALTIME',
#   'postMarketChangePercent': 0.0005662596,
#   'postMarketChange': 0.010900497,
#   'postMarketTime': '2024-01-09 18:13:01',
#   'postMarketPrice': 19.2609,
#   'postMarketSource': 'FREE_REALTIME',
#   'regularMarketChangePercent': -0.016853929,
#   'regularMarketChange': -0.32999992,
#   'regularMarketTime': '2024-01-09 16:00:00',
#   'priceHint': 2,
#   'regularMarketPrice': 19.25,
#   'regularMarketDayHigh': 19.759,
#   'regularMarketDayLow': 19.16,
#   'regularMarketVolume': 18217481,
#   'regularMarketPreviousClose': 19.58,
#   'regularMarketSource': 'FREE_REALTIME',
#   'regularMarketOpen': 19.58,
#   'exchange': 'NMS',
#   'exchangeName': 'NasdaqGS',
#   'exchangeDataDelayedBy': 0,
#   'marketState': 'POST',
#   'quoteType': 'EQUITY',
#   'symbol': 'RIVN',
#   'underlyingSymbol': None,
#   'shortName': 'Rivian Automotive, Inc.',
#   'longName': 'Rivian Automotive, Inc.',
#   'currency': 'USD',
#   'quoteSourceName': 'Nasdaq Real Time Price',
#   'currencySymbol': '$',
#   'fromCurrency': None,
#   'toCurrency': None,
#   'lastMarket': None,
#   'marketCap': 18436071424}}

# %%
tk.recommendation_trend
# Out:
#            period  strongBuy  buy  hold  sell  strongSell
# symbol row
# RIVN   0       0m          0    0     0     0           0
#        1      -1m          4   14     7     0           0
#        2      -2m          5   12     7     1           0
#        3      -3m          0    0     0     0           0

# %%
tk.sec_filings
# Out:
#                   date            epochDate      type  \
# symbol row
# RIVN   0    2024-01-02  2024-01-01 19:00:00       8-K
#        1    2023-11-20  2023-11-19 19:00:00       8-K
#        2    2023-11-13  2023-11-12 19:00:00       8-K
#        3    2023-11-07  2023-11-06 19:00:00      10-Q
#        4    2023-10-11  2023-10-10 20:00:00       8-K
#        5    2023-10-04  2023-10-03 20:00:00       8-K
#        6    2023-10-02  2023-10-01 20:00:00       8-K
#        7    2023-09-29  2023-09-28 20:00:00       8-K
#        8    2023-09-11  2023-09-10 20:00:00  SC 13G/A
#        9    2023-09-01  2023-08-31 20:00:00       8-K
#        10   2023-08-29  2023-08-28 20:00:00       8-K
#        11   2023-08-08  2023-08-07 20:00:00      10-Q
#        12   2023-08-02  2023-08-01 20:00:00       8-K
#        13   2023-07-03  2023-07-02 20:00:00       8-K
#        14   2023-06-23  2023-06-22 20:00:00       8-K
#        15   2023-05-26  2023-05-25 20:00:00   PX14A6G
#        16   2023-05-09  2023-05-08 20:00:00       8-K
#        17   2023-05-05  2023-05-04 20:00:00   CORRESP
#        18   2023-05-01  2023-04-30 20:00:00   DEF 14A
#        19   2023-04-19  2023-04-18 20:00:00       8-K
#        20   2023-04-03  2023-04-02 20:00:00       8-K
#        21   2023-03-10  2023-03-09 19:00:00       8-K
#        22   2023-03-07  2023-03-06 19:00:00       8-K
#        23   2023-02-28  2023-02-27 19:00:00       8-K
#        24   2023-02-08  2023-02-07 19:00:00  SC 13G/A
#        25   2023-01-10  2023-01-09 19:00:00  SC 13G/A
#        26   2023-01-03  2023-01-02 19:00:00       8-K
#        27   2022-12-20  2022-12-19 19:00:00       8-K
#        28   2022-11-09  2022-11-08 19:00:00       8-K
#        29   2022-10-03  2022-10-02 20:00:00       8-K
#        30   2022-08-11  2022-08-10 20:00:00       8-K
#        31   2022-07-06  2022-07-05 20:00:00       8-K
#        32   2022-06-09  2022-06-08 20:00:00       8-K
#        33   2022-06-06  2022-06-05 20:00:00       8-K
#        34   2022-05-11  2022-05-10 20:00:00      10-Q
#        35   2022-05-06  2022-05-05 20:00:00       8-K
#        36   2022-04-27  2022-04-26 20:00:00   DEFA14A
#        37   2022-04-05  2022-04-04 20:00:00       8-K
#        38   2022-03-31  2022-03-30 20:00:00       S-8
#        39   2022-03-10  2022-03-09 19:00:00       8-K
#        40   2022-02-14  2022-02-13 19:00:00  SC 13G/A
#        41   2022-02-10  2022-02-09 19:00:00    SC 13G
#        42   2022-02-02  2022-02-01 19:00:00    SC 13G
#
#                                                         title  \
# symbol row
# RIVN   0                   Corporate Changes & Voting Matters
#        1                   Corporate Changes & Voting Matters
#        2                   Corporate Changes & Voting Matters
#        3                           Periodic Financial Reports
#        4                   Corporate Changes & Voting Matters
#        5                   Corporate Changes & Voting Matters
#        6                   Corporate Changes & Voting Matters
#        7                   Corporate Changes & Voting Matters
#        8                     Tender Offer/Acquisition Reports
#        9                   Corporate Changes & Voting Matters
#        10                  Corporate Changes & Voting Matters
#        11                          Periodic Financial Reports
#        12                  Corporate Changes & Voting Matters
#        13                  Corporate Changes & Voting Matters
#        14                  Corporate Changes & Voting Matters
#        15                       Notice of exempt solicitation
#        16                  Corporate Changes & Voting Matters
#        17   A correspondence can be sent as a document wit...
#        18                                    Proxy Statements
#        19                  Corporate Changes & Voting Matters
#        20                  Corporate Changes & Voting Matters
#        21                  Corporate Changes & Voting Matters
#        22                  Corporate Changes & Voting Matters
#        23                  Corporate Changes & Voting Matters
#        24                    Tender Offer/Acquisition Reports
#        25                    Tender Offer/Acquisition Reports
#        26                  Corporate Changes & Voting Matters
#        27                  Corporate Changes & Voting Matters
#        28                  Corporate Changes & Voting Matters
#        29                  Corporate Changes & Voting Matters
#        30                  Corporate Changes & Voting Matters
#        31                  Corporate Changes & Voting Matters
#        32                  Corporate Changes & Voting Matters
#        33                  Corporate Changes & Voting Matters
#        34                          Periodic Financial Reports
#        35                  Corporate Changes & Voting Matters
#        36                                    Proxy Statements
#        37                  Corporate Changes & Voting Matters
#        38                              Offering Registrations
#        39                  Corporate Changes & Voting Matters
#        40                    Tender Offer/Acquisition Reports
#        41                    Tender Offer/Acquisition Reports
#        42                    Tender Offer/Acquisition Reports
#
#                                                      edgarUrl  \
# symbol row
# RIVN   0    https://finance.yahoo.com/sec-filing/RIVN/0001...
#        1    https://finance.yahoo.com/sec-filing/RIVN/0001...
#        2    https://finance.yahoo.com/sec-filing/RIVN/0001...
#        3    https://finance.yahoo.com/sec-filing/RIVN/0001...
#        4    https://finance.yahoo.com/sec-filing/RIVN/0001...
#        5    https://finance.yahoo.com/sec-filing/RIVN/0001...
#        6    https://finance.yahoo.com/sec-filing/RIVN/0001...
#        7    https://finance.yahoo.com/sec-filing/RIVN/0001...
#        8    https://finance.yahoo.com/sec-filing/RIVN/0000...
#        9    https://finance.yahoo.com/sec-filing/RIVN/0001...
#        10   https://finance.yahoo.com/sec-filing/RIVN/0001...
#        11   https://finance.yahoo.com/sec-filing/RIVN/0001...
#        12   https://finance.yahoo.com/sec-filing/RIVN/0001...
#        13   https://finance.yahoo.com/sec-filing/RIVN/0001...
#        14   https://finance.yahoo.com/sec-filing/RIVN/0001...
#        15   https://finance.yahoo.com/sec-filing/RIVN/0001...
#        16   https://finance.yahoo.com/sec-filing/RIVN/0001...
#        17   https://finance.yahoo.com/sec-filing/RIVN/0001...
#        18   https://finance.yahoo.com/sec-filing/RIVN/0001...
#        19   https://finance.yahoo.com/sec-filing/RIVN/0001...
#        20   https://finance.yahoo.com/sec-filing/RIVN/0001...
#        21   https://finance.yahoo.com/sec-filing/RIVN/0001...
#        22   https://finance.yahoo.com/sec-filing/RIVN/0001...
#        23   https://finance.yahoo.com/sec-filing/RIVN/0001...
#        24   https://finance.yahoo.com/sec-filing/RIVN/0001...
#        25   https://finance.yahoo.com/sec-filing/RIVN/0000...
#        26   https://finance.yahoo.com/sec-filing/RIVN/0001...
#        27   https://finance.yahoo.com/sec-filing/RIVN/0001...
#        28   https://finance.yahoo.com/sec-filing/RIVN/0001...
#        29   https://finance.yahoo.com/sec-filing/RIVN/0001...
#        30   https://finance.yahoo.com/sec-filing/RIVN/0001...
#        31   https://finance.yahoo.com/sec-filing/RIVN/0001...
#        32   https://finance.yahoo.com/sec-filing/RIVN/0001...
#        33   https://finance.yahoo.com/sec-filing/RIVN/0001...
#        34   https://finance.yahoo.com/sec-filing/RIVN/0001...
#        35   https://finance.yahoo.com/sec-filing/RIVN/0001...
#        36   https://finance.yahoo.com/sec-filing/RIVN/0001...
#        37   https://finance.yahoo.com/sec-filing/RIVN/0001...
#        38   https://finance.yahoo.com/sec-filing/RIVN/0001...
#        39   https://finance.yahoo.com/sec-filing/RIVN/0001...
#        40   https://finance.yahoo.com/sec-filing/RIVN/0000...
#        41   https://finance.yahoo.com/sec-filing/RIVN/0001...
#        42   https://finance.yahoo.com/sec-filing/RIVN/0001...
#
#                                                      exhibits  maxAge
# symbol row
# RIVN   0    [{'type': '8-K', 'url': 'https://cdn.yahoofina...       1
#        1    [{'type': '8-K', 'url': 'https://cdn.yahoofina...       1
#        2    [{'type': '8-K', 'url': 'https://cdn.yahoofina...       1
#        3    [{'type': '10-Q', 'url': 'https://cdn.yahoofin...       1
#        4    [{'type': 'EX-10.1', 'url': 'https://cdn.yahoo...       1
#        5    [{'type': '8-K', 'url': 'https://cdn.yahoofina...       1
#        6    [{'type': '8-K', 'url': 'https://cdn.yahoofina...       1
#        7    [{'type': 'EX-10.1', 'url': 'https://cdn.yahoo...       1
#        8    [{'type': 'SC 13G/A', 'url': 'https://s3.amazo...       1
#        9    [{'type': 'EXCEL', 'url': 'https://s3.amazonaw...       1
#        10   [{'type': 'EXCEL', 'url': 'https://s3.amazonaw...       1
#        11   [{'type': '10-Q', 'url': 'https://cdn.yahoofin...       1
#        12   [{'type': '8-K', 'url': 'https://cdn.yahoofina...       1
#        13   [{'type': '8-K', 'url': 'https://cdn.yahoofina...       1
#        14   [{'type': 'EXCEL', 'url': 'https://s3.amazonaw...       1
#        15   [{'type': 'PX14A6G', 'url': 'https://cdn.yahoo...       1
#        16   [{'type': '8-K', 'url': 'https://cdn.yahoofina...       1
#        17   [{'type': 'CORRESP', 'url': 'https://cdn.yahoo...       1
#        18   [{'type': 'DEF 14A', 'url': 'https://cdn.yahoo...       1
#        19   [{'type': '8-K', 'url': 'https://cdn.yahoofina...       1
#        20   [{'type': '8-K', 'url': 'https://cdn.yahoofina...       1
#        21   [{'type': '8-K', 'url': 'https://cdn.yahoofina...       1
#        22   [{'type': '8-K', 'url': 'https://cdn.yahoofina...       1
#        23   [{'type': '8-K', 'url': 'https://cdn.yahoofina...       1
#        24   [{'type': 'SC 13G/A', 'url': 'https://cdn.yaho...       1
#        25   [{'type': 'SC 13G/A', 'url': 'https://s3.amazo...       1
#        26   [{'type': 'EX-99.1', 'url': 'https://cdn.yahoo...       1
#        27   [{'type': 'EXCEL', 'url': 'https://s3.amazonaw...       1
#        28   [{'type': 'EX-99.1', 'url': 'https://cdn.yahoo...       1
#        29   [{'type': '8-K', 'url': 'https://cdn.yahoofina...       1
#        30   [{'type': '8-K', 'url': 'https://cdn.yahoofina...       1
#        31   [{'type': '8-K', 'url': 'https://cdn.yahoofina...       1
#        32   [{'type': '8-K', 'url': 'https://cdn.yahoofina...       1
#        33   [{'type': 'EXCEL', 'url': 'https://s3.amazonaw...       1
#        34   [{'type': '10-Q', 'url': 'https://cdn.yahoofin...       1
#        35   [{'type': '8-K', 'url': 'https://cdn.yahoofina...       1
#        36   [{'type': 'DEFA14A', 'url': 'https://cdn.yahoo...       1
#        37   [{'type': '8-K', 'url': 'https://cdn.yahoofina...       1
#        38   [{'type': 'EX-FILING FEES', 'url': 'https://cd...       1
#        39   [{'type': '8-K', 'url': 'https://cdn.yahoofina...       1
#        40   [{'type': 'SC 13G/A', 'url': 'https://s3.amazo...       1
#        41   [{'type': 'SC 13G', 'url': 'https://cdn.yahoof...       1
#        42   [{'type': 'SC 13G', 'url': 'https://cdn.yahoof...       1

# %%
tk.share_purchase_activity
# Out:
# {'RIVN': {'maxAge': 1,
#   'period': '6m',
#   'buyInfoCount': 14,
#   'buyInfoShares': 867220,
#   'buyPercentInsiderShares': 0.003,
#   'sellInfoCount': 2,
#   'sellInfoShares': 6530,
#   'sellPercentInsiderShares': 0.0,
#   'netInfoCount': 16,
#   'netInfoShares': 860690,
#   'netPercentInsiderShares': 0.003,
#   'totalInsiderShares': 273188960}}

# %%
tk.summary_detail
# Out:
# {'RIVN': {'maxAge': 1,
#   'priceHint': 2,
#   'previousClose': 19.58,
#   'open': 19.58,
#   'dayLow': 19.16,
#   'dayHigh': 19.759,
#   'regularMarketPreviousClose': 19.58,
#   'regularMarketOpen': 19.58,
#   'regularMarketDayLow': 19.16,
#   'regularMarketDayHigh': 19.759,
#   'payoutRatio': 0.0,
#   'beta': 2.131,
#   'forwardPE': -5.4225354,
#   'volume': 18217481,
#   'regularMarketVolume': 18217481,
#   'averageVolume': 36712150,
#   'averageVolume10days': 28333110,
#   'averageDailyVolume10Day': 28333110,
#   'bid': 19.25,
#   'ask': 19.29,
#   'bidSize': 3000,
#   'askSize': 1100,
#   'marketCap': 18436071424,
#   'fiftyTwoWeekLow': 11.68,
#   'fiftyTwoWeekHigh': 28.06,
#   'priceToSalesTrailing12Months': 4.874688,
#   'fiftyDayAverage': 18.7686,
#   'twoHundredDayAverage': 18.5954,
#   'trailingAnnualDividendRate': 0.0,
#   'trailingAnnualDividendYield': 0.0,
#   'currency': 'USD',
#   'fromCurrency': None,
#   'toCurrency': None,
#   'lastMarket': None,
#   'coinMarketCapLink': None,
#   'algorithm': None,
#   'tradeable': False}}

# %%
tk.balance_sheet()
# Out:
#          asOfDate periodType currencyCode  AccountsPayable  \
# symbol
# RIVN   2020-12-31        12M          USD     9.000000e+07
# RIVN   2021-12-31        12M          USD     4.830000e+08
# RIVN   2022-12-31        12M          USD     1.000000e+09
#
#         AccountsReceivable  AccumulatedDepreciation  AdditionalPaidInCapital  \
# symbol
# RIVN                   NaN              -38000000.0             3.020000e+08
# RIVN            26000000.0             -233000000.0             2.588700e+10
# RIVN           102000000.0             -883000000.0             2.692600e+10
#
#         CapitalLeaseObligations  CapitalStock  CashAndCashEquivalents  ...  \
# symbol                                                                 ...
# RIVN                105000000.0           0.0            2.979000e+09  ...
# RIVN                307000000.0     1000000.0            1.813300e+10  ...
# RIVN                581000000.0     1000000.0            1.156800e+10  ...
#
#         StockholdersEquity  TangibleBookValue   TotalAssets  \
# symbol
# RIVN         -1.384000e+09      -1.384000e+09  4.602000e+09
# RIVN          1.951400e+10       1.951400e+10  2.229400e+10
# RIVN          1.379900e+10       1.379900e+10  1.787600e+10
#
#         TotalCapitalization     TotalDebt  TotalEquityGrossMinorityInterest  \
# symbol
# RIVN          -1.337000e+09  1.800000e+08                     -1.384000e+09
# RIVN           2.074000e+10  1.533000e+09                      1.951400e+10
# RIVN           1.503000e+10  1.812000e+09                      1.379900e+10
#
#         TotalLiabilitiesNetMinorityInterest  TotalNonCurrentAssets  \
# symbol
# RIVN                           5.986000e+09           1.586000e+09
# RIVN                           2.780000e+09           3.735000e+09
# RIVN                           4.077000e+09           4.746000e+09
#
#         TotalNonCurrentLiabilitiesNetMinorityInterest  WorkingCapital
# symbol
# RIVN                                     5.375000e+09    2.405000e+09
# RIVN                                     1.467000e+09    1.724600e+10
# RIVN                                     1.653000e+09    1.070600e+10
#
# [3 rows x 64 columns]

# %%
tk.cash_flow(trailing=False)
# Out:
#          asOfDate periodType currencyCode  AssetImpairmentCharge  \
# symbol
# RIVN   2020-12-31        12M          USD                    NaN
# RIVN   2021-12-31        12M          USD             95000000.0
# RIVN   2022-12-31        12M          USD            920000000.0
#
#         BeginningCashPosition  CapitalExpenditure  CapitalExpenditureReported  \
# symbol
# RIVN             2.273000e+09       -9.140000e+08               -9.140000e+08
# RIVN             3.011000e+09       -1.794000e+09               -1.794000e+09
# RIVN             1.842300e+10       -1.369000e+09               -1.369000e+09
#
#         CashFlowFromContinuingFinancingActivities  \
# symbol
# RIVN                                 2.500000e+09
# RIVN                                 1.982800e+10
# RIVN                                 9.900000e+07
#
#         CashFlowFromContinuingInvestingActivities  \
# symbol
# RIVN                                -9.140000e+08
# RIVN                                -1.794000e+09
# RIVN                                -1.369000e+09
#
#         CashFlowFromContinuingOperatingActivities  ...  \
# symbol                                             ...
# RIVN                                -8.480000e+08  ...
# RIVN                                -2.622000e+09  ...
# RIVN                                -5.052000e+09  ...
#
#         NetIncomeFromContinuingOperations  NetIssuancePaymentsOfDebt  \
# symbol
# RIVN                        -1.018000e+09               0.000000e+00
# RIVN                        -4.688000e+09               3.640000e+09
# RIVN                        -6.752000e+09               0.000000e+00
#
#         NetLongTermDebtIssuance  NetOtherFinancingCharges  OperatingCashFlow  \
# symbol
# RIVN               0.000000e+00                       NaN      -8.480000e+08
# RIVN               3.640000e+09                       NaN      -2.622000e+09
# RIVN               0.000000e+00                -3000000.0      -5.052000e+09
#
#         OperatingGainsLosses  OtherNonCashItems  RepaymentOfDebt  \
# symbol
# RIVN                     NaN       4.100000e+07              NaN
# RIVN             441000000.0       1.120000e+09      -86000000.0
# RIVN                     NaN       8.200000e+07              NaN
#
#         RepurchaseOfCapitalStock  StockBasedCompensation
# symbol
# RIVN                  -6000000.0                     NaN
# RIVN                         NaN             570000000.0
# RIVN                         NaN             987000000.0
#
# [3 rows x 46 columns]

# %%
tk.income_statement()
# Out:
#          asOfDate periodType currencyCode  BasicAverageShares  BasicEPS  \
# symbol
# RIVN   2020-12-31        12M          USD         723000000.0 -1.409405
# RIVN   2021-12-31        12M          USD         900000000.0 -5.208889
# RIVN   2022-12-31        12M          USD         913000000.0 -7.400000
# RIVN   2023-06-30        TTM          USD         929500000.0 -6.460000
# RIVN   2023-09-30        TTM          USD         937750000.0 -6.020000
#
#         CostOfRevenue  DilutedAverageShares  DilutedEPS  \
# symbol
# RIVN              NaN           723000000.0   -1.409405
# RIVN     5.200000e+08           900000000.0   -5.208889
# RIVN     4.781000e+09           913000000.0   -7.400000
# RIVN              NaN           929500000.0   -6.460000
# RIVN     6.206000e+09           937750000.0   -6.020000
#
#         DilutedNIAvailtoComStockholders          EBIT  ...  \
# symbol                                                 ...
# RIVN                      -2.506000e+09 -1.010000e+09  ...
# RIVN                      -4.688000e+09 -4.659000e+09  ...
# RIVN                      -6.752000e+09 -6.645000e+09  ...
# RIVN                                NaN           NaN  ...
# RIVN                      -5.634000e+09 -5.453000e+09  ...
#
#         ResearchAndDevelopment  SellingGeneralAndAdministration  \
# symbol
# RIVN              7.660000e+08                     2.550000e+08
# RIVN              1.850000e+09                     1.242000e+09
# RIVN              1.944000e+09                     1.789000e+09
# RIVN                       NaN                              NaN
# RIVN              1.871000e+09                     1.658000e+09
#
#         TaxEffectOfUnusualItems  TaxProvision  TaxRateForCalcs  TotalExpenses  \
# symbol
# RIVN                        0.0           0.0             0.00   1.021000e+09
# RIVN                        0.0           0.0             0.00   4.275000e+09
# RIVN                        0.0     4000000.0             0.00   8.514000e+09
# RIVN                        NaN           NaN              NaN            NaN
# RIVN                        0.0     1000000.0             0.21   9.735000e+09
#
#         TotalOperatingIncomeAsReported  TotalRevenue  TotalUnusualItems  \
# symbol
# RIVN                     -1.021000e+09  0.000000e+00                NaN
# RIVN                     -4.220000e+09  5.500000e+07       -441000000.0
# RIVN                     -6.856000e+09  1.658000e+09                NaN
# RIVN                               NaN           NaN                NaN
# RIVN                     -5.953000e+09  3.782000e+09                NaN
#
#         TotalUnusualItemsExcludingGoodwill
# symbol
# RIVN                                   NaN
# RIVN                          -441000000.0
# RIVN                                   NaN
# RIVN                                   NaN
# RIVN                                   NaN
#
# [5 rows x 47 columns]

# %%
tk.valuation_measures
# Out:
#          asOfDate periodType  EnterpriseValue  EnterprisesValueEBITDARatio  \
# symbol
# RIVN   2022-12-31         3M     5.462215e+09                    -3.663458
# RIVN   2023-03-31         3M     4.779720e+09                    -4.260000
# RIVN   2023-06-30         3M     7.713321e+09                    -8.402311
# RIVN   2023-09-30         3M     1.616575e+10                   -15.308477
# RIVN   2024-01-08        TTM     1.303211e+10                          NaN
# RIVN   2024-01-09        TTM              NaN                    -2.841097
#
#         EnterprisesValueRevenueRatio     MarketCap   PbRatio    PsRatio
# symbol
# RIVN                        8.238636  1.697322e+10  1.112746  16.181153
# RIVN                        7.231044  1.453572e+10  1.053389   8.524270
# RIVN                        6.880750  1.564932e+10  1.236883   6.893599
# RIVN                       12.091063  2.302075e+10  1.981533   7.570701
# RIVN                             NaN  1.875211e+10  1.777114   4.854877
# RIVN                        3.445825           NaN       NaN        NaN

# %%
tk.all_financial_data()
# Out:
#          asOfDate periodType currencyCode  AccountsPayable  \
# symbol
# RIVN   2020-12-31        12M          USD     9.000000e+07
# RIVN   2021-12-31        12M          USD     4.830000e+08
# RIVN   2022-12-31        12M          USD     1.000000e+09
#
#         AccountsReceivable  AccumulatedDepreciation  AdditionalPaidInCapital  \
# symbol
# RIVN                   NaN              -38000000.0             3.020000e+08
# RIVN            26000000.0             -233000000.0             2.588700e+10
# RIVN           102000000.0             -883000000.0             2.692600e+10
#
#         AssetImpairmentCharge  BasicAverageShares  BasicEPS  ...  \
# symbol                                                       ...
# RIVN                      NaN         723000000.0 -1.409405  ...
# RIVN               95000000.0         900000000.0 -5.208889  ...
# RIVN              920000000.0         913000000.0 -7.400000  ...
#
#         TotalEquityGrossMinorityInterest  TotalExpenses  \
# symbol
# RIVN                       -1.384000e+09   1.021000e+09
# RIVN                        1.951400e+10   4.275000e+09
# RIVN                        1.379900e+10   8.514000e+09
#
#         TotalLiabilitiesNetMinorityInterest  TotalNonCurrentAssets  \
# symbol
# RIVN                           5.986000e+09           1.586000e+09
# RIVN                           2.780000e+09           3.735000e+09
# RIVN                           4.077000e+09           4.746000e+09
#
#         TotalNonCurrentLiabilitiesNetMinorityInterest  \
# symbol
# RIVN                                     5.375000e+09
# RIVN                                     1.467000e+09
# RIVN                                     1.653000e+09
#
#         TotalOperatingIncomeAsReported  TotalRevenue  TotalUnusualItems  \
# symbol
# RIVN                     -1.021000e+09  0.000000e+00                NaN
# RIVN                     -4.220000e+09  5.500000e+07       -441000000.0
# RIVN                     -6.856000e+09  1.658000e+09                NaN
#
#         TotalUnusualItemsExcludingGoodwill  WorkingCapital
# symbol
# RIVN                                   NaN    2.405000e+09
# RIVN                          -441000000.0    1.724600e+10
# RIVN                                   NaN    1.070600e+10
#
# [3 rows x 150 columns]

# %%
types = ['TotalDebt', 'TotalAssets', 'EBIT', 'EBITDA', 'PeRatio']
tk.get_financial_data(types, trailing=False)
# Out:
#          asOfDate periodType currencyCode          EBIT        EBITDA  \
# symbol
# RIVN   2020-12-31        12M          USD -1.010000e+09 -9.810000e+08
# RIVN   2021-12-31        12M          USD -4.659000e+09 -4.462000e+09
# RIVN   2022-12-31        12M          USD -6.645000e+09 -5.993000e+09
#
#          TotalAssets     TotalDebt
# symbol
# RIVN    4.602000e+09  1.800000e+08
# RIVN    2.229400e+10  1.533000e+09
# RIVN    1.787600e+10  1.812000e+09

# %%
tk.history()
# Out:
#                                        open       high        low  close  \
# symbol date
# RIVN   2024-01-02                 21.855000  21.940001  20.760000  21.10
#        2024-01-03                 20.530001  20.660000  19.660000  20.32
#        2024-01-04                 19.920000  20.295000  19.475000  19.50
#        2024-01-05                 19.379999  19.900000  19.000000  19.08
#        2024-01-08                 19.059999  19.580000  18.889999  19.58
#        2024-01-09 16:00:00-05:00  19.580000  19.759001  19.160000  19.25
#
#                                     volume  adjclose
# symbol date
# RIVN   2024-01-02                 49626300     21.10
#        2024-01-03                 35634500     20.32
#        2024-01-04                 28453000     19.50
#        2024-01-05                 27403000     19.08
#        2024-01-08                 18745500     19.58
#        2024-01-09 16:00:00-05:00  18217481     19.25

# %% [markdown]
# The Yahoo Finance API restricts the amount of one minute interval data to seven days per request. However, the data availability extends to 30 days. The following will allow the user to retrieve the last 30 days of one minute interval data, with the one caveat that 4 requests are made in 7 day ranges to retrieve the desired data:
#
# tickers = Ticker('fb aapl nflx', asynchronous=True)
#
# df = tickers.history(period='1mo', interval='
# ==================> refer this for details < ==================================
# https://yahooquery.dpguthrie.com/guide/ticker/historical/
# ==================> refer for details < ==================================1m')

# %% [markdown]
# ************************  KEY FINANCIAL DATA KEYWORDS FOR SPECIFIC INFORMATION *******************************************
# ************************  How to USe ? refer to the example below              *******************************************
#
# types = ['TotalDebt', 'TotalAssets', 'EBIT', 'EBITDA', 'PeRatio']
# tk.get_financial_data(types, trailing=False)
#
# Balance Sheet
# [
#     'AccountsPayable', 'AccountsReceivable', 'AccruedInterestReceivable',
#     'AccumulatedDepreciation', 'AdditionalPaidInCapital',
#     'AllowanceForDoubtfulAccountsReceivable', 'AssetsHeldForSaleCurrent',
#     'AvailableForSaleSecurities', 'BuildingsAndImprovements', 'CapitalLeaseObligations',
#     'CapitalStock', 'CashAndCashEquivalents', 'CashCashEquivalentsAndShortTermInvestments',
#     'CashEquivalents', 'CashFinancial', 'CommercialPaper', 'CommonStock',
#     'CommonStockEquity', 'ConstructionInProgress', 'CurrentAccruedExpenses',
#     'CurrentAssets', 'CurrentCapitalLeaseObligation', 'CurrentDebt',
#     'CurrentDebtAndCapitalLeaseObligation', 'CurrentDeferredAssets',
#     'CurrentDeferredLiabilities', 'CurrentDeferredRevenue', 'CurrentDeferredTaxesAssets',
#     'CurrentDeferredTaxesLiabilities', 'CurrentLiabilities', 'CurrentNotesPayable',
#     'CurrentProvisions', 'DefinedPensionBenefit', 'DerivativeProductLiabilities',
#     'DividendsPayable', 'DuefromRelatedPartiesCurrent', 'DuefromRelatedPartiesNonCurrent',
#     'DuetoRelatedPartiesCurrent', 'DuetoRelatedPartiesNonCurrent', 'EmployeeBenefits',
#     'FinancialAssets', 'FinancialAssetsDesignatedasFairValueThroughProfitorLossTotal',
#     'FinishedGoods', 'FixedAssetsRevaluationReserve', 'ForeignCurrencyTranslationAdjustments',
#     'GainsLossesNotAffectingRetainedEarnings', 'GeneralPartnershipCapital', 'Goodwill',
#     'GoodwillAndOtherIntangibleAssets', 'GrossAccountsReceivable', 'GrossPPE',
#     'HedgingAssetsCurrent', 'HeldToMaturitySecurities', 'IncomeTaxPayable',
#     'InterestPayable', 'InventoriesAdjustmentsAllowances', 'Inventory',
#     'InvestedCapital', 'InvestmentProperties', 'InvestmentinFinancialAssets',
#     'InvestmentsAndAdvances', 'InvestmentsInOtherVenturesUnderEquityMethod',
#     'InvestmentsinAssociatesatCost', 'InvestmentsinJointVenturesatCost',
#     'InvestmentsinSubsidiariesatCost', 'LandAndImprovements', 'Leases',
#     'LiabilitiesHeldforSaleNonCurrent', 'LimitedPartnershipCapital',
#     'LineOfCredit', 'LoansReceivable', 'LongTermCapitalLeaseObligation',
#     'LongTermDebt', 'LongTermDebtAndCapitalLeaseObligation', 'LongTermEquityInvestment',
#     'LongTermProvisions', 'MachineryFurnitureEquipment', 'MinimumPensionLiabilities',
#     'MinorityInterest', 'NetDebt', 'NetPPE', 'NetTangibleAssets', 'NonCurrentAccountsReceivable',
#     'NonCurrentAccruedExpenses', 'NonCurrentDeferredAssets', 'NonCurrentDeferredLiabilities',
#     'NonCurrentDeferredRevenue', 'NonCurrentDeferredTaxesAssets', 'NonCurrentDeferredTaxesLiabilities',
#     'NonCurrentNoteReceivables', 'NonCurrentPensionAndOtherPostretirementBenefitPlans',
#     'NonCurrentPrepaidAssets', 'NotesReceivable', 'OrdinarySharesNumber',
#     'OtherCapitalStock', 'OtherCurrentAssets', 'OtherCurrentBorrowings',
#     'OtherCurrentLiabilities', 'OtherEquityAdjustments', 'OtherEquityInterest',
#     'OtherIntangibleAssets', 'OtherInventories', 'OtherInvestments', 'OtherNonCurrentAssets',
#     'OtherNonCurrentLiabilities', 'OtherPayable', 'OtherProperties', 'OtherReceivables',
#     'OtherShortTermInvestments', 'Payables', 'PayablesAndAccruedExpenses',
#     'PensionandOtherPostRetirementBenefitPlansCurrent', 'PreferredSecuritiesOutsideStockEquity',
#     'PreferredSharesNumber', 'PreferredStock', 'PreferredStockEquity',
#     'PrepaidAssets', 'Properties', 'RawMaterials', 'Receivables',
#     'ReceivablesAdjustmentsAllowances', 'RestrictedCash', 'RestrictedCommonStock',
#     'RetainedEarnings', 'ShareIssued', 'StockholdersEquity', 'TangibleBookValue',
#     'TaxesReceivable', 'TotalAssets', 'TotalCapitalization', 'TotalDebt',
#     'TotalEquityGrossMinorityInterest', 'TotalLiabilitiesNetMinorityInterest',
#     'TotalNonCurrentAssets', 'TotalNonCurrentLiabilitiesNetMinorityInterest',
#     'TotalPartnershipCapital', 'TotalTaxPayable', 'TradeandOtherPayablesNonCurrent',
#     'TradingSecurities', 'TreasurySharesNumber', 'TreasuryStock', 'UnrealizedG
#
# Cash Flow
# [
#     'RepaymentOfDebt', 'RepurchaseOfCapitalStock', 'CashDividendsPaid',
#     'CommonStockIssuance', 'ChangeInWorkingCapital',
#     'CapitalExpenditure',
#     'CashFlowFromContinuingFinancingActivities', 'NetIncome',
#     'FreeCashFlow', 'ChangeInCashSupplementalAsReported',
#     'SaleOfInvestment', 'EndCashPosition', 'OperatingCashFlow',
#     'DeferredIncomeTax', 'NetOtherInvestingChanges',
#     'ChangeInAccountPayable', 'NetOtherFinancingCharges',
#     'PurchaseOfInvestment', 'ChangeInInventory',
#     'DepreciationAndAmortization', 'PurchaseOfBusiness',
#     'InvestingCashFlow', 'ChangesInAccountReceivables',
#     'StockBasedCompensation', 'OtherNonCashItems',
#     'BeginningC
#
# Income Statement
# [
#     'Amortization', 'AmortizationOfIntangiblesIncomeStatement',
#     'AverageDilutionEarnings', 'BasicAccountingChange', 'BasicAverageShares',
#     'BasicContinuousOperations', 'BasicDiscontinuousOperations', 'BasicEPS',
#     'BasicEPSOtherGainsLosses', 'BasicExtraordinary', 'ContinuingAndDiscontinuedBasicEPS',
#     'ContinuingAndDiscontinuedDilutedEPS', 'CostOfRevenue', 'DepletionIncomeStatement',
#     'DepreciationAmortizationDepletionIncomeStatement', 'DepreciationAndAmortizationInIncomeStatement',
#     'DepreciationIncomeStatement', 'DilutedAccountingChange', 'DilutedAverageShares',
#     'DilutedContinuousOperations', 'DilutedDiscontinuousOperations', 'DilutedEPS',
#     'DilutedEPSOtherGainsLosses', 'DilutedExtraordinary', 'DilutedNIAvailtoComStockholders',
#     'DividendPerShare', 'EBIT', 'EBITDA', 'EarningsFromEquityInterest',
#     'EarningsFromEquityInterestNetOfTax', 'ExciseTaxes', 'GainOnSaleOfBusiness',
#     'GainOnSaleOfPPE', 'GainOnSaleOfSecurity', 'GeneralAndAdministrativeExpense',
#     'GrossProfit', 'ImpairmentOfCapitalAssets', 'InsuranceAndClaims',
#     'InterestExpense', 'InterestExpenseNonOperating', 'InterestIncome',
#     'InterestIncomeNonOperating', 'MinorityInterests', 'NetIncome', 'NetIncomeCommonStockholders',
#     'NetIncomeContinuousOperations', 'NetIncomeDiscontinuousOperations',
#     'NetIncomeExtraordinary', 'NetIncomeFromContinuingAndDiscontinuedOperation',
#     'NetIncomeFromContinuingOperationNetMinorityInterest', 'NetIncomeFromTaxLossCarryforward',
#     'NetIncomeIncludingNoncontrollingInterests', 'NetInterestIncome',
#     'NetNonOperatingInterestIncomeExpense', 'NormalizedBasicEPS', 'NormalizedDilutedEPS',
#     'NormalizedEBITDA', 'NormalizedIncome', 'OperatingExpense', 'OperatingIncome',
#     'OperatingRevenue', 'OtherGandA', 'OtherIncomeExpense', 'OtherNonOperatingIncomeExpenses',
#     'OtherOperatingExpenses', 'OtherSpecialCharges', 'OtherTaxes',
#     'OtherunderPreferredStockDividend', 'PreferredStockDividends',
#     'PretaxIncome', 'ProvisionForDoubtfulAccounts', 'ReconciledCostOfRevenue',
#     'ReconciledDepreciation', 'RentAndLandingFees', 'RentExpenseSupplemental',
#     'ReportedNormalizedBasicEPS', 'ReportedNormalizedDilutedEPS', 'ResearchAndDevelopment',
#     'RestructuringAndMergernAcquisition', 'SalariesAndWages', 'SecuritiesAmortization',
#     'SellingAndMarketingExpense', 'SellingGeneralAndAdministration', 'SpecialIncomeCharges',
#     'TaxEffectOfUnusualItems', 'TaxLossCarryforwardBasicEPS', 'TaxLossCarryforwardDilutedEPS',
#     'TaxProvision', 'TaxRateForCalcs', 'TotalExpenses', 'TotalOperatingIncomeAsReported',
#     'TotalOtherFinanceCost', 'TotalRevenue', 'TotalUnusualItems',
#     'TotalUnusualIte
#
# Valuation Measures
# [
#     'ForwardPeRatio', 'PsRatio', 'PbRatio',
#     'EnterprisesValueEBITDARatio', 'EnterprisesValueRevenueRatio',
#     'PeRatio', 'MarketCap', 'EnterpriseValue', 'PegRatio'
# ]msExcludingGoodwill', 'WriteOff'
# ]
# ashPosition'
# ]
# ainLoss',
#     'WorkInProcess', 'WorkingCapital'
# ]

# %%
tk.corporate_events
# Out:
#                         id significance  \
# symbol date
# RIVN   2021-12-16  4486216            1
#        2022-03-10  4517609            1
#        2022-05-11  4545442            1
#        2022-08-11  4582990            1
#        2022-10-03  4603305            1
#        2022-11-09  4622248            1
#        2023-10-02  4769073            1
#        2022-01-18  4494615            1
#        2022-04-27  4536460            1
#        2022-05-11  4545274            1
#        2022-05-14  4547352            1
#        2023-01-03  4642040            1
#        2023-01-03  4642042            1
#        2023-02-28  4669747            1
#        2023-03-13  4675688            1
#        2023-10-04  4770065            1
#        2024-01-02  4806122            1
#
#                                                             headline  \
# symbol date
# RIVN   2021-12-16  Rivian Automotive Reports Quarterly Loss Per S...
#        2022-03-10  Rivian Automotive Inc Says Total Revenues For ...
#        2022-05-11  Rivian Automotive Reports Quarterly Loss Per S...
#        2022-08-11  Rivian Automotive Reports QTRLY Loss Per Share...
#        2022-10-03  Rivian Automotive Says Produced 7,363 Vehicles...
#        2022-11-09  Rivian Automotive Inc Reports Third Quarter Re...
#        2023-10-02  Rivian In Quarter Ended Sept, Produced 16,304 ...
#        2022-01-18  Ford Provides Update On Certain Special Items ...
#        2022-04-27      Ford Motor Reports Q1 Loss Per Share Of $0.78
#        2022-05-11  Rivian Releases First Quarter 2022 Financial R...
#        2022-05-14  Ford Sold 7 Million Shares Of Rivian On May 13...
#        2023-01-03  Rivian CEO In Email To Employees Says Supply C...
#        2023-01-03    Rivian Says Delivered 8,054 Vehicles In Q4 2022
#        2023-02-28  Rivian - QTRLY Loss Per Share $1.87 QTRLY Adju...
#        2023-03-13  Amazon, Rivian In Talks To End Exclusivity Par...
#        2023-10-04  Rivian Automotive Intends To Offer $1.5 Billio...
#        2024-01-02  Rivian Automotive Says In Q4 Delivered 13,972 ...
#
#                                                          description  \
# symbol date
# RIVN   2021-12-16  Dec 16 (Reuters) - Rivian Automotive Inc <RIVN...
#        2022-03-10  March 10 (Reuters) - Rivian Automotive Inc <RI...
#        2022-05-11  May 11 (Reuters) - Rivian Automotive Inc <RIVN...
#        2022-08-11  Aug 11 (Reuters) - Rivian Automotive Inc <RIVN...
#        2022-10-03  Oct 3 (Reuters) - Rivian Automotive Inc <RIVN....
#        2022-11-09  Nov 9 (Reuters) - Rivian Automotive Inc <RIVN....
#        2023-10-02  Oct 2 (Reuters) - Rivian Automotive Inc <RIVN....
#        2022-01-18  Jan 18 (Reuters) - Ford Motor Co <F.N>::FORD P...
#        2022-04-27  April 27 (Reuters) - Ford Motor Co <F.N>::FORD...
#        2022-05-11  May 11 (Reuters) - Rivian Automotive Inc <RIVN...
#        2022-05-14  May 13 (Reuters) - :FORD SOLD 7 MILLION SHARES...
#        2023-01-03  Jan 3 (Reuters) - Rivian Automotive Inc <RIVN....
#        2023-01-03  Jan 3 (Reuters) - Rivian Automotive Inc <RIVN....
#        2023-02-28  Feb 28 (Reuters) - Rivian Automotive Inc <RIVN...
#        2023-03-13  March 13 (Reuters) - :AMAZON, RIVIAN IN TALKS ...
#        2023-10-04  Oct 4 (Reuters) - Rivian Automotive Inc <RIVN....
#        2024-01-02  Jan 2 (Reuters) - Rivian Automotive Inc <RIVN....
#
#                          parentTopics
# symbol date
# RIVN   2021-12-16  Corporate Guidance
#        2022-03-10  Corporate Guidance
#        2022-05-11  Corporate Guidance
#        2022-08-11  Corporate Guidance
#        2022-10-03  Corporate Guidance
#        2022-11-09  Corporate Guidance
#        2023-10-02  Corporate Guidance
#        2022-01-18         Performance
#        2022-04-27         Performance
#        2022-05-11         Performance
#        2022-05-14   Ownership/Control
#        2023-01-03         Performance
#        2023-01-03         Performance
#        2023-02-28         Performance
#        2023-03-13     Corporate Deals
#        2023-10-04           Financing
#        2024-01-02         Performance

# %%
aapl = Ticker('aapl')
aapl.news(5)
# Out:
# ['error']

# %%
tk.quotes
# Out:
# {'RIVN': {'language': 'en-US',
#   'region': 'US',
#   'quoteType': 'EQUITY',
#   'typeDisp': 'Equity',
#   'quoteSourceName': 'Nasdaq Real Time Price',
#   'triggerable': True,
#   'customPriceAlertConfidence': 'HIGH',
#   'currency': 'USD',
#   'marketState': 'POST',
#   'regularMarketChangePercent': -1.6853929,
#   'regularMarketPrice': 19.25,
#   'exchange': 'NMS',
#   'shortName': 'Rivian Automotive, Inc.',
#   'longName': 'Rivian Automotive, Inc.',
#   'messageBoardId': 'finmb_144746614',
#   'exchangeTimezoneName': 'America/New_York',
#   'exchangeTimezoneShortName': 'EST',
#   'gmtOffSetMilliseconds': -18000000,
#   'market': 'us_market',
#   'esgPopulated': False,
#   'firstTradeDateMilliseconds': 1636554600000,
#   'priceHint': 2,
#   'postMarketChangePercent': -0.15584773,
#   'postMarketTime': 1704843397,
#   'postMarketPrice': 19.22,
#   'postMarketChange': -0.030000687,
#   'regularMarketChange': -0.32999992,
#   'regularMarketTime': 1704834000,
#   'regularMarketDayHigh': 19.759,
#   'regularMarketDayRange': '19.16 - 19.759',
#   'regularMarketDayLow': 19.16,
#   'regularMarketVolume': 18217481,
#   'regularMarketPreviousClose': 19.58,
#   'bid': 19.25,
#   'ask': 19.29,
#   'bidSize': 30,
#   'askSize': 11,
#   'fullExchangeName': 'NasdaqGS',
#   'financialCurrency': 'USD',
#   'regularMarketOpen': 19.58,
#   'averageDailyVolume3Month': 36712150,
#   'averageDailyVolume10Day': 28333110,
#   'fiftyTwoWeekLowChange': 7.5699997,
#   'fiftyTwoWeekLowChangePercent': 0.6481164,
#   'fiftyTwoWeekRange': '11.68 - 28.06',
#   'fiftyTwoWeekHighChange': -8.809999,
#   'fiftyTwoWeekHighChangePercent': -0.31397006,
#   'fiftyTwoWeekLow': 11.68,
#   'fiftyTwoWeekHigh': 28.06,
#   'fiftyTwoWeekChangePercent': 19.027351,
#   'earningsTimestamp': 1708549200,
#   'earningsTimestampStart': 1708549200,
#   'earningsTimestampEnd': 1708549200,
#   'trailingAnnualDividendRate': 0.0,
#   'trailingAnnualDividendYield': 0.0,
#   'epsTrailingTwelveMonths': -6.02,
#   'epsForward': -3.55,
#   'epsCurrentYear': -4.95,
#   'priceEpsCurrentYear': -3.888889,
#   'sharesOutstanding': 949892992,
#   'bookValue': 11.038,
#   'fiftyDayAverage': 18.7686,
#   'fiftyDayAverageChange': 0.48139954,
#   'fiftyDayAverageChangePercent': 0.025649197,
#   'twoHundredDayAverage': 18.5954,
#   'twoHundredDayAverageChange': 0.65460014,
#   'twoHundredDayAverageChangePercent': 0.03520226,
#   'marketCap': 18436071424,
#   'forwardPE': -5.4225354,
#   'priceToBook': 1.7439753,
#   'sourceInterval': 15,
#   'exchangeDataDelayedBy': 0,
#   'ipoExpectedDate': '2021-11-10',
#   'averageAnalystRating': '2.1 - Buy',
#   'tradeable': False,
#   'cryptoTradeable': False,
#   'displayName': 'Rivian Automotive'}}

# %%
tk.recommendations
# Out:
# {'RIVN': {'symbol': 'RIVN',
#   'recommendedSymbols': [{'symbol': 'LCID', 'score': 0.27211},
#    {'symbol': 'COIN', 'score': 0.130288},
#    {'symbol': 'RBLX', 'score': 0.125622},
#    {'symbol': 'NIO', 'score': 0.122046},
#    {'symbol': 'QS', 'score': 0.119754}]}}

# %%
tickers = Ticker('aapl gs hasgx ^GSPC ezu')
tickers.recommendations
# Out:
# {'aapl': {'symbol': 'AAPL',
#   'recommendedSymbols': [{'symbol': 'AMZN', 'score': 0.34103},
#    {'symbol': 'TSLA', 'score': 0.319434},
#    {'symbol': 'GOOG', 'score': 0.300335},
#    {'symbol': 'META', 'score': 0.293414},
#    {'symbol': 'MSFT', 'score': 0.224703}]},
#  'gs': {'symbol': 'GS',
#   'recommendedSymbols': [{'symbol': 'MS', 'score': 0.214246},
#    {'symbol': 'JPM', 'score': 0.166364},
#    {'symbol': 'WFC', 'score': 0.15493},
#    {'symbol': 'C', 'score': 0.145765},
#    {'symbol': 'AXP', 'score': 0.14089}]},
#  'hasgx': {'symbol': 'HASGX',
#   'recommendedSymbols': [{'symbol': 'HAVLX', 'score': 0.022692},
#    {'symbol': 'HASCX', 'score': 0.017097},
#    {'symbol': 'HAMGX', 'score': 0.016919},
#    {'symbol': 'HAIGX', 'score': 0.014178},
#    {'symbol': 'HAMVX', 'score': 0.013996}]},
#  '^GSPC': {'symbol': '^GSPC',
#   'recommendedSymbols': [{'symbol': '^TYX', 'score': 0.182613},
#    {'symbol': '^IXIC', 'score': 0.166723},
#    {'symbol': '^DJI', 'score': 0.142361},
#    {'symbol': 'GE', 'score': 0.101402},
#    {'symbol': 'MCD', 'score': 0.098343}]},
#  'ezu': {'symbol': 'EZU',
#   'recommendedSymbols': [{'symbol': 'EWQ', 'score': 0.149148},
#    {'symbol': 'IEV', 'score': 0.145155},
#    {'symbol': 'EWU', 'score': 0.141407},
#    {'symbol': 'EWN', 'score': 0.138025},
#    {'symbol': 'EWP', 'score': 0.137958}]}}

# %%
tickers = Ticker('spy ma fsr rivn')
tickers.recommendations
# Out:
# {'spy': {'symbol': 'SPY',
#   'recommendedSymbols': [{'symbol': 'QQQ', 'score': 0.21067},
#    {'symbol': 'DIA', 'score': 0.129867},
#    {'symbol': 'IWM', 'score': 0.1102},
#    {'symbol': 'GLD', 'score': 0.103194},
#    {'symbol': 'NVDA', 'score': 0.102036}]},
#  'ma': {'symbol': 'MA',
#   'recommendedSymbols': [{'symbol': 'V', 'score': 0.314786},
#    {'symbol': 'PYPL', 'score': 0.148816},
#    {'symbol': 'AXP', 'score': 0.136451},
#    {'symbol': 'CRM', 'score': 0.124525},
#    {'symbol': 'ADBE', 'score': 0.123967}]},
#  'fsr': {'symbol': 'FSR',
#   'recommendedSymbols': [{'symbol': 'LI', 'score': 0.14357},
#    {'symbol': 'BLNK', 'score': 0.143474},
#    {'symbol': 'QS', 'score': 0.143443},
#    {'symbol': 'XPEV', 'score': 0.139339},
#    {'symbol': 'WKHS', 'score': 0.131737}]},
#  'rivn': {'symbol': 'RIVN',
#   'recommendedSymbols': [{'symbol': 'LCID', 'score': 0.27211},
#    {'symbol': 'COIN', 'score': 0.130288},
#    {'symbol': 'RBLX', 'score': 0.125622},
#    {'symbol': 'NIO', 'score': 0.122046},
#    {'symbol': 'QS', 'score': 0.119754}]}}

# %%
aapl = Ticker('aapl')
aapl.technical_insights
# Out:
# {'aapl': {'symbol': 'aapl',
#   'instrumentInfo': {'technicalEvents': {'provider': 'Trading Central',
#     'sector': 'Technology',
#     'shortTermOutlook': {'stateDescription': 'Recent bearish events outweigh bullish events.',
#      'direction': 'Bearish',
#      'score': 2,
#      'scoreDescription': 'Bearish Evidence',
#      'sectorDirection': 'Bearish',
#      'sectorScore': 3,
#      'sectorScoreDescription': 'Strong Bearish Evidence',
#      'indexDirection': 'Bullish',
#      'indexScore': 3,
#      'indexScoreDescription': 'Strong Bullish Evidence'},
#     'intermediateTermOutlook': {'stateDescription': 'Recent bearish events outweigh bullish events.',
#      'direction': 'Bearish',
#      'score': 1,
#      'scoreDescription': 'Weak Bearish Evidence',
#      'sectorDirection': 'Bullish',
#      'sectorScore': 3,
#      'sectorScoreDescription': 'Strong Bullish Evidence',
#      'indexDirection': 'Bullish',
#      'indexScore': 3,
#      'indexScoreDescription': 'Strong Bullish Evidence'},
#     'longTermOutlook': {'stateDescription': 'There is one bullish event.',
#      'direction': 'Bullish',
#      'score': 1,
#      'scoreDescription': 'Weak Bullish Evidence',
#      'sectorDirection': 'Neutral',
#      'sectorScore': 0,
#      'sectorScoreDescription': 'No Evidence',
#      'indexDirection': 'Bullish',
#      'indexScore': 2,
#      'indexScoreDescription': 'Bullish Evidence'}},
#    'keyTechnicals': {'provider': 'Trading Central',
#     'support': 173.9458,
#     'resistance': 189.9,
#     'stopLoss': 171.335722},
#    'valuation': {'color': 0.0,
#     'description': 'Overvalued',
#     'discount': '-3%',
#     'relativeValue': 'Premium',
#     'provider': 'Trading Central'}},
#   'companySnapshot': {'sectorInfo': 'Technology',
#    'company': {'innovativeness': 0.9981,
#     'hiring': 0.9512999999999999,
#     'sustainability': 0.5667,
#     'insiderSentiments': 0.1832,
#     'earningsReports': 0.8724,
#     'dividends': 0.0701},
#    'sector': {'innovativeness': 0.5,
#     'hiring': 0.5,
#     'sustainability': 0.5,
#     'insiderSentiments': 0.5,
#     'earningsReports': 0.5,
#     'dividends': 0.5}},
#   'recommendation': {'targetPrice': 230.0,
#    'provider': 'Argus Research',
#    'rating': 'BUY'},
#   'sigDevs': [{'headline': 'U.S. Moves Closer To Filing Sweeping Antitrust Case Against Apple - NYT',
#     'date': '2024-01-05'}],
#   'secReports': [{'id': '0000320193-23-000106_320193',
#     'type': 'Periodic Financial Reports',
#     'title': '10-K : Periodic Financial Reports',
#     'description': 'Annual report pursuant to Section 13 and 15(d)',
#     'filingDate': 1698969600000,
#     'snapshotUrl': 'https://cdn.yahoofinance.com/prod/sec-reports-thumbnails/0000320193/000032019323000106/thumbnail.png',
#     'formType': '10-K'},
#    {'id': '0000320193-23-000104_320193',
#     'type': 'Corporate Changes & Voting Matters',
#     'title': '8-K : Corporate Changes & Voting Matters',
#     'description': 'Current report filing',
#     'filingDate': 1698883200000,
#     'snapshotUrl': 'https://cdn.yahoofinance.com/prod/sec-reports-thumbnails/0000320193/000032019323000104/thumbnail.png',
#     'formType': '8-K'},
#    {'id': '0000320193-23-000077_320193',
#     'type': 'Periodic Financial Reports',
#     'title': '10-Q : Periodic Financial Reports',
#     'description': 'Quarterly report pursuant to Section 13 or 15(d)',
#     'filingDate': 1691107200000,
#     'snapshotUrl': 'https://cdn.yahoofinance.com/prod/sec-reports-thumbnails/0000320193/000032019323000077/thumbnail.png',
#     'formType': '10-Q'},
#    {'id': '0000320193-23-000075_320193',
#     'type': 'Corporate Changes & Voting Matters',
#     'title': '8-K : Corporate Changes & Voting Matters',
#     'description': 'Current report filing',
#     'filingDate': 1691020800000,
#     'snapshotUrl': 'https://cdn.yahoofinance.com/prod/sec-reports-thumbnails/0000320193/000032019323000075/thumbnail.png',
#     'formType': '8-K'},
#    {'id': '0001140361-23-023909_320193',
#     'type': 'Corporate Changes & Voting Matters',
#     'title': '8-K : Corporate Changes & Voting Matters',
#     'description': 'Current report filing',
#     'filingDate': 1683676800000,
#     'snapshotUrl': 'https://cdn.yahoofinance.com/prod/sec-reports-thumbnails/0000320193/000114036123023909/thumbnail.png',
#     'formType': '8-K'},
#    {'id': '0000320193-23-000064_320193',
#     'type': 'Periodic Financial Reports',
#     'title': '10-Q : Periodic Financial Reports',
#     'description': 'Quarterly report pursuant to Section 13 or 15(d)',
#     'filingDate': 1683244800000,
#     'snapshotUrl': 'https://cdn.yahoofinance.com/prod/sec-reports-thumbnails/0000320193/000032019323000064/thumbnail.png',
#     'formType': '10-Q'},
#    {'id': '0000320193-23-000063_320193',
#     'type': 'Corporate Changes & Voting Matters',
#     'title': '8-K : Corporate Changes & Voting Matters',
#     'description': 'Current report filing',
#     'filingDate': 1683158400000,
#     'snapshotUrl': 'https://cdn.yahoofinance.com/prod/sec-reports-thumbnails/0000320193/000032019323000063/thumbnail.png',
#     'formType': '8-K'},
#    {'id': '0001140361-23-011192_320193',
#     'type': 'Corporate Changes & Voting Matters',
#     'title': '8-K : Corporate Changes & Voting Matters',
#     'description': 'Current report filing',
#     'filingDate': 1678406400000,
#     'snapshotUrl': 'https://cdn.yahoofinance.com/prod/sec-reports-thumbnails/0000320193/000114036123011192/thumbnail.png',
#     'formType': '8-K'},
#    {'id': '0001193125-23-038262_320193',
#     'type': 'Tender Offer/Acquisition Reports',
#     'title': 'SC 13G/A : Tender Offer/Acquisition Reports',
#     'description': 'Schedule filed to report acquisition of beneficial ownership of 5% or more of a class of equity securities by passive investors and certain institutions',
#     'filingDate': 1676332800000,
#     'snapshotUrl': 'https://cdn.yahoofinance.com/prod/sec-reports-thumbnails/0001067983/000119312523038262/thumbnail.png',
#     'formType': 'SC 13G/A'},
#    {'id': '0001104659-23-015055_320193',
#     'type': 'Tender Offer/Acquisition Reports',
#     'title': 'SC 13G/A : Tender Offer/Acquisition Reports',
#     'description': 'Schedule filed to report acquisition of beneficial ownership of 5% or more of a class of equity securities by passive investors and certain institutions',
#     'filingDate': 1675900800000,
#     'snapshotUrl': 'https://cdn.yahoofinance.com/prod/sec-reports-thumbnails/0000320193/000110465923015055/thumbnail.png',
#     'formType': 'SC 13G/A'},
#    {'id': '0000320193-23-000006_320193',
#     'type': 'Periodic Financial Reports',
#     'title': '10-Q : Periodic Financial Reports',
#     'description': 'Quarterly report pursuant to Section 13 or 15(d)',
#     'filingDate': 1675382400000,
#     'snapshotUrl': 'https://cdn.yahoofinance.com/prod/sec-reports-thumbnails/0000320193/000032019323000006/thumbnail.png',
#     'formType': '10-Q'},
#    {'id': '0001140361-23-004439_320193',
#     'type': 'Proxy Statements',
#     'title': 'DEFA14A : Proxy Statements',
#     'description': 'Definitive additional proxy soliciting materials including Rule 14(a)(12) material. Note: Submission type DEFA14A can be filed as part of Form 8-K. For filers subject to 8-K filing requirements we recommend the use of the 8-K combined form type as the easiest method for fulfilling your filing requirement for both forms',
#     'filingDate': 1675382400000,
#     'snapshotUrl': 'https://cdn.yahoofinance.com/prod/sec-reports-thumbnails/0000320193/000114036123004439/thumbnail.png',
#     'formType': 'DEFA14A'},
#    {'id': '0000320193-23-000005_320193',
#     'type': 'Corporate Changes & Voting Matters',
#     'title': '8-K : Corporate Changes & Voting Matters',
#     'description': 'Current report filing',
#     'filingDate': 1675296000000,
#     'snapshotUrl': 'https://cdn.yahoofinance.com/prod/sec-reports-thumbnails/0000320193/000032019323000005/thumbnail.png',
#     'formType': '8-K'},
#    {'id': '0001308179-23-000020_320193',
#     'type': 'Proxy Statements',
#     'title': 'DEFA14A : Proxy Statements',
#     'description': 'Definitive additional proxy soliciting materials including Rule 14(a)(12) material. Note: Submission type DEFA14A can be filed as part of Form 8-K. For filers subject to 8-K filing requirements we recommend the use of the 8-K combined form type as the easiest method for fulfilling your filing requirement for both forms',
#     'filingDate': 1673481600000,
#     'snapshotUrl': 'https://cdn.yahoofinance.com/prod/sec-reports-thumbnails/0000320193/000130817923000020/thumbnail.png',
#     'formType': 'DEFA14A'},
#    {'id': '0001308179-23-000019_320193',
#     'type': 'Proxy Statements',
#     'title': 'DEF 14A : Proxy Statements',
#     'description': 'Definitive proxy statements',
#     'filingDate': 1673481600000,
#     'snapshotUrl': 'https://cdn.yahoofinance.com/prod/sec-reports-thumbnails/0000320193/000130817923000019/thumbnail.png',
#     'formType': 'DEF 14A'},
#    {'id': '0001193125-22-278435_320193',
#     'type': 'Corporate Changes & Voting Matters',
#     'title': '8-K : Corporate Changes & Voting Matters',
#     'description': 'Current report filing',
#     'filingDate': 1667779200000,
#     'snapshotUrl': 'https://cdn.yahoofinance.com/prod/sec-reports-thumbnails/0000320193/000119312522278435/thumbnail.png',
#     'formType': '8-K'},
#    {'id': '0000320193-22-000108_320193',
#     'type': 'Periodic Financial Reports',
#     'title': '10-K : Periodic Financial Reports',
#     'description': 'Annual report pursuant to Section 13 and 15(d)',
#     'filingDate': 1666915200000,
#     'snapshotUrl': 'https://cdn.yahoofinance.com/prod/sec-reports-thumbnails/0000320193/000032019322000108/thumbnail.png',
#     'formType': '10-K'},
#    {'id': '0000320193-22-000107_320193',
#     'type': 'Corporate Changes & Voting Matters',
#     'title': '8-K : Corporate Changes & Voting Matters',
#     'description': 'Current report filing',
#     'filingDate': 1666828800000,
#     'snapshotUrl': 'https://cdn.yahoofinance.com/prod/sec-reports-thumbnails/0000320193/000032019322000107/thumbnail.png',
#     'formType': '8-K'},
#    {'id': '0001193125-22-225365_320193',
#     'type': 'Corporate Changes & Voting Matters',
#     'title': '8-K : Corporate Changes & Voting Matters',
#     'description': 'Current report filing',
#     'filingDate': 1660867200000,
#     'snapshotUrl': 'https://cdn.yahoofinance.com/prod/sec-reports-thumbnails/0000320193/000119312522225365/thumbnail.png',
#     'formType': '8-K'},
#    {'id': '0001193125-22-214914_320193',
#     'type': 'Corporate Changes & Voting Matters',
#     'title': '8-K : Corporate Changes & Voting Matters',
#     'description': 'Current report filing',
#     'filingDate': 1659916800000,
#     'snapshotUrl': 'https://cdn.yahoofinance.com/prod/sec-reports-thumbnails/0000320193/000119312522214914/thumbnail.png',
#     'formType': '8-K'},
#    {'id': '0000320193-22-000070_320193',
#     'type': 'Periodic Financial Reports',
#     'title': '10-Q : Periodic Financial Reports',
#     'description': 'Quarterly report pursuant to Section 13 or 15(d)',
#     'filingDate': 1659052800000,
#     'snapshotUrl': 'https://cdn.yahoofinance.com/prod/sec-reports-thumbnails/0000320193/000032019322000070/thumbnail.png',
#     'formType': '10-Q'},
#    {'id': '0000320193-22-000069_320193',
#     'type': 'Corporate Changes & Voting Matters',
#     'title': '8-K : Corporate Changes & Voting Matters',
#     'description': 'Current report filing',
#     'filingDate': 1658966400000,
#     'snapshotUrl': 'https://cdn.yahoofinance.com/prod/sec-reports-thumbnails/0000320193/000032019322000069/thumbnail.png',
#     'formType': '8-K'},
#    {'id': '0001193125-22-128361_320193',
#     'type': 'Offering Registrations',
#     'title': 'S-8 POS : Offering Registrations',
#     'description': 'Post-effective amendment to a S-8 registration statement',
#     'filingDate': 1651190400000,
#     'snapshotUrl': 'https://cdn.yahoofinance.com/prod/sec-reports-thumbnails/0000320193/000119312522128361/thumbnail.png',
#     'formType': 'S-8 POS'},
#    {'id': '0001193125-22-128368_320193',
#     'type': 'Offering Registrations',
#     'title': 'S-8 : Offering Registrations',
#     'description': 'Initial registration statement for securities to be offered to employees pursuant to employee benefit plans',
#     'filingDate': 1651190400000,
#     'snapshotUrl': 'https://cdn.yahoofinance.com/prod/sec-reports-thumbnails/0000320193/000119312522128368/thumbnail.png',
#     'formType': 'S-8'},
#    {'id': '0000320193-22-000059_320193',
#     'type': 'Periodic Financial Reports',
#     'title': '10-Q : Periodic Financial Reports',
#     'description': 'Quarterly report pursuant to Section 13 or 15(d)',
#     'filingDate': 1651190400000,
#     'snapshotUrl': 'https://cdn.yahoofinance.com/prod/sec-reports-thumbnails/0000320193/000032019322000059/thumbnail.png',
#     'formType': '10-Q'},
#    {'id': '0001193125-22-128354_320193',
#     'type': 'Offering Registrations',
#     'title': 'S-8 POS : Offering Registrations',
#     'description': 'Post-effective amendment to a S-8 registration statement',
#     'filingDate': 1651190400000,
#     'snapshotUrl': 'https://cdn.yahoofinance.com/prod/sec-reports-thumbnails/0000320193/000119312522128354/thumbnail.png',
#     'formType': 'S-8 POS'},
#    {'id': '0000320193-22-000058_320193',
#     'type': 'Corporate Changes & Voting Matters',
#     'title': '8-K : Corporate Changes & Voting Matters',
#     'description': 'Current report filing',
#     'filingDate': 1651104000000,
#     'snapshotUrl': 'https://cdn.yahoofinance.com/prod/sec-reports-thumbnails/0000320193/000032019322000058/thumbnail.png',
#     'formType': '8-K'},
#    {'id': '0001193125-22-066169_320193',
#     'type': 'Corporate Changes & Voting Matters',
#     'title': '8-K : Corporate Changes & Voting Matters',
#     'description': 'Current report filing',
#     'filingDate': 1646352000000,
#     'snapshotUrl': 'https://cdn.yahoofinance.com/prod/sec-reports-thumbnails/0000320193/000119312522066169/thumbnail.png',
#     'formType': '8-K'},
#    {'id': '0001104659-22-016224_320193',
#     'type': 'Tender Offer/Acquisition Reports',
#     'title': 'SC 13G/A : Tender Offer/Acquisition Reports',
#     'description': 'Schedule filed to report acquisition of beneficial ownership of 5% or more of a class of equity securities by passive investors and certain institutions',
#     'filingDate': 1644364800000,
#     'snapshotUrl': 'https://cdn.yahoofinance.com/prod/sec-reports-thumbnails/0000320193/000110465922016224/thumbnail.png',
#     'formType': 'SC 13G/A'},
#    {'id': '0000320193-22-000007_320193',
#     'type': 'Periodic Financial Reports',
#     'title': '10-Q : Periodic Financial Reports',
#     'description': 'Quarterly report pursuant to Section 13 or 15(d)',
#     'filingDate': 1643328000000,
#     'snapshotUrl': 'https://cdn.yahoofinance.com/prod/sec-reports-thumbnails/320193/000032019322000007/thumbnail.png',
#     'formType': '10-Q'},
#    {'id': '0000320193-22-000006_320193',
#     'type': 'Corporate Changes & Voting Matters',
#     'title': '8-K : Corporate Changes & Voting Matters',
#     'description': 'Current report filing',
#     'filingDate': 1643241600000,
#     'snapshotUrl': 'https://cdn.yahoofinance.com/prod/sec-reports-thumbnails/320193/000032019322000006/thumbnail.png',
#     'formType': '8-K'}]}}
