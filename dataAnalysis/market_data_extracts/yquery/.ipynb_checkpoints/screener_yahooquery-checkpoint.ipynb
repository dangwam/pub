# %%
import pandas as pd
from yahooquery import Ticker
from datetime import datetime
s = Screener()

# %% [markdown]
# ### 'bearish_stocks_right_now', 'best_hist_performance_etfs','cheapest_etfs' , 'fifty_two_wk_gainers',
# ### 'fifty_two_wk_losers', 'high_yield_bond', 'high_yield_high_return', 'largest_market_cap',
# ### 'latest_analyst_upgraded_stocks', 'morningstar_five_star_stocks', 'most_institutionally_bought_large_cap_stocks',
# ### 'most_institutionally_held_large_cap_stocks', 'most_institutionally_sold_large_cap_stocks','most_shorted_stocks',
# ### 'most_watched_tickers', 'net_net_strategy','portfolio_actions_most_added',
# ### 'stocks_most_bought_by_hedge_funds', 'stocks_most_bought_by_pension_fund', 'stocks_most_bought_by_private_equity',
# ### 'stocks_most_bought_by_sovereign_wealth_fund', 'stocks_with_most_institutional_buyers',
# ### 'stocks_with_most_institutional_sellers', 'strong_undervalued_stocks',
# ### 'top_options_implied_volatality',  'top_options_open_interest' 'top_performing_etfs',
# ### 'top_stocks_owned_by_cathie_wood',  'top_stocks_owned_by_goldman_sachs' ' 'top_stocks_owned_by_ray_dalio'### ,
#  'top_stocks_owned_by_warren_buff
# ### 'undervalued_growth_stocks',  'undervalued_large_caps'
#  'undervalued_wide_moat_stocks
#  'upside_breakout_stocks_dail
# ### 'uranium'
# ### 'day_gainers','day_gainers_options','day_losers','day_gainers_br','day_losers_br','day_losers_options',
# ### 'fifty_two_wk_gainers','fifty_two_wk_losers','financial_data_stock_exchanges',y',et',

# %%
select_count = 10
industry = 'most_shorted_stocks'

data_path = r'C:\Users\pythonProject\data\data_produced\yquerry_screens\options'
today = datetime.today().strftime('%Y%m%d')
file_name = data_path + f"\\{today}_option_data_multiple_tickers.csv"
file_name_oi = data_path + f"\\{today}_oi_data_multiple_tickers.csv"
file_name


my_dict = industry + '_dict'
my_data_list = industry + '_data_list'
my_df = 'df_' + industry
my_dict = s.get_screeners([industry])
my_data_list = my_dict[industry]['quotes']
columns = ['symbol', 'longName', 'regularMarketTime','quoteType', 'dividendYield', 'yieldTTM', 'annualReturnNavY3', 'annualReturnNavY5', 'fiftyTwoWeekRange', 
           'regularMarketPrice', 'regularMarketDayRange', 'regularMarketVolume',
          'regularMarketOpen', 'averageDailyVolume3Month', 'averageDailyVolume10Day', 'averageAnalystRating'
          ]
df_temp = pd.DataFrame(my_data_list, columns=columns)
df_temp.set_index(keys=['symbol'], inplace = True)
df_temp.to_csv(file_name)
df_temp.describe()
# Out:
#        regularMarketTime  dividendYield  yieldTTM  annualReturnNavY3  \
# count       2.500000e+01       5.000000       0.0                0.0
# mean        1.705698e+09      15.032000       NaN                NaN
# std         9.255629e-01       9.131619       NaN                NaN
# min         1.705698e+09       6.940000       NaN                NaN
# 25%         1.705698e+09       8.030000       NaN                NaN
# 50%         1.705698e+09      11.750000       NaN                NaN
# 75%         1.705698e+09      19.780000       NaN                NaN
# max         1.705698e+09      28.660000       NaN                NaN
#
#        annualReturnNavY5  regularMarketPrice  regularMarketVolume  \
# count                0.0           25.000000         2.500000e+01
# mean                 NaN           11.936600         5.997975e+06
# std                  NaN           11.908634         1.163018e+07
# min                  NaN            1.540000         1.006380e+05
# 25%                  NaN            2.810000         7.460780e+05
# 50%                  NaN            6.050000         2.073096e+06
# 75%                  NaN           20.180000         6.995104e+06
# max                  NaN           44.920000         5.628310e+07
#
#        regularMarketOpen  averageDailyVolume3Month  averageDailyVolume10Day
# count          25.000000              2.500000e+01             2.500000e+01
# mean           11.921280              5.944984e+06             6.489188e+06
# std            11.510224              8.042694e+06             1.179490e+07
# min             1.680000              6.995010e+05             2.181300e+05
# 25%             3.040000              1.449721e+06             8.014700e+05
# 50%             6.250000              3.203257e+06             2.078830e+06
# 75%            21.400000              7.407201e+06             5.555240e+06
# max            43.100000              3.861312e+07             4.511599e+07

# %%
my_dict
# Out:
# {'most_shorted_stocks': {'id': '679b1d2b-95d6-4731-9fd1-f9539ede458c',
#   'title': 'Most Shorted Stocks',
#   'description': 'Stocks with the highest short interest positions from Nasdaq and NYSE reports released every two weeks.',
#   'canonicalName': 'MOST_SHORTED_STOCKS',
#   'criteriaMeta': {'size': 25,
#    'offset': 0,
#    'sortField': 'short_percentage_of_shares_outstanding.value',
#    'sortType': 'DESC',
#    'quoteType': 'EQUITY',
#    'criteria': [{'field': 'region',
#      'operators': ['EQ'],
#      'values': [],
#      'labelsSelected': [52],
#      'dependentValues': []},
#     {'field': 'intradayprice',
#      'operators': ['GT'],
#      'values': [1],
#      'labelsSelected': [],
#      'dependentValues': []},
#     {'field': 'avgdailyvol3m',
#      'operators': ['GT'],
#      'values': [200000],
#      'labelsSelected': [],
#      'dependentValues': []}],
#    'topOperator': 'AND'},
#   'rawCriteria': '{"size":25,"offset":0,"sortField":"short_percentage_of_shares_outstanding.value","sortType":"DESC","quoteType":"EQUITY","topOperator":"AND","query":{"operator":"AND","operands":[{"operator":"or","operands":[{"operator":"EQ","operands":["region","us"]}]},{"operator":"gt","operands":["intradayprice",1]},{"operator":"gt","operands":["avgdailyvol3m",200000]}]}}',
#   'start': 0,
#   'count': 25,
#   'total': 3258,
#   'quotes': [{'language': 'en-US',
#     'region': 'US',
#     'quoteType': 'EQUITY',
#     'typeDisp': 'Equity',
#     'quoteSourceName': 'Delayed Quote',
#     'triggerable': False,
#     'customPriceAlertConfidence': 'LOW',
#     'lastCloseTevEbitLtm': -1.045166,
#     'lastClosePriceToNNWCPerShare': -0.05716165237264171,
#     'currency': 'USD',
#     'regularMarketChangePercent': -6.097563,
#     'exchange': 'NCM',
#     'averageAnalystRating': '3.0 - Hold',
#     'fiftyTwoWeekLow': 0.325,
#     'fiftyTwoWeekHigh': 126.0,
#     'shortName': 'Smart for Life, Inc.',
#     'firstTradeDateMilliseconds': 1645021800000,
#     'priceHint': 4,
#     'preMarketChange': -0.00999999,
#     'preMarketChangePercent': -0.64935005,
#     'preMarketTime': 1705924137,
#     'preMarketPrice': 1.53,
#     'regularMarketChange': -0.100000024,
#     'regularMarketTime': 1705698000,
#     'regularMarketPrice': 1.54,
#     'regularMarketDayHigh': 1.7299,
#     'regularMarketDayRange': '1.5 - 1.7299',
#     'regularMarketDayLow': 1.5,
#     'regularMarketVolume': 455249,
#     'regularMarketPreviousClose': 1.64,
#     'bid': 0.0,
#     'ask': 0.0,
#     'bidSize': 29,
#     'askSize': 8,
#     'market': 'us_market',
#     'messageBoardId': 'finmb_542818360',
#     'fullExchangeName': 'NasdaqCM',
#     'longName': 'Smart for Life, Inc.',
#     'financialCurrency': 'USD',
#     'regularMarketOpen': 1.68,
#     'averageDailyVolume3Month': 2957315,
#     'averageDailyVolume10Day': 396699,
#     'fiftyTwoWeekLowChange': 1.2149999,
#     'fiftyTwoWeekLowChangePercent': 3.7384615,
#     'fiftyTwoWeekRange': '0.325 - 126.0',
#     'fiftyTwoWeekHighChange': -124.46,
#     'fiftyTwoWeekHighChangePercent': -0.98777777,
#     'fiftyTwoWeekChangePercent': -98.50296,
#     'trailingAnnualDividendRate': 0.0,
#     'trailingAnnualDividendYield': 0.0,
#     'marketState': 'PRE',
#     'epsTrailingTwelveMonths': -126.01,
#     'epsForward': -0.27,
#     'epsCurrentYear': -50.58,
#     'priceEpsCurrentYear': -0.030446814,
#     'sharesOutstanding': 796666,
#     'bookValue': 1.507,
#     'fiftyDayAverage': 1.488804,
#     'fiftyDayAverageChange': 0.05119598,
#     'fiftyDayAverageChangePercent': 0.03438732,
#     'twoHundredDayAverage': 7.9341264,
#     'twoHundredDayAverageChange': -6.3941264,
#     'twoHundredDayAverageChangePercent': -0.80590177,
#     'marketCap': 1226865,
#     'forwardPE': -5.7037034,
#     'priceToBook': 1.0218978,
#     'sourceInterval': 15,
#     'exchangeDataDelayedBy': 0,
#     'exchangeTimezoneName': 'America/New_York',
#     'exchangeTimezoneShortName': 'EST',
#     'gmtOffSetMilliseconds': -18000000,
#     'ipoExpectedDate': '2023-12-18',
#     'esgPopulated': False,
#     'tradeable': False,
#     'cryptoTradeable': False,
#     'displayName': 'Smart for Life',
#     'symbol': 'SMFL'},
#    {'language': 'en-US',
#     'region': 'US',
#     'quoteType': 'EQUITY',
#     'typeDisp': 'Equity',
#     'quoteSourceName': 'Nasdaq Real Time Price',
#     'triggerable': False,
#     'customPriceAlertConfidence': 'LOW',
#     'lastCloseTevEbitLtm': -0.16766,
#     'lastClosePriceToNNWCPerShare': 3.941820656820966,
#     'currency': 'USD',
#     'regularMarketChangePercent': -7.9787226,
#     'exchange': 'NCM',
#     'averageAnalystRating': '2.0 - Buy',
#     'fiftyTwoWeekLow': 2.75,
#     'fiftyTwoWeekHigh': 149.8,
#     'shortName': 'First Wave BioPharma, Inc.',
#     'firstTradeDateMilliseconds': 1476192600000,
#     'priceHint': 4,
#     'preMarketChange': -0.00999999,
#     'preMarketChangePercent': -0.28901705,
#     'preMarketTime': 1705925107,
#     'preMarketPrice': 3.45,
#     'regularMarketChange': -0.29999995,
#     'regularMarketTime': 1705698001,
#     'regularMarketPrice': 3.46,
#     'regularMarketDayHigh': 3.97,
#     'regularMarketDayRange': '3.4 - 3.97',
#     'regularMarketDayLow': 3.4,
#     'regularMarketVolume': 253845,
#     'regularMarketPreviousClose': 3.76,
#     'bid': 3.45,
#     'ask': 3.5,
#     'bidSize': 9,
#     'askSize': 10,
#     'market': 'us_market',
#     'messageBoardId': 'finmb_261738327',
#     'fullExchangeName': 'NasdaqCM',
#     'longName': 'First Wave BioPharma, Inc.',
#     'financialCurrency': 'USD',
#     'regularMarketOpen': 3.7,
#     'averageDailyVolume3Month': 699501,
#     'averageDailyVolume10Day': 218130,
#     'fiftyTwoWeekLowChange': 0.71000004,
#     'fiftyTwoWeekLowChangePercent': 0.25818184,
#     'fiftyTwoWeekRange': '2.75 - 149.8',
#     'fiftyTwoWeekHighChange': -146.34,
#     'fiftyTwoWeekHighChangePercent': -0.9769025,
#     'fiftyTwoWeekChangePercent': -96.1978,
#     'earningsTimestamp': 1699909200,
#     'earningsTimestampStart': 1711051200,
#     'earningsTimestampEnd': 1711396800,
#     'trailingAnnualDividendRate': 0.0,
#     'trailingPE': 0.003058158,
#     'trailingAnnualDividendYield': 0.0,
#     'marketState': 'PRE',
#     'epsTrailingTwelveMonths': 1131.4,
#     'epsForward': -5.33,
#     'epsCurrentYear': -46.82,
#     'priceEpsCurrentYear': -0.073900044,
#     'sharesOutstanding': 674998,
#     'bookValue': 4.871,
#     'fiftyDayAverage': 5.0151,
#     'fiftyDayAverageChange': -1.5551,
#     'fiftyDayAverageChangePercent': -0.31008354,
#     'twoHundredDayAverage': 19.227175,
#     'twoHundredDayAverageChange': -15.767175,
#     'twoHundredDayAverageChangePercent': -0.82004637,
#     'marketCap': 2335493,
#     'forwardPE': -0.64915574,
#     'priceToBook': 0.71032643,
#     'sourceInterval': 15,
#     'exchangeDataDelayedBy': 0,
#     'exchangeTimezoneName': 'America/New_York',
#     'exchangeTimezoneShortName': 'EST',
#     'gmtOffSetMilliseconds': -18000000,
#     'prevName': 'AzurRx BioPharma, Inc.',
#     'nameChangeDate': '2024-01-21',
#     'esgPopulated': False,
#     'tradeable': False,
#     'cryptoTradeable': False,
#     'displayName': 'First Wave BioPharma',
#     'symbol': 'FWBI'},
#    {'language': 'en-US',
#     'region': 'US',
#     'quoteType': 'EQUITY',
#     'typeDisp': 'Equity',
#     'quoteSourceName': 'Delayed Quote',
#     'triggerable': True,
#     'customPriceAlertConfidence': 'HIGH',
#     'lastCloseTevEbitLtm': -0.145959,
#     'lastClosePriceToNNWCPerShare': -0.37463765507753843,
#     'currency': 'USD',
#     'regularMarketChangePercent': -1.4598526,
#     'exchange': 'NMS',
#     'averageAnalystRating': '2.7 - Hold',
#     'fiftyTwoWeekLow': 3.9869,
#     'fiftyTwoWeekHigh': 12.65,
#     'shortName': 'Novavax, Inc.',
#     'firstTradeDateMilliseconds': 818173800000,
#     'priceHint': 4,
#     'preMarketChange': 0.029999733,
#     'preMarketChangePercent': 0.7407341,
#     'preMarketTime': 1705924222,
#     'preMarketPrice': 4.08,
#     'regularMarketChange': -0.059999943,
#     'regularMarketTime': 1705698000,
#     'regularMarketPrice': 4.05,
#     'regularMarketDayHigh': 4.115,
#     'regularMarketDayRange': '3.9869 - 4.115',
#     'regularMarketDayLow': 3.9869,
#     'regularMarketVolume': 5745481,
#     'regularMarketPreviousClose': 4.11,
#     'bid': 0.0,
#     'ask': 0.0,
#     'bidSize': 29,
#     'askSize': 40,
#     'market': 'us_market',
#     'messageBoardId': 'finmb_350381',
#     'fullExchangeName': 'NasdaqGS',
#     'longName': 'Novavax, Inc.',
#     'financialCurrency': 'USD',
#     'regularMarketOpen': 4.11,
#     'averageDailyVolume3Month': 7407201,
#     'averageDailyVolume10Day': 8155140,
#     'fiftyTwoWeekLowChange': 0.0631001,
#     'fiftyTwoWeekLowChangePercent': 0.015826857,
#     'fiftyTwoWeekRange': '3.9869 - 12.65',
#     'fiftyTwoWeekHighChange': -8.599999,
#     'fiftyTwoWeekHighChangePercent': -0.6798419,
#     'fiftyTwoWeekChangePercent': -66.02349,
#     'dividendDate': 1557446400,
#     'earningsTimestamp': 1699536600,
#     'earningsTimestampStart': 1708945140,
#     'earningsTimestampEnd': 1709294400,
#     'trailingAnnualDividendRate': 0.0,
#     'trailingAnnualDividendYield': 0.0,
#     'marketState': 'PRE',
#     'epsTrailingTwelveMonths': -6.23,
#     'epsForward': -0.72,
#     'epsCurrentYear': -4.28,
#     'priceEpsCurrentYear': -0.9462617,
#     'sharesOutstanding': 118790000,
#     'bookValue': -5.713,
#     'fiftyDayAverage': 5.3606,
#     'fiftyDayAverageChange': -1.3105998,
#     'fiftyDayAverageChangePercent': -0.24448752,
#     'twoHundredDayAverage': 7.14965,
#     'twoHundredDayAverageChange': -3.09965,
#     'twoHundredDayAverageChangePercent': -0.43353868,
#     'marketCap': 481099520,
#     'forwardPE': -5.625,
#     'priceToBook': -0.7089096,
#     'sourceInterval': 15,
#     'exchangeDataDelayedBy': 0,
#     'exchangeTimezoneName': 'America/New_York',
#     'exchangeTimezoneShortName': 'EST',
#     'gmtOffSetMilliseconds': -18000000,
#     'esgPopulated': False,
#     'tradeable': False,
#     'cryptoTradeable': False,
#     'displayName': 'Novavax',
#     'symbol': 'NVAX'},
#    {'language': 'en-US',
#     'region': 'US',
#     'quoteType': 'EQUITY',
#     'typeDisp': 'Equity',
#     'quoteSourceName': 'Nasdaq Real Time Price',
#     'triggerable': False,
#     'customPriceAlertConfidence': 'LOW',
#     'lastCloseTevEbitLtm': -0.399891,
#     'lastClosePriceToNNWCPerShare': -1.9455704892241308,
#     'currency': 'USD',
#     'regularMarketChangePercent': -15.355807,
#     'exchange': 'NCM',
#     'averageAnalystRating': '2.5 - Buy',
#     'fiftyTwoWeekLow': 1.9,
#     'fiftyTwoWeekHigh': 38.6,
#     'shortName': 'Cingulate Inc.',
#     'firstTradeDateMilliseconds': 1638973800000,
#     'priceHint': 4,
#     'preMarketChange': 0.07999992,
#     'preMarketChangePercent': 1.7699099,
#     'preMarketTime': 1705924800,
#     'preMarketPrice': 4.6,
#     'regularMarketChange': -0.8200002,
#     'regularMarketTime': 1705698000,
#     'regularMarketPrice': 4.52,
#     'regularMarketDayHigh': 5.225,
#     'regularMarketDayRange': '4.5 - 5.225',
#     'regularMarketDayLow': 4.5,
#     'regularMarketVolume': 100638,
#     'regularMarketPreviousClose': 5.34,
#     'bid': 4.55,
#     'ask': 6.21,
#     'bidSize': 9,
#     'askSize': 9,
#     'market': 'us_market',
#     'messageBoardId': 'finmb_1674914781',
#     'fullExchangeName': 'NasdaqCM',
#     'longName': 'Cingulate Inc.',
#     'financialCurrency': 'USD',
#     'regularMarketOpen': 5.11,
#     'averageDailyVolume3Month': 1515880,
#     'averageDailyVolume10Day': 237380,
#     'fiftyTwoWeekLowChange': 2.62,
#     'fiftyTwoWeekLowChangePercent': 1.3789474,
#     'fiftyTwoWeekRange': '1.9 - 38.6',
#     'fiftyTwoWeekHighChange': -34.079998,
#     'fiftyTwoWeekHighChangePercent': -0.88290155,
#     'fiftyTwoWeekChangePercent': -77.4,
#     'trailingAnnualDividendRate': 0.0,
#     'trailingAnnualDividendYield': 0.0,
#     'marketState': 'PRE',
#     'epsTrailingTwelveMonths': -31.2,
#     'epsForward': -11.55,
#     'epsCurrentYear': -153.86,
#     'priceEpsCurrentYear': -0.029377356,
#     'sharesOutstanding': 1450170,
#     'bookValue': -0.111,
#     'fiftyDayAverage': 5.47648,
#     'fiftyDayAverageChange': -0.95648,
#     'fiftyDayAverageChangePercent': -0.17465234,
#     'twoHundredDayAverage': 13.03382,
#     'twoHundredDayAverageChange': -8.513821,
#     'twoHundredDayAverageChangePercent': -0.6532099,
#     'marketCap': 6554768,
#     'forwardPE': -0.39134198,
#     'priceToBook': -40.72072,
#     'sourceInterval': 15,
#     'exchangeDataDelayedBy': 0,
#     'exchangeTimezoneName': 'America/New_York',
#     'exchangeTimezoneShortName': 'EST',
#     'gmtOffSetMilliseconds': -18000000,
#     'ipoExpectedDate': '2021-12-08',
#     'esgPopulated': False,
#     'tradeable': False,
#     'cryptoTradeable': False,
#     'displayName': 'Cingulate',
#     'symbol': 'CING'},
#    {'language': 'en-US',
#     'region': 'US',
#     'quoteType': 'EQUITY',
#     'typeDisp': 'Equity',
#     'quoteSourceName': 'Nasdaq Real Time Price',
#     'triggerable': True,
#     'customPriceAlertConfidence': 'HIGH',
#     'lastCloseTevEbitLtm': -5.737243,
#     'lastClosePriceToNNWCPerShare': -0.5670050264730819,
#     'currency': 'USD',
#     'regularMarketChangePercent': -0.9472218,
#     'exchange': 'NMS',
#     'averageAnalystRating': '3.6 - Underperform',
#     'fiftyTwoWeekLow': 5.58,
#     'fiftyTwoWeekHigh': 22.87,
#     'shortName': 'Beyond Meat, Inc.',
#     'firstTradeDateMilliseconds': 1556803800000,
#     'priceHint': 2,
#     'preMarketChange': -0.010000229,
#     'preMarketChangePercent': -0.13661514,
#     'preMarketTime': 1705924800,
#     'preMarketPrice': 7.31,
#     'regularMarketChange': -0.069999695,
#     'regularMarketTime': 1705698001,
#     'regularMarketPrice': 7.32,
#     'regularMarketDayHigh': 7.485,
#     'regularMarketDayRange': '7.29 - 7.485',
#     'regularMarketDayLow': 7.29,
#     'regularMarketVolume': 2073096,
#     'regularMarketPreviousClose': 7.39,
#     'bid': 7.33,
#     'ask': 7.45,
#     'bidSize': 11,
#     'askSize': 8,
#     'market': 'us_market',
#     'messageBoardId': 'finmb_222996066',
#     'fullExchangeName': 'NasdaqGS',
#     'longName': 'Beyond Meat, Inc.',
#     'financialCurrency': 'USD',
#     'regularMarketOpen': 7.35,
#     'averageDailyVolume3Month': 3034483,
#     'averageDailyVolume10Day': 2078830,
#     'fiftyTwoWeekLowChange': 1.7400002,
#     'fiftyTwoWeekLowChangePercent': 0.31182802,
#     'fiftyTwoWeekRange': '5.58 - 22.87',
#     'fiftyTwoWeekHighChange': -15.550001,
#     'fiftyTwoWeekHighChangePercent': -0.6799301,
#     'fiftyTwoWeekChangePercent': -56.50624,
#     'earningsTimestamp': 1699480800,
#     'earningsTimestampStart': 1708513140,
#     'earningsTimestampEnd': 1708948800,
#     'trailingAnnualDividendRate': 0.0,
#     'trailingAnnualDividendYield': 0.0,
#     'marketState': 'PRE',
#     'epsTrailingTwelveMonths': -3.89,
#     'epsForward': -3.01,
#     'epsCurrentYear': -3.75,
#     'priceEpsCurrentYear': -1.952,
#     'sharesOutstanding': 64540900,
#     'bookValue': -5.63,
#     'fiftyDayAverage': 8.0916,
#     'fiftyDayAverageChange': -0.77160025,
#     'fiftyDayAverageChangePercent': -0.09535818,
#     'twoHundredDayAverage': 10.952,
#     'twoHundredDayAverageChange': -3.6319995,
#     'twoHundredDayAverageChangePercent': -0.3316289,
#     'marketCap': 472439392,
#     'forwardPE': -2.4318938,
#     'priceToBook': -1.3001776,
#     'sourceInterval': 15,
#     'exchangeDataDelayedBy': 0,
#     'exchangeTimezoneName': 'America/New_York',
#     'exchangeTimezoneShortName': 'EST',
#     'gmtOffSetMilliseconds': -18000000,
#     'esgPopulated': False,
#     'tradeable': False,
#     'cryptoTradeable': False,
#     'displayName': 'Beyond Meat',
#     'symbol': 'BYND'},
#    {'language': 'en-US',
#     'region': 'US',
#     'quoteType': 'EQUITY',
#     'typeDisp': 'Equity',
#     'quoteSourceName': 'Nasdaq Real Time Price',
#     'triggerable': False,
#     'customPriceAlertConfidence': 'LOW',
#     'lastClosePriceToNNWCPerShare': -0.1143864168015788,
#     'currency': 'USD',
#     'regularMarketChangePercent': -5.9207478,
#     'exchange': 'NGM',
#     'fiftyTwoWeekLow': 16.65,
#     'fiftyTwoWeekHigh': 60.72,
#     'shortName': 'B. Riley Financial, Inc.',
#     'firstTradeDateMilliseconds': 1187011800000,
#     'priceHint': 2,
#     'preMarketChange': -2.6900005,
#     'preMarketChangePercent': -13.330032,
#     'preMarketTime': 1705925088,
#     'preMarketPrice': 17.49,
#     'regularMarketChange': -1.2700005,
#     'regularMarketTime': 1705698000,
#     'regularMarketPrice': 20.18,
#     'regularMarketDayHigh': 21.83,
#     'regularMarketDayRange': '19.77 - 21.83',
#     'regularMarketDayLow': 19.77,
#     'regularMarketVolume': 1511894,
#     'regularMarketPreviousClose': 21.45,
#     'bid': 0.0,
#     'ask': 0.0,
#     'bidSize': 30,
#     'askSize': 10,
#     'market': 'us_market',
#     'messageBoardId': 'finmb_4439094',
#     'fullExchangeName': 'NasdaqGM',
#     'longName': 'B. Riley Financial, Inc.',
#     'financialCurrency': 'USD',
#     'regularMarketOpen': 21.4,
#     'averageDailyVolume3Month': 1388352,
#     'averageDailyVolume10Day': 867280,
#     'fiftyTwoWeekLowChange': 3.5300007,
#     'fiftyTwoWeekLowChangePercent': 0.21201205,
#     'fiftyTwoWeekRange': '16.65 - 60.72',
#     'fiftyTwoWeekHighChange': -40.54,
#     'fiftyTwoWeekHighChangePercent': -0.6676548,
#     'fiftyTwoWeekChangePercent': -52.640224,
#     'dividendDate': 1701302400,
#     'earningsTimestamp': 1699450200,
#     'earningsTimestampStart': 1708426740,
#     'earningsTimestampEnd': 1708948800,
#     'trailingAnnualDividendRate': 4.0,
#     'dividendRate': 4.0,
#     'trailingAnnualDividendYield': 0.18648018,
#     'dividendYield': 19.78,
#     'marketState': 'PRE',
#     'epsTrailingTwelveMonths': -2.65,
#     'sharesOutstanding': 30582900,
#     'bookValue': 13.53,
#     'fiftyDayAverage': 22.5286,
#     'fiftyDayAverageChange': -2.3486004,
#     'fiftyDayAverageChangePercent': -0.10424972,
#     'twoHundredDayAverage': 36.95125,
#     'twoHundredDayAverageChange': -16.771248,
#     'twoHundredDayAverageChangePercent': -0.453875,
#     'marketCap': 617162944,
#     'priceToBook': 1.4915004,
#     'sourceInterval': 15,
#     'exchangeDataDelayedBy': 0,
#     'exchangeTimezoneName': 'America/New_York',
#     'exchangeTimezoneShortName': 'EST',
#     'gmtOffSetMilliseconds': -18000000,
#     'esgPopulated': False,
#     'tradeable': False,
#     'cryptoTradeable': False,
#     'displayName': 'B. Riley Financial',
#     'symbol': 'RILY'},
#    {'language': 'en-US',
#     'region': 'US',
#     'quoteType': 'EQUITY',
#     'typeDisp': 'Equity',
#     'quoteSourceName': 'Nasdaq Real Time Price',
#     'triggerable': True,
#     'customPriceAlertConfidence': 'HIGH',
#     'lastCloseTevEbitLtm': -15.68701,
#     'lastClosePriceToNNWCPerShare': -6.579306658366245,
#     'currency': 'USD',
#     'regularMarketChangePercent': 4.9775186,
#     'exchange': 'NMS',
#     'averageAnalystRating': '3.7 - Underperform',
#     'fiftyTwoWeekLow': 11.93,
#     'fiftyTwoWeekHigh': 72.58,
#     'shortName': 'Upstart Holdings, Inc.',
#     'firstTradeDateMilliseconds': 1608129000000,
#     'priceHint': 2,
#     'preMarketChange': 0.76000214,
#     'preMarketChangePercent': 2.3248765,
#     'preMarketTime': 1705924885,
#     'preMarketPrice': 33.45,
#     'regularMarketChange': 1.5499992,
#     'regularMarketTime': 1705698000,
#     'regularMarketPrice': 32.69,
#     'regularMarketDayHigh': 33.0358,
#     'regularMarketDayRange': '30.75 - 33.0358',
#     'regularMarketDayLow': 30.75,
#     'regularMarketVolume': 8299677,
#     'regularMarketPreviousClose': 31.14,
#     'bid': 0.0,
#     'ask': 0.0,
#     'bidSize': 12,
#     'askSize': 13,
#     'market': 'us_market',
#     'messageBoardId': 'finmb_306975137',
#     'fullExchangeName': 'NasdaqGS',
#     'longName': 'Upstart Holdings, Inc.',
#     'financialCurrency': 'USD',
#     'regularMarketOpen': 31.052,
#     'averageDailyVolume3Month': 9431049,
#     'averageDailyVolume10Day': 8370870,
#     'fiftyTwoWeekLowChange': 20.759998,
#     'fiftyTwoWeekLowChangePercent': 1.7401507,
#     'fiftyTwoWeekRange': '11.93 - 72.58',
#     'fiftyTwoWeekHighChange': -39.890003,
#     'fiftyTwoWeekHighChangePercent': -0.5496005,
#     'fiftyTwoWeekChangePercent': 76.03662,
#     'earningsTimestamp': 1699392600,
#     'earningsTimestampStart': 1707735540,
#     'earningsTimestampEnd': 1708084800,
#     'trailingAnnualDividendRate': 0.0,
#     'trailingAnnualDividendYield': 0.0,
#     'marketState': 'PRE',
#     'epsTrailingTwelveMonths': -3.05,
#     'epsForward': 0.1,
#     'epsCurrentYear': -0.58,
#     'priceEpsCurrentYear': -56.36207,
#     'sharesOutstanding': 85057296,
#     'bookValue': 7.536,
#     'fiftyDayAverage': 33.3048,
#     'fiftyDayAverageChange': -0.6147995,
#     'fiftyDayAverageChangePercent': -0.018459788,
#     'twoHundredDayAverage': 31.4856,
#     'twoHundredDayAverageChange': 1.2043991,
#     'twoHundredDayAverageChangePercent': 0.03825238,
#     'marketCap': 2780523008,
#     'forwardPE': 326.9,
#     'priceToBook': 4.337845,
#     'sourceInterval': 15,
#     'exchangeDataDelayedBy': 0,
#     'exchangeTimezoneName': 'America/New_York',
#     'exchangeTimezoneShortName': 'EST',
#     'gmtOffSetMilliseconds': -18000000,
#     'ipoExpectedDate': '2020-12-16',
#     'esgPopulated': False,
#     'tradeable': False,
#     'cryptoTradeable': False,
#     'displayName': 'Upstart',
#     'symbol': 'UPST'},
#    {'language': 'en-US',
#     'region': 'US',
#     'quoteType': 'EQUITY',
#     'typeDisp': 'Equity',
#     'quoteSourceName': 'Nasdaq Real Time Price',
#     'triggerable': False,
#     'customPriceAlertConfidence': 'LOW',
#     'lastCloseTevEbitLtm': -20.010384,
#     'lastClosePriceToNNWCPerShare': -1.0608958437547182,
#     'currency': 'USD',
#     'regularMarketChangePercent': 4.855271,
#     'exchange': 'NYQ',
#     'averageAnalystRating': '3.2 - Hold',
#     'fiftyTwoWeekLow': 6.08,
#     'fiftyTwoWeekHigh': 62.59,
#     'shortName': 'Carvana Co.',
#     'firstTradeDateMilliseconds': 1493386200000,
#     'priceHint': 2,
#     'preMarketChange': 0.6800003,
#     'preMarketChangePercent': 1.513803,
#     'preMarketTime': 1705925155,
#     'preMarketPrice': 45.6,
#     'regularMarketChange': 2.079998,
#     'regularMarketTime': 1705698002,
#     'regularMarketPrice': 44.92,
#     'regularMarketDayHigh': 45.43,
#     'regularMarketDayRange': '41.91 - 45.43',
#     'regularMarketDayLow': 41.91,
#     'regularMarketVolume': 6995104,
#     'regularMarketPreviousClose': 42.84,
#     'bid': 45.28,
#     'ask': 45.38,
#     'bidSize': 10,
#     'askSize': 10,
#     'market': 'us_market',
#     'messageBoardId': 'finmb_424080297',
#     'fullExchangeName': 'NYSE',
#     'longName': 'Carvana Co.',
#     'financialCurrency': 'USD',
#     'regularMarketOpen': 43.1,
#     'averageDailyVolume3Month': 8709255,
#     'averageDailyVolume10Day': 5131710,
#     'fiftyTwoWeekLowChange': 38.839996,
#     'fiftyTwoWeekLowChangePercent': 6.3881574,
#     'fiftyTwoWeekRange': '6.08 - 62.59',
#     'fiftyTwoWeekHighChange': -17.670002,
#     'fiftyTwoWeekHighChangePercent': -0.2823135,
#     'fiftyTwoWeekChangePercent': 525.6268,
#     'earningsTimestamp': 1698960600,
#     'earningsTimestampStart': 1708513140,
#     'earningsTimestampEnd': 1708948800,
#     'trailingAnnualDividendRate': 0.0,
#     'trailingAnnualDividendYield': 0.0,
#     'marketState': 'PRE',
#     'epsTrailingTwelveMonths': -4.184,
#     'epsForward': -3.5,
#     'epsCurrentYear': 0.02,
#     'priceEpsCurrentYear': 2246.0,
#     'sharesOutstanding': 84500000,
#     'bookValue': 2.974,
#     'fiftyDayAverage': 41.7826,
#     'fiftyDayAverageChange': 3.1373978,
#     'fiftyDayAverageChangePercent': 0.07508862,
#     'twoHundredDayAverage': 32.56125,
#     'twoHundredDayAverageChange': 12.358749,
#     'twoHundredDayAverageChangePercent': 0.3795539,
#     'marketCap': 7977791488,
#     'forwardPE': -12.834285,
#     'priceToBook': 15.104237,
#     'sourceInterval': 15,
#     'exchangeDataDelayedBy': 0,
#     'exchangeTimezoneName': 'America/New_York',
#     'exchangeTimezoneShortName': 'EST',
#     'gmtOffSetMilliseconds': -18000000,
#     'esgPopulated': False,
#     'tradeable': False,
#     'cryptoTradeable': False,
#     'displayName': 'Carvana',
#     'symbol': 'CVNA'},
#    {'language': 'en-US',
#     'region': 'US',
#     'quoteType': 'EQUITY',
#     'typeDisp': 'Equity',
#     'quoteSourceName': 'Nasdaq Real Time Price',
#     'triggerable': False,
#     'customPriceAlertConfidence': 'LOW',
#     'lastCloseTevEbitLtm': -9.339438,
#     'lastClosePriceToNNWCPerShare': 8.762734069462935,
#     'currency': 'USD',
#     'regularMarketChangePercent': 1.813269,
#     'exchange': 'NCM',
#     'averageAnalystRating': '2.0 - Buy',
#     'fiftyTwoWeekLow': 12.32,
#     'fiftyTwoWeekHigh': 38.53,
#     'shortName': 'Cassava Sciences, Inc.',
#     'firstTradeDateMilliseconds': 963581400000,
#     'priceHint': 2,
#     'preMarketChange': -0.22999954,
#     'preMarketChangePercent': -0.87154055,
#     'preMarketTime': 1705923545,
#     'preMarketPrice': 26.16,
#     'regularMarketChange': 0.4699993,
#     'regularMarketTime': 1705698000,
#     'regularMarketPrice': 26.39,
#     'regularMarketDayHigh': 26.47,
#     'regularMarketDayRange': '25.24 - 26.47',
#     'regularMarketDayLow': 25.24,
#     'regularMarketVolume': 710451,
#     'regularMarketPreviousClose': 25.92,
#     'bid': 0.0,
#     'ask': 0.0,
#     'bidSize': 12,
#     'askSize': 12,
#     'market': 'us_market',
#     'messageBoardId': 'finmb_107567',
#     'fullExchangeName': 'NasdaqCM',
#     'longName': 'Cassava Sciences, Inc.',
#     'financialCurrency': 'USD',
#     'regularMarketOpen': 25.9,
#     'averageDailyVolume3Month': 1331093,
#     'averageDailyVolume10Day': 996740,
#     'fiftyTwoWeekLowChange': 14.07,
#     'fiftyTwoWeekLowChangePercent': 1.1420455,
#     'fiftyTwoWeekRange': '12.32 - 38.53',
#     'fiftyTwoWeekHighChange': -12.139999,
#     'fiftyTwoWeekHighChangePercent': -0.31507915,
#     'fiftyTwoWeekChangePercent': -27.579582,
#     'dividendDate': 1494374400,
#     'earningsTimestamp': 1699365660,
#     'earningsTimestampStart': 1708945140,
#     'earningsTimestampEnd': 1709294400,
#     'trailingAnnualDividendRate': 0.0,
#     'trailingAnnualDividendYield': 0.0,
#     'marketState': 'PRE',
#     'epsTrailingTwelveMonths': -2.29,
#     'epsForward': -0.54,
#     'epsCurrentYear': -2.34,
#     'priceEpsCurrentYear': -11.277778,
#     'sharesOutstanding': 42236900,
#     'bookValue': 3.682,
#     'fiftyDayAverage': 23.7582,
#     'fiftyDayAverageChange': 2.6317997,
#     'fiftyDayAverageChangePercent': 0.110774375,
#     'twoHundredDayAverage': 21.8517,
#     'twoHundredDayAverageChange': 4.5382996,
#     'twoHundredDayAverageChangePercent': 0.20768633,
#     'marketCap': 1114631808,
#     'forwardPE': -48.87037,
#     'priceToBook': 7.1673,
#     'sourceInterval': 15,
#     'exchangeDataDelayedBy': 0,
#     'exchangeTimezoneName': 'America/New_York',
#     'exchangeTimezoneShortName': 'EST',
#     'gmtOffSetMilliseconds': -18000000,
#     'esgPopulated': False,
#     'tradeable': False,
#     'cryptoTradeable': False,
#     'displayName': 'Cassava Sciences',
#     'symbol': 'SAVA'},
#    {'language': 'en-US',
#     'region': 'US',
#     'quoteType': 'EQUITY',
#     'typeDisp': 'Equity',
#     'quoteSourceName': 'Nasdaq Real Time Price',
#     'triggerable': False,
#     'customPriceAlertConfidence': 'LOW',
#     'lastCloseTevEbitLtm': -7.410216,
#     'lastClosePriceToNNWCPerShare': 4.063079520841141,
#     'currency': 'USD',
#     'regularMarketChangePercent': 3.117207,
#     'exchange': 'NYQ',
#     'averageAnalystRating': '3.0 - Hold',
#     'fiftyTwoWeekLow': 13.45,
#     'fiftyTwoWeekHigh': 48.87,
#     'shortName': 'C3.ai, Inc.',
#     'firstTradeDateMilliseconds': 1607524200000,
#     'priceHint': 2,
#     'preMarketChange': 0.27000046,
#     'preMarketChangePercent': 1.0882727,
#     'preMarketTime': 1705925005,
#     'preMarketPrice': 25.08,
#     'regularMarketChange': 0.75,
#     'regularMarketTime': 1705698002,
#     'regularMarketPrice': 24.81,
#     'regularMarketDayHigh': 24.83,
#     'regularMarketDayRange': '23.73 - 24.83',
#     'regularMarketDayLow': 23.73,
#     'regularMarketVolume': 7137399,
#     'regularMarketPreviousClose': 24.06,
#     'bid': 25.1,
#     'ask': 25.21,
#     'bidSize': 10,
#     'askSize': 9,
#     'market': 'us_market',
#     'messageBoardId': 'finmb_24249083',
#     'fullExchangeName': 'NYSE',
#     'longName': 'C3.ai, Inc.',
#     'financialCurrency': 'USD',
#     'regularMarketOpen': 24.35,
#     'averageDailyVolume3Month': 8975906,
#     'averageDailyVolume10Day': 6918410,
#     'fiftyTwoWeekLowChange': 11.36,
#     'fiftyTwoWeekLowChangePercent': 0.8446097,
#     'fiftyTwoWeekRange': '13.45 - 48.87',
#     'fiftyTwoWeekHighChange': -24.06,
#     'fiftyTwoWeekHighChangePercent': -0.4923266,
#     'fiftyTwoWeekChangePercent': 70.63273,
#     'earningsTimestamp': 1701900000,
#     'earningsTimestampStart': 1709204340,
#     'earningsTimestampEnd': 1709553600,
#     'trailingAnnualDividendRate': 0.0,
#     'trailingAnnualDividendYield': 0.0,
#     'marketState': 'PRE',
#     'epsTrailingTwelveMonths': -2.3,
#     'epsForward': -0.27,
#     'epsCurrentYear': -0.73,
#     'priceEpsCurrentYear': -33.9863,
#     'sharesOutstanding': 116365000,
#     'bookValue': 7.603,
#     'fiftyDayAverage': 28.4914,
#     'fiftyDayAverageChange': -3.6814003,
#     'fiftyDayAverageChangePercent': -0.12921093,
#     'twoHundredDayAverage': 29.4879,
#     'twoHundredDayAverageChange': -4.6779003,
#     'twoHundredDayAverageChangePercent': -0.15863796,
#     'marketCap': 2973850624,
#     'forwardPE': -91.888885,
#     'priceToBook': 3.2631855,
#     'sourceInterval': 15,
#     'exchangeDataDelayedBy': 0,
#     'exchangeTimezoneName': 'America/New_York',
#     'exchangeTimezoneShortName': 'EST',
#     'gmtOffSetMilliseconds': -18000000,
#     'ipoExpectedDate': '2020-12-09',
#     'esgPopulated': False,
#     'tradeable': False,
#     'cryptoTradeable': False,
#     'displayName': 'C3.ai',
#     'symbol': 'AI'},
#    {'language': 'en-US',
#     'region': 'US',
#     'quoteType': 'EQUITY',
#     'typeDisp': 'Equity',
#     'quoteSourceName': 'Nasdaq Real Time Price',
#     'triggerable': False,
#     'customPriceAlertConfidence': 'LOW',
#     'lastCloseTevEbitLtm': -55.053563,
#     'lastClosePriceToNNWCPerShare': -0.22951456351538524,
#     'currency': 'USD',
#     'regularMarketChangePercent': -0.8928587,
#     'exchange': 'NYQ',
#     'averageAnalystRating': '2.0 - Buy',
#     'fiftyTwoWeekLow': 7.615,
#     'fiftyTwoWeekHigh': 24.56,
#     'shortName': 'Sunnova Energy International In',
#     'firstTradeDateMilliseconds': 1564061400000,
#     'priceHint': 2,
#     'preMarketChange': 0.25,
#     'preMarketChangePercent': 2.5025024,
#     'preMarketTime': 1705925020,
#     'preMarketPrice': 10.24,
#     'regularMarketChange': -0.09000015,
#     'regularMarketTime': 1705698002,
#     'regularMarketPrice': 9.99,
#     'regularMarketDayHigh': 10.075,
#     'regularMarketDayRange': '9.29 - 10.075',
#     'regularMarketDayLow': 9.29,
#     'regularMarketVolume': 8074904,
#     'regularMarketPreviousClose': 10.08,
#     'bid': 0.0,
#     'ask': 0.0,
#     'bidSize': 13,
#     'askSize': 9,
#     'market': 'us_market',
#     'messageBoardId': 'finmb_234681245',
#     'fullExchangeName': 'NYSE',
#     'longName': 'Sunnova Energy International Inc.',
#     'financialCurrency': 'USD',
#     'regularMarketOpen': 10.01,
#     'averageDailyVolume3Month': 5874427,
#     'averageDailyVolume10Day': 5323890,
#     'fiftyTwoWeekLowChange': 2.375,
#     'fiftyTwoWeekLowChangePercent': 0.31188446,
#     'fiftyTwoWeekRange': '7.615 - 24.56',
#     'fiftyTwoWeekHighChange': -14.57,
#     'fiftyTwoWeekHighChangePercent': -0.59324104,
#     'fiftyTwoWeekChangePercent': -51.315792,
#     'earningsTimestamp': 1698321600,
#     'earningsTimestampStart': 1708462800,
#     'earningsTimestampEnd': 1708981200,
#     'trailingAnnualDividendRate': 0.0,
#     'trailingAnnualDividendYield': 0.0,
#     'marketState': 'PRE',
#     'epsTrailingTwelveMonths': -2.15,
#     'epsForward': -1.65,
#     'epsCurrentYear': -2.07,
#     'priceEpsCurrentYear': -4.826087,
#     'sharesOutstanding': 122416000,
#     'bookValue': 12.727,
#     'fiftyDayAverage': 12.0668,
#     'fiftyDayAverageChange': -2.0768003,
#     'fiftyDayAverageChangePercent': -0.17210862,
#     'twoHundredDayAverage': 14.34835,
#     'twoHundredDayAverageChange': -4.35835,
#     'twoHundredDayAverageChangePercent': -0.3037527,
#     'marketCap': 1222935808,
#     'forwardPE': -6.0545454,
#     'priceToBook': 0.78494537,
#     'sourceInterval': 15,
#     'exchangeDataDelayedBy': 0,
#     'exchangeTimezoneName': 'America/New_York',
#     'exchangeTimezoneShortName': 'EST',
#     'gmtOffSetMilliseconds': -18000000,
#     'esgPopulated': False,
#     'tradeable': False,
#     'cryptoTradeable': False,
#     'displayName': 'Sunnova Energy',
#     'symbol': 'NOVA'},
#    {'language': 'en-US',
#     'region': 'US',
#     'quoteType': 'EQUITY',
#     'typeDisp': 'Equity',
#     'quoteSourceName': 'Nasdaq Real Time Price',
#     'triggerable': False,
#     'customPriceAlertConfidence': 'LOW',
#     'lastCloseTevEbitLtm': -1.062593,
#     'lastClosePriceToNNWCPerShare': -7.8318389617465884,
#     'currency': 'USD',
#     'regularMarketChangePercent': 11.607142,
#     'exchange': 'NCM',
#     'averageAnalystRating': '2.6 - Hold',
#     'fiftyTwoWeekLow': 2.18,
#     'fiftyTwoWeekHigh': 15.4,
#     'shortName': 'Blink Charging Co. Common Stock',
#     'firstTradeDateMilliseconds': 1261405800000,
#     'priceHint': 4,
#     'preMarketChange': 0.049999952,
#     'preMarketChangePercent': 1.9999981,
#     'preMarketTime': 1705924810,
#     'preMarketPrice': 2.55,
#     'regularMarketChange': 0.26,
#     'regularMarketTime': 1705698000,
#     'regularMarketPrice': 2.5,
#     'regularMarketDayHigh': 2.515,
#     'regularMarketDayRange': '2.19 - 2.515',
#     'regularMarketDayLow': 2.19,
#     'regularMarketVolume': 7811791,
#     'regularMarketPreviousClose': 2.24,
#     'bid': 2.54,
#     'ask': 0.0,
#     'bidSize': 362,
#     'askSize': 14,
#     'market': 'us_market',
#     'messageBoardId': 'finmb_83115902',
#     'fullExchangeName': 'NasdaqCM',
#     'longName': 'Blink Charging Co.',
#     'financialCurrency': 'USD',
#     'regularMarketOpen': 2.26,
#     'averageDailyVolume3Month': 7418339,
#     'averageDailyVolume10Day': 8672380,
#     'fiftyTwoWeekLowChange': 0.31999993,
#     'fiftyTwoWeekLowChangePercent': 0.14678895,
#     'fiftyTwoWeekRange': '2.18 - 15.4',
#     'fiftyTwoWeekHighChange': -12.9,
#     'fiftyTwoWeekHighChangePercent': -0.83766234,
#     'fiftyTwoWeekChangePercent': -82.33216,
#     'dividendDate': 1503964800,
#     'earningsTimestamp': 1699565400,
#     'earningsTimestampStart': 1708981200,
#     'earningsTimestampEnd': 1709326800,
#     'trailingAnnualDividendRate': 0.0,
#     'trailingAnnualDividendYield': 0.0,
#     'marketState': 'PRE',
#     'epsTrailingTwelveMonths': -3.58,
#     'epsForward': -0.94,
#     'epsCurrentYear': -3.26,
#     'priceEpsCurrentYear': -0.76687115,
#     'sharesOutstanding': 67408000,
#     'bookValue': 3.275,
#     'fiftyDayAverage': 3.1719,
#     'fiftyDayAverageChange': -0.67190003,
#     'fiftyDayAverageChangePercent': -0.21182889,
#     'twoHundredDayAverage': 4.84835,
#     'twoHundredDayAverageChange': -2.34835,
#     'twoHundredDayAverageChangePercent': -0.48436067,
#     'marketCap': 168520000,
#     'forwardPE': -2.6595745,
#     'priceToBook': 0.7633588,
#     'sourceInterval': 15,
#     'exchangeDataDelayedBy': 0,
#     'exchangeTimezoneName': 'America/New_York',
#     'exchangeTimezoneShortName': 'EST',
#     'gmtOffSetMilliseconds': -18000000,
#     'esgPopulated': False,
#     'tradeable': False,
#     'cryptoTradeable': False,
#     'displayName': 'Blink Charging',
#     'symbol': 'BLNK'},
#    {'language': 'en-US',
#     'region': 'US',
#     'quoteType': 'EQUITY',
#     'typeDisp': 'Equity',
#     'quoteSourceName': 'Delayed Quote',
#     'triggerable': False,
#     'customPriceAlertConfidence': 'LOW',
#     'lastClosePriceToNNWCPerShare': -0.25515099901928395,
#     'currency': 'USD',
#     'regularMarketChangePercent': 2.2346416,
#     'exchange': 'NYQ',
#     'averageAnalystRating': '2.7 - Hold',
#     'fiftyTwoWeekLow': 10.1,
#     'fiftyTwoWeekHigh': 17.74,
#     'shortName': 'Arbor Realty Trust',
#     'firstTradeDateMilliseconds': 1081344600000,
#     'priceHint': 2,
#     'preMarketChange': 0.0,
#     'preMarketChangePercent': 0.0,
#     'preMarketTime': 1705923051,
#     'preMarketPrice': 14.64,
#     'regularMarketChange': 0.32000065,
#     'regularMarketTime': 1705698002,
#     'regularMarketPrice': 14.64,
#     'regularMarketDayHigh': 14.65,
#     'regularMarketDayRange': '14.045 - 14.65',
#     'regularMarketDayLow': 14.045,
#     'regularMarketVolume': 3232760,
#     'regularMarketPreviousClose': 14.32,
#     'bid': 0.0,
#     'ask': 15.0,
#     'bidSize': 30,
#     'askSize': 32,
#     'market': 'us_market',
#     'messageBoardId': 'finmb_6207506',
#     'fullExchangeName': 'NYSE',
#     'longName': 'Arbor Realty Trust, Inc.',
#     'financialCurrency': 'USD',
#     'regularMarketOpen': 14.44,
#     'averageDailyVolume3Month': 5064700,
#     'averageDailyVolume10Day': 3769250,
#     'fiftyTwoWeekLowChange': 4.54,
#     'fiftyTwoWeekLowChangePercent': 0.44950494,
#     'fiftyTwoWeekRange': '10.1 - 17.74',
#     'fiftyTwoWeekHighChange': -3.0999994,
#     'fiftyTwoWeekHighChangePercent': -0.1747463,
#     'fiftyTwoWeekChangePercent': 1.6666651,
#     'dividendDate': 1701302400,
#     'earningsTimestamp': 1698415200,
#     'earningsTimestampStart': 1708003800,
#     'earningsTimestampEnd': 1708349400,
#     'trailingAnnualDividendRate': 1.68,
#     'trailingPE': 8.271187,
#     'dividendRate': 1.72,
#     'trailingAnnualDividendYield': 0.11731844,
#     'dividendYield': 11.75,
#     'marketState': 'PRE',
#     'epsTrailingTwelveMonths': 1.77,
#     'epsForward': 1.86,
#     'epsCurrentYear': 2.18,
#     'priceEpsCurrentYear': 6.715596,
#     'sharesOutstanding': 188502000,
#     'bookValue': 13.109,
#     'fiftyDayAverage': 14.0574,
#     'fiftyDayAverageChange': 0.5826006,
#     'fiftyDayAverageChangePercent': 0.041444406,
#     'twoHundredDayAverage': 14.0511,
#     'twoHundredDayAverageChange': 0.58890057,
#     'twoHundredDayAverageChangePercent': 0.04191135,
#     'marketCap': 2759669248,
#     'forwardPE': 7.870968,
#     'priceToBook': 1.11679,
#     'sourceInterval': 15,
#     'exchangeDataDelayedBy': 0,
#     'exchangeTimezoneName': 'America/New_York',
#     'exchangeTimezoneShortName': 'EST',
#     'gmtOffSetMilliseconds': -18000000,
#     'esgPopulated': False,
#     'tradeable': False,
#     'cryptoTradeable': False,
#     'displayName': 'Arbor Realty Trust',
#     'symbol': 'ABR'},
#    {'language': 'en-US',
#     'region': 'US',
#     'quoteType': 'EQUITY',
#     'typeDisp': 'Equity',
#     'quoteSourceName': 'Delayed Quote',
#     'triggerable': False,
#     'customPriceAlertConfidence': 'LOW',
#     'lastCloseTevEbitLtm': -24.352692,
#     'lastClosePriceToNNWCPerShare': -209.89393271724174,
#     'currency': 'USD',
#     'regularMarketChangePercent': 0.84558654,
#     'exchange': 'NGM',
#     'averageAnalystRating': '2.6 - Hold',
#     'fiftyTwoWeekLow': 18.45,
#     'fiftyTwoWeekHigh': 69.15,
#     'shortName': 'Trupanion, Inc.',
#     'firstTradeDateMilliseconds': 1405690200000,
#     'priceHint': 2,
#     'regularMarketChange': 0.22999954,
#     'regularMarketTime': 1705698000,
#     'regularMarketPrice': 27.43,
#     'regularMarketDayHigh': 27.9,
#     'regularMarketDayRange': '26.39 - 27.9',
#     'regularMarketDayLow': 26.39,
#     'regularMarketVolume': 750575,
#     'regularMarketPreviousClose': 27.2,
#     'bid': 18.9,
#     'ask': 29.95,
#     'bidSize': 11,
#     'askSize': 8,
#     'market': 'us_market',
#     'messageBoardId': 'finmb_40255796',
#     'fullExchangeName': 'NasdaqGM',
#     'longName': 'Trupanion, Inc.',
#     'financialCurrency': 'USD',
#     'regularMarketOpen': 27.48,
#     'averageDailyVolume3Month': 751929,
#     'averageDailyVolume10Day': 504620,
#     'fiftyTwoWeekLowChange': 8.98,
#     'fiftyTwoWeekLowChangePercent': 0.48672083,
#     'fiftyTwoWeekRange': '18.45 - 69.15',
#     'fiftyTwoWeekHighChange': -41.72,
#     'fiftyTwoWeekHighChangePercent': -0.6033261,
#     'fiftyTwoWeekChangePercent': -50.92145,
#     'earningsTimestamp': 1698957000,
#     'earningsTimestampStart': 1707821940,
#     'earningsTimestampEnd': 1708344000,
#     'trailingAnnualDividendRate': 0.0,
#     'trailingAnnualDividendYield': 0.0,
#     'marketState': 'PRE',
#     'epsTrailingTwelveMonths': -1.26,
#     'epsForward': -0.4,
#     'epsCurrentYear': -1.21,
#     'priceEpsCurrentYear': -22.66942,
#     'sharesOutstanding': 41545200,
#     'bookValue': 6.954,
#     'fiftyDayAverage': 28.181,
#     'fiftyDayAverageChange': -0.75099945,
#     'fiftyDayAverageChangePercent': -0.026649142,
#     'twoHundredDayAverage': 27.6789,
#     'twoHundredDayAverageChange': -0.24889946,
#     'twoHundredDayAverageChangePercent': -0.00899239,
#     'marketCap': 1139584896,
#     'forwardPE': -68.575,
#     'priceToBook': 3.9444923,
#     'sourceInterval': 15,
#     'exchangeDataDelayedBy': 0,
#     'exchangeTimezoneName': 'America/New_York',
#     'exchangeTimezoneShortName': 'EST',
#     'gmtOffSetMilliseconds': -18000000,
#     'esgPopulated': False,
#     'tradeable': False,
#     'cryptoTradeable': False,
#     'displayName': 'Trupanion',
#     'symbol': 'TRUP'},
#    {'language': 'en-US',
#     'region': 'US',
#     'quoteType': 'EQUITY',
#     'typeDisp': 'Equity',
#     'quoteSourceName': 'Nasdaq Real Time Price',
#     'triggerable': False,
#     'customPriceAlertConfidence': 'LOW',
#     'lastCloseTevEbitLtm': 0.103707,
#     'lastClosePriceToNNWCPerShare': 3.4591374387053335,
#     'currency': 'USD',
#     'regularMarketChangePercent': -12.917588,
#     'exchange': 'NCM',
#     'fiftyTwoWeekLow': 6.95,
#     'fiftyTwoWeekHigh': 10125.0,
#     'shortName': 'Mullen Automotive, Inc.',
#     'firstTradeDateMilliseconds': 1224250200000,
#     'priceHint': 2,
#     'preMarketChange': -0.11000013,
#     'preMarketChangePercent': -1.4066513,
#     'preMarketTime': 1705924957,
#     'preMarketPrice': 7.71,
#     'regularMarketChange': -1.1599994,
#     'regularMarketTime': 1705698001,
#     'regularMarketPrice': 7.82,
#     'regularMarketDayHigh': 9.05,
#     'regularMarketDayRange': '7.58 - 9.05',
#     'regularMarketDayLow': 7.58,
#     'regularMarketVolume': 1508405,
#     'regularMarketPreviousClose': 8.98,
#     'bid': 0.0,
#     'ask': 0.0,
#     'bidSize': 10,
#     'askSize': 8,
#     'market': 'us_market',
#     'messageBoardId': 'finmb_302789480',
#     'fullExchangeName': 'NasdaqCM',
#     'longName': 'Mullen Automotive, Inc.',
#     'financialCurrency': 'USD',
#     'regularMarketOpen': 9.04,
#     'averageDailyVolume3Month': 1428187,
#     'averageDailyVolume10Day': 802930,
#     'fiftyTwoWeekLowChange': 0.87000036,
#     'fiftyTwoWeekLowChangePercent': 0.12517992,
#     'fiftyTwoWeekRange': '6.95 - 10125.0',
#     'fiftyTwoWeekHighChange': -10117.18,
#     'fiftyTwoWeekHighChangePercent': -0.99922764,
#     'fiftyTwoWeekChangePercent': -99.88415,
#     'dividendDate': 1507161600,
#     'earningsTimestamp': 1705442779,
#     'earningsTimestampStart': 1707774060,
#     'earningsTimestampEnd': 1708119660,
#     'trailingAnnualDividendRate': 0.0,
#     'trailingAnnualDividendYield': 0.0,
#     'marketState': 'PRE',
#     'epsTrailingTwelveMonths': -1574.14,
#     'epsForward': 0.75,
#     'epsCurrentYear': 4275.0,
#     'priceEpsCurrentYear': 0.0018292398,
#     'sharesOutstanding': 5884690,
#     'bookValue': 72.762,
#     'fiftyDayAverage': 14.9734,
#     'fiftyDayAverageChange': -7.1534,
#     'fiftyDayAverageChangePercent': -0.47774053,
#     'twoHundredDayAverage': 383.75336,
#     'twoHundredDayAverageChange': -375.93335,
#     'twoHundredDayAverageChangePercent': -0.9796223,
#     'marketCap': 46018276,
#     'forwardPE': 10.426667,
#     'priceToBook': 0.10747368,
#     'sourceInterval': 15,
#     'exchangeDataDelayedBy': 0,
#     'exchangeTimezoneName': 'America/New_York',
#     'exchangeTimezoneShortName': 'EST',
#     'gmtOffSetMilliseconds': -18000000,
#     'prevName': 'Net Element, Inc.',
#     'nameChangeDate': '2024-01-21',
#     'esgPopulated': False,
#     'tradeable': False,
#     'cryptoTradeable': False,
#     'displayName': 'Mullen Automotive',
#     'symbol': 'MULN'},
#    {'language': 'en-US',
#     'region': 'US',
#     'quoteType': 'EQUITY',
#     'typeDisp': 'Equity',
#     'quoteSourceName': 'Delayed Quote',
#     'triggerable': True,
#     'customPriceAlertConfidence': 'HIGH',
#     'lastCloseTevEbitLtm': -2.693921,
#     'lastClosePriceToNNWCPerShare': 2.627501504497309,
#     'currency': 'USD',
#     'regularMarketChangePercent': -1.83357,
#     'exchange': 'NMS',
#     'averageAnalystRating': '1.9 - Buy',
#     'fiftyTwoWeekLow': 8.04,
#     'fiftyTwoWeekHigh': 43.69,
#     'shortName': 'Biomea Fusion, Inc.',
#     'firstTradeDateMilliseconds': 1618579800000,
#     'priceHint': 2,
#     'preMarketChange': -0.22000027,
#     'preMarketChangePercent': -1.5804616,
#     'preMarketTime': 1705915688,
#     'preMarketPrice': 13.7,
#     'regularMarketChange': -0.26000023,
#     'regularMarketTime': 1705698001,
#     'regularMarketPrice': 13.92,
#     'regularMarketDayHigh': 14.3,
#     'regularMarketDayRange': '13.4407 - 14.3',
#     'regularMarketDayLow': 13.4407,
#     'regularMarketVolume': 746078,
#     'regularMarketPreviousClose': 14.18,
#     'bid': 13.66,
#     'ask': 15.3,
#     'bidSize': 10,
#     'askSize': 9,
#     'market': 'us_market',
#     'messageBoardId': 'finmb_695310535',
#     'fullExchangeName': 'NasdaqGS',
#     'longName': 'Biomea Fusion, Inc.',
#     'financialCurrency': 'USD',
#     'regularMarketOpen': 14.05,
#     'averageDailyVolume3Month': 1286906,
#     'averageDailyVolume10Day': 801470,
#     'fiftyTwoWeekLowChange': 5.88,
#     'fiftyTwoWeekLowChangePercent': 0.7313433,
#     'fiftyTwoWeekRange': '8.04 - 43.69',
#     'fiftyTwoWeekHighChange': -29.769999,
#     'fiftyTwoWeekHighChangePercent': -0.6813916,
#     'fiftyTwoWeekChangePercent': 51.799347,
#     'earningsTimestamp': 1698696080,
#     'earningsTimestampStart': 1698696080,
#     'earningsTimestampEnd': 1698696080,
#     'trailingAnnualDividendRate': 0.0,
#     'trailingAnnualDividendYield': 0.0,
#     'marketState': 'PRE',
#     'epsTrailingTwelveMonths': -3.33,
#     'epsForward': -3.6,
#     'epsCurrentYear': -3.33,
#     'priceEpsCurrentYear': -4.18018,
#     'sharesOutstanding': 35705800,
#     'bookValue': 5.592,
#     'fiftyDayAverage': 13.4185,
#     'fiftyDayAverageChange': 0.5015001,
#     'fiftyDayAverageChangePercent': 0.037373785,
#     'twoHundredDayAverage': 20.05105,
#     'twoHundredDayAverageChange': -6.13105,
#     'twoHundredDayAverageChangePercent': -0.305772,
#     'marketCap': 497024736,
#     'forwardPE': -3.8666668,
#     'priceToBook': 2.4892704,
#     'sourceInterval': 15,
#     'exchangeDataDelayedBy': 0,
#     'exchangeTimezoneName': 'America/New_York',
#     'exchangeTimezoneShortName': 'EST',
#     'gmtOffSetMilliseconds': -18000000,
#     'ipoExpectedDate': '2021-04-16',
#     'esgPopulated': False,
#     'tradeable': False,
#     'cryptoTradeable': False,
#     'displayName': 'Biomea Fusion',
#     'symbol': 'BMEA'},
#    {'language': 'en-US',
#     'region': 'US',
#     'quoteType': 'EQUITY',
#     'typeDisp': 'Equity',
#     'quoteSourceName': 'Delayed Quote',
#     'triggerable': False,
#     'customPriceAlertConfidence': 'LOW',
#     'lastClosePriceToNNWCPerShare': -0.128512483473642,
#     'currency': 'USD',
#     'regularMarketChangePercent': 3.8626676,
#     'exchange': 'PNK',
#     'averageAnalystRating': '1.0 - Strong Buy',
#     'fiftyTwoWeekLow': 0.49,
#     'fiftyTwoWeekHigh': 32.87,
#     'shortName': 'Ebix, Inc.',
#     'firstTradeDateMilliseconds': 552144600000,
#     'priceHint': 4,
#     'regularMarketChange': 0.09000015,
#     'regularMarketTime': 1705697999,
#     'regularMarketPrice': 2.42,
#     'regularMarketDayHigh': 2.5,
#     'regularMarketDayRange': '2.3 - 2.5',
#     'regularMarketDayLow': 2.3,
#     'regularMarketVolume': 398497,
#     'regularMarketPreviousClose': 2.33,
#     'market': 'us_market',
#     'messageBoardId': 'finmb_266099',
#     'fullExchangeName': 'Other OTC',
#     'longName': 'Ebix, Inc.',
#     'financialCurrency': 'USD',
#     'regularMarketOpen': 2.4,
#     'averageDailyVolume3Month': 3220301,
#     'averageDailyVolume10Day': 629820,
#     'fiftyTwoWeekLowChange': 1.9300001,
#     'fiftyTwoWeekLowChangePercent': 3.9387755,
#     'fiftyTwoWeekRange': '0.49 - 32.87',
#     'fiftyTwoWeekHighChange': -30.449999,
#     'fiftyTwoWeekHighChangePercent': -0.92637664,
#     'fiftyTwoWeekChangePercent': -87.74683,
#     'dividendDate': 1671148800,
#     'earningsTimestamp': 1699965733,
#     'earningsTimestampStart': 1710333000,
#     'earningsTimestampEnd': 1710765000,
#     'dividendRate': 0.3,
#     'dividendYield': 6.94,
#     'marketState': 'PRE',
#     'epsForward': 1.17,
#     'epsCurrentYear': 0.55,
#     'priceEpsCurrentYear': 4.4,
#     'sharesOutstanding': 30901400,
#     'fiftyDayAverage': 3.4086,
#     'fiftyDayAverageChange': -0.9886,
#     'fiftyDayAverageChangePercent': -0.2900311,
#     'twoHundredDayAverage': 13.56525,
#     'twoHundredDayAverageChange': -11.14525,
#     'twoHundredDayAverageChangePercent': -0.821603,
#     'marketCap': 74781392,
#     'forwardPE': 2.0683763,
#     'sourceInterval': 15,
#     'exchangeDataDelayedBy': 0,
#     'exchangeTimezoneName': 'America/New_York',
#     'exchangeTimezoneShortName': 'EST',
#     'gmtOffSetMilliseconds': -18000000,
#     'esgPopulated': False,
#     'tradeable': False,
#     'cryptoTradeable': False,
#     'displayName': 'Ebix',
#     'symbol': 'EBIXQ'},
#    {'language': 'en-US',
#     'region': 'US',
#     'quoteType': 'EQUITY',
#     'typeDisp': 'Equity',
#     'quoteSourceName': 'Delayed Quote',
#     'triggerable': False,
#     'customPriceAlertConfidence': 'LOW',
#     'lastCloseTevEbitLtm': -5.229081,
#     'lastClosePriceToNNWCPerShare': -1.1223613696726713,
#     'currency': 'USD',
#     'regularMarketChangePercent': 2.181816,
# ...
#     'regularMarketDayHigh': 2.29,
#     'regularMarketDayRange': '2.145 - 2.29',
#     'regularMarketDayLow': 2.145,
#     'regularMarketVolume': 1792944,
#     'regularMarketPreviousClose': 2.25,
#     'bid': 0.0,
#     'ask': 0.0,
#     'bidSize': 18,
#     'askSize': 40,
#     'market': 'us_market',
#     'messageBoardId': 'finmb_127282',
#     'fullExchangeName': 'NasdaqGM',
#     'longName': 'MicroVision, Inc.',
#     'financialCurrency': 'USD',
#     'regularMarketOpen': 2.27,
#     'averageDailyVolume3Month': 2276954,
#     'averageDailyVolume10Day': 1771900,
#     'fiftyTwoWeekLowChange': 0.46500003,
#     'fiftyTwoWeekLowChangePercent': 0.2554945,
#     'fiftyTwoWeekRange': '1.82 - 8.2',
#     'fiftyTwoWeekHighChange': -5.915,
#     'fiftyTwoWeekHighChangePercent': -0.7213415,
#     'fiftyTwoWeekChangePercent': -8.76494,
#     'earningsTimestamp': 1699513219,
#     'earningsTimestampStart': 1708981200,
#     'earningsTimestampEnd': 1709326800,
#     'trailingAnnualDividendRate': 0.0,
#     'trailingAnnualDividendYield': 0.0,
#     'marketState': 'PRE',
#     'epsTrailingTwelveMonths': -0.43,
#     'epsForward': -0.36,
#     'epsCurrentYear': -0.38,
#     'priceEpsCurrentYear': -6.0131583,
#     'sharesOutstanding': 189986000,
#     'bookValue': 0.518,
#     'fiftyDayAverage': 2.4656,
#     'fiftyDayAverageChange': -0.18059993,
#     'fiftyDayAverageChangePercent': -0.073247865,
#     'twoHundredDayAverage': 2.91575,
#     'twoHundredDayAverageChange': -0.63074994,
#     'twoHundredDayAverageChangePercent': -0.2163251,
#     'marketCap': 434118016,
#     'forwardPE': -6.3472223,
#     'priceToBook': 4.411197,
#     'sourceInterval': 15,
#     'exchangeDataDelayedBy': 0,
#     'exchangeTimezoneName': 'America/New_York',
#     'exchangeTimezoneShortName': 'EST',
#     'gmtOffSetMilliseconds': -18000000,
#     'esgPopulated': False,
#     'tradeable': False,
#     'cryptoTradeable': False,
#     'displayName': 'MicroVision',
#     'symbol': 'MVIS'},
#    {'language': 'en-US',
#     'region': 'US',
#     'quoteType': 'EQUITY',
#     'typeDisp': 'Equity',
#     'quoteSourceName': 'Delayed Quote',
#     'triggerable': False,
#     'customPriceAlertConfidence': 'LOW',
#     'lastCloseTevEbitLtm': -14.169075,
#     'lastClosePriceToNNWCPerShare': -0.09088457006710308,
#     'currency': 'USD',
#     'regularMarketChangePercent': -17.527386,
#     'exchange': 'ASE',
#     'averageAnalystRating': '3.0 - Hold',
#     'fiftyTwoWeekLow': 1.06,
#     'fiftyTwoWeekHigh': 42.9,
#     'shortName': 'Polished Inc.',
#     'firstTradeDateMilliseconds': 1596202200000,
#     'priceHint': 2,
#     'preMarketChange': 0.11000013,
#     'preMarketChangePercent': 2.087289,
#     'preMarketTime': 1705924114,
#     'preMarketPrice': 5.38,
#     'regularMarketChange': -1.1199999,
#     'regularMarketTime': 1705698000,
#     'regularMarketPrice': 5.27,
#     'regularMarketDayHigh': 6.6499,
#     'regularMarketDayRange': '5.2002 - 6.6499',
#     'regularMarketDayLow': 5.2002,
#     'regularMarketVolume': 179937,
#     'regularMarketPreviousClose': 6.39,
#     'bid': 5.4,
#     'ask': 5.57,
#     'bidSize': 14,
#     'askSize': 8,
#     'market': 'us_market',
#     'messageBoardId': 'finmb_609619170',
#     'fullExchangeName': 'NYSE American',
#     'longName': 'Polished.com Inc.',
#     'financialCurrency': 'USD',
#     'regularMarketOpen': 6.25,
#     'averageDailyVolume3Month': 3203257,
#     'averageDailyVolume10Day': 735310,
#     'fiftyTwoWeekLowChange': 4.21,
#     'fiftyTwoWeekLowChangePercent': 3.9716983,
#     'fiftyTwoWeekRange': '1.06 - 42.9',
#     'fiftyTwoWeekHighChange': -37.63,
#     'fiftyTwoWeekHighChangePercent': -0.8771562,
#     'fiftyTwoWeekChangePercent': -79.923805,
#     'earningsTimestamp': 1700518500,
#     'earningsTimestampStart': 1700518500,
#     'earningsTimestampEnd': 1700518500,
#     'trailingAnnualDividendRate': 0.0,
#     'trailingAnnualDividendYield': 0.0,
#     'marketState': 'PRE',
#     'epsTrailingTwelveMonths': -61.25,
#     'epsForward': 0.01,
#     'sharesOutstanding': 2109350,
#     'bookValue': 25.773,
#     'fiftyDayAverage': 3.71194,
#     'fiftyDayAverageChange': 1.5580599,
#     'fiftyDayAverageChangePercent': 0.41974276,
#     'twoHundredDayAverage': 12.73131,
#     'twoHundredDayAverageChange': -7.46131,
#     'twoHundredDayAverageChangePercent': -0.58605987,
#     'marketCap': 11116274,
#     'forwardPE': 527.0,
#     'priceToBook': 0.20447755,
#     'sourceInterval': 15,
#     'exchangeDataDelayedBy': 0,
#     'exchangeTimezoneName': 'America/New_York',
#     'exchangeTimezoneShortName': 'EST',
#     'gmtOffSetMilliseconds': -18000000,
#     'prevName': '1847 Goedeker Inc.',
#     'nameChangeDate': '2024-01-21',
#     'esgPopulated': False,
#     'tradeable': False,
#     'cryptoTradeable': False,
#     'symbol': 'POL'},
#    {'language': 'en-US',
#     'region': 'US',
#     'quoteType': 'EQUITY',
#     'typeDisp': 'Equity',
#     'quoteSourceName': 'Nasdaq Real Time Price',
#     'triggerable': False,
#     'customPriceAlertConfidence': 'LOW',
#     'lastCloseTevEbitLtm': 76.903854,
#     'lastClosePriceToNNWCPerShare': -0.28941807750527077,
#     'currency': 'USD',
#     'regularMarketChangePercent': 1.2606729,
#     'exchange': 'NYQ',
#     'averageAnalystRating': '2.9 - Hold',
#     'fiftyTwoWeekLow': 17.68,
#     'fiftyTwoWeekHigh': 35.77,
#     'shortName': "Kohl's Corporation",
#     'firstTradeDateMilliseconds': 706282200000,
#     'priceHint': 2,
#     'preMarketChange': 0.25,
#     'preMarketChangePercent': 1.004016,
#     'preMarketTime': 1705924800,
#     'preMarketPrice': 25.15,
#     'regularMarketChange': 0.30999947,
#     'regularMarketTime': 1705698002,
#     'regularMarketPrice': 24.9,
#     'regularMarketDayHigh': 24.9,
#     'regularMarketDayRange': '24.03 - 24.9',
#     'regularMarketDayLow': 24.03,
#     'regularMarketVolume': 4350403,
#     'regularMarketPreviousClose': 24.59,
#     'bid': 24.95,
#     'ask': 25.1,
#     'bidSize': 9,
#     'askSize': 8,
#     'market': 'us_market',
#     'messageBoardId': 'finmb_61243',
#     'fullExchangeName': 'NYSE',
#     'longName': "Kohl's Corporation",
#     'financialCurrency': 'USD',
#     'regularMarketOpen': 24.67,
#     'averageDailyVolume3Month': 5726977,
#     'averageDailyVolume10Day': 5332720,
#     'fiftyTwoWeekLowChange': 7.2199993,
#     'fiftyTwoWeekLowChangePercent': 0.408371,
#     'fiftyTwoWeekRange': '17.68 - 35.77',
#     'fiftyTwoWeekHighChange': -10.870001,
#     'fiftyTwoWeekHighChangePercent': -0.30388597,
#     'fiftyTwoWeekChangePercent': -23.78329,
#     'dividendDate': 1703030400,
#     'earningsTimestamp': 1700575200,
#     'earningsTimestampStart': 1709127000,
#     'earningsTimestampEnd': 1709559000,
#     'trailingAnnualDividendRate': 2.0,
#     'dividendRate': 2.0,
#     'trailingAnnualDividendYield': 0.081333876,
#     'dividendYield': 8.03,
#     'marketState': 'PRE',
#     'epsTrailingTwelveMonths': -1.01,
#     'epsForward': 2.65,
#     'epsCurrentYear': 2.46,
#     'priceEpsCurrentYear': 10.121951,
#     'sharesOutstanding': 110712000,
#     'bookValue': 33.793,
#     'fiftyDayAverage': 25.5412,
#     'fiftyDayAverageChange': -0.641201,
#     'fiftyDayAverageChangePercent': -0.025104577,
#     'twoHundredDayAverage': 23.638,
#     'twoHundredDayAverageChange': 1.2619991,
#     'twoHundredDayAverageChangePercent': 0.053388573,
#     'marketCap': 2756728832,
#     'forwardPE': 9.396226,
#     'priceToBook': 0.736839,
#     'sourceInterval': 15,
#     'exchangeDataDelayedBy': 0,
#     'exchangeTimezoneName': 'America/New_York',
#     'exchangeTimezoneShortName': 'EST',
#     'gmtOffSetMilliseconds': -18000000,
#     'esgPopulated': False,
#     'tradeable': False,
#     'cryptoTradeable': False,
#     'displayName': "Kohl's",
#     'symbol': 'KSS'},
#    {'language': 'en-US',
#     'region': 'US',
#     'quoteType': 'EQUITY',
#     'typeDisp': 'Equity',
#     'quoteSourceName': 'Nasdaq Real Time Price',
#     'triggerable': False,
#     'customPriceAlertConfidence': 'LOW',
#     'lastCloseTevEbitLtm': 20.394501,
#     'lastClosePriceToNNWCPerShare': -0.30899832575468794,
#     'currency': 'USD',
#     'regularMarketChangePercent': 0.0,
#     'exchange': 'NYQ',
#     'averageAnalystRating': '3.1 - Hold',
#     'fiftyTwoWeekLow': 2.92,
#     'fiftyTwoWeekHigh': 14.0,
#     'shortName': 'Medical Properties Trust, Inc.',
#     'firstTradeDateMilliseconds': 1120829400000,
#     'priceHint': 4,
#     'preMarketChange': 0.00999999,
#     'preMarketChangePercent': 0.3257326,
#     'preMarketTime': 1705925012,
#     'preMarketPrice': 3.08,
#     'regularMarketChange': 0.0,
#     'regularMarketTime': 1705698002,
#     'regularMarketPrice': 3.07,
#     'regularMarketDayHigh': 3.095,
#     'regularMarketDayRange': '2.92 - 3.095',
#     'regularMarketDayLow': 2.92,
#     'regularMarketVolume': 24195645,
#     'regularMarketPreviousClose': 3.07,
#     'bid': 3.07,
#     'ask': 3.1,
#     'bidSize': 418,
#     'askSize': 418,
#     'market': 'us_market',
#     'messageBoardId': 'finmb_12344550',
#     'fullExchangeName': 'NYSE',
#     'longName': 'Medical Properties Trust, Inc.',
#     'financialCurrency': 'USD',
#     'regularMarketOpen': 3.07,
#     'averageDailyVolume3Month': 20392093,
#     'averageDailyVolume10Day': 43980890,
#     'fiftyTwoWeekLowChange': 0.14999986,
#     'fiftyTwoWeekLowChangePercent': 0.051369812,
#     'fiftyTwoWeekRange': '2.92 - 14.0',
#     'fiftyTwoWeekHighChange': -10.93,
#     'fiftyTwoWeekHighChangePercent': -0.78071433,
#     'fiftyTwoWeekChangePercent': -77.72134,
#     'dividendDate': 1704931200,
#     'earningsTimestamp': 1698332400,
#     'earningsTimestampStart': 1708522200,
#     'earningsTimestampEnd': 1708954200,
#     'trailingAnnualDividendRate': 1.02,
#     'dividendRate': 0.88,
#     'trailingAnnualDividendYield': 0.33224756,
#     'dividendYield': 28.66,
#     'marketState': 'PRE',
#     'epsTrailingTwelveMonths': -0.06,
#     'epsForward': 0.84,
#     'epsCurrentYear': 0.45,
#     'priceEpsCurrentYear': 6.822222,
#     'sharesOutstanding': 599000000,
#     'bookValue': 13.843,
#     'fiftyDayAverage': 4.5422,
#     'fiftyDayAverageChange': -1.4722002,
#     'fiftyDayAverageChangePercent': -0.32411608,
#     'twoHundredDayAverage': 6.89025,
#     'twoHundredDayAverageChange': -3.8202503,
#     'twoHundredDayAverageChangePercent': -0.5544429,
#     'marketCap': 1838929920,
#     'forwardPE': 3.654762,
#     'priceToBook': 0.22177273,
#     'sourceInterval': 15,
#     'exchangeDataDelayedBy': 0,
#     'exchangeTimezoneName': 'America/New_York',
#     'exchangeTimezoneShortName': 'EST',
#     'gmtOffSetMilliseconds': -18000000,
#     'esgPopulated': False,
#     'tradeable': False,
#     'cryptoTradeable': False,
#     'displayName': 'Medical Properties Trust',
#     'symbol': 'MPW'},
#    {'language': 'en-US',
#     'region': 'US',
#     'quoteType': 'EQUITY',
#     'typeDisp': 'Equity',
#     'quoteSourceName': 'Nasdaq Real Time Price',
#     'triggerable': True,
#     'customPriceAlertConfidence': 'HIGH',
#     'lastCloseTevEbitLtm': -4.367956,
#     'lastClosePriceToNNWCPerShare': -0.3050319286306184,
#     'currency': 'USD',
#     'regularMarketChangePercent': -9.090912,
#     'exchange': 'NMS',
#     'averageAnalystRating': '2.7 - Hold',
#     'fiftyTwoWeekLow': 1.38,
#     'fiftyTwoWeekHigh': 37.34,
#     'shortName': 'Cutera, Inc.',
#     'firstTradeDateMilliseconds': 1080743400000,
#     'priceHint': 4,
#     'preMarketChange': 0.029999971,
#     'preMarketChangePercent': 1.090908,
#     'preMarketTime': 1705924993,
#     'preMarketPrice': 2.78,
#     'regularMarketChange': -0.2750001,
#     'regularMarketTime': 1705698001,
#     'regularMarketPrice': 2.75,
#     'regularMarketDayHigh': 3.04,
#     'regularMarketDayRange': '2.56 - 3.04',
#     'regularMarketDayLow': 2.56,
#     'regularMarketVolume': 2503044,
#     'regularMarketPreviousClose': 3.025,
#     'bid': 2.7,
#     'ask': 2.83,
#     'bidSize': 29,
#     'askSize': 14,
#     'market': 'us_market',
#     'messageBoardId': 'finmb_99457',
#     'fullExchangeName': 'NasdaqGS',
#     'longName': 'Cutera, Inc.',
#     'financialCurrency': 'USD',
#     'regularMarketOpen': 3.04,
#     'averageDailyVolume3Month': 1921380,
#     'averageDailyVolume10Day': 5555240,
#     'fiftyTwoWeekLowChange': 1.37,
#     'fiftyTwoWeekLowChangePercent': 0.9927536,
#     'fiftyTwoWeekRange': '1.38 - 37.34',
#     'fiftyTwoWeekHighChange': -34.59,
#     'fiftyTwoWeekHighChangePercent': -0.92635244,
#     'fiftyTwoWeekChangePercent': -92.01742,
#     'earningsTimestamp': 1704805201,
#     'earningsTimestampStart': 1708945140,
#     'earningsTimestampEnd': 1709294400,
#     'trailingAnnualDividendRate': 0.0,
#     'trailingAnnualDividendYield': 0.0,
#     'marketState': 'PRE',
#     'epsTrailingTwelveMonths': -3.86,
#     'epsForward': -2.93,
#     'epsCurrentYear': -3.46,
#     'priceEpsCurrentYear': -0.79479766,
#     'sharesOutstanding': 20015100,
#     'bookValue': -3.474,
#     'fiftyDayAverage': 2.722,
#     'fiftyDayAverageChange': 0.028000116,
#     'fiftyDayAverageChangePercent': 0.010286598,
#     'twoHundredDayAverage': 10.9356,
#     'twoHundredDayAverageChange': -8.1856,
#     'twoHundredDayAverageChangePercent': -0.74852777,
#     'marketCap': 55041524,
#     'forwardPE': -0.9385665,
#     'priceToBook': -0.7915947,
#     'sourceInterval': 15,
#     'exchangeDataDelayedBy': 0,
#     'exchangeTimezoneName': 'America/New_York',
#     'exchangeTimezoneShortName': 'EST',
#     'gmtOffSetMilliseconds': -18000000,
#     'esgPopulated': False,
#     'tradeable': False,
#     'cryptoTradeable': False,
#     'displayName': 'Cutera',
#     'symbol': 'CUTR'},
#    {'language': 'en-US',
#     'region': 'US',
#     'quoteType': 'EQUITY',
#     'typeDisp': 'Equity',
#     'quoteSourceName': 'Delayed Quote',
#     'triggerable': True,
#     'customPriceAlertConfidence': 'HIGH',
#     'lastCloseTevEbitLtm': -6.516071,
#     'lastClosePriceToNNWCPerShare': 3.562278503127384,
#     'currency': 'USD',
#     'regularMarketChangePercent': 0.6655567,
#     'exchange': 'NMS',
#     'averageAnalystRating': '2.0 - Buy',
#     'fiftyTwoWeekLow': 4.9,
#     'fiftyTwoWeekHigh': 11.925,
#     'shortName': 'Anavex Life Sciences Corp.',
#     'firstTradeDateMilliseconds': 1154525400000,
#     'priceHint': 2,
#     'preMarketChange': 0.049999714,
#     'preMarketChangePercent': 0.8264415,
#     'preMarketTime': 1705923260,
#     'preMarketPrice': 6.1,
#     'regularMarketChange': 0.03999996,
#     'regularMarketTime': 1705698000,
#     'regularMarketPrice': 6.05,
#     'regularMarketDayHigh': 6.1,
#     'regularMarketDayRange': '5.8002 - 6.1',
#     'regularMarketDayLow': 5.8002,
#     'regularMarketVolume': 1209988,
#     'regularMarketPreviousClose': 6.01,
#     'bid': 6.0,
#     'ask': 6.23,
#     'bidSize': 8,
#     'askSize': 12,
#     'market': 'us_market',
#     'messageBoardId': 'finmb_13580387',
#     'fullExchangeName': 'NasdaqGS',
#     'longName': 'Anavex Life Sciences Corp.',
#     'financialCurrency': 'USD',
#     'regularMarketOpen': 6.01,
#     'averageDailyVolume3Month': 1449721,
#     'averageDailyVolume10Day': 1370230,
#     'fiftyTwoWeekLowChange': 1.1500001,
#     'fiftyTwoWeekLowChangePercent': 0.2346939,
#     'fiftyTwoWeekRange': '4.9 - 11.925',
#     'fiftyTwoWeekHighChange': -5.875,
#     'fiftyTwoWeekHighChangePercent': -0.49266246,
#     'fiftyTwoWeekChangePercent': -42.215855,
#     'earningsTimestamp': 1701091800,
#     'earningsTimestampStart': 1707139800,
#     'earningsTimestampEnd': 1707485400,
#     'trailingAnnualDividendRate': 0.0,
#     'trailingAnnualDividendYield': 0.0,
#     'marketState': 'PRE',
#     'epsTrailingTwelveMonths': -0.6,
#     'epsForward': -0.31,
#     'epsCurrentYear': -0.54,
#     'priceEpsCurrentYear': -11.203704,
#     'sharesOutstanding': 82086496,
#     'bookValue': 1.729,
#     'fiftyDayAverage': 7.2471,
#     'fiftyDayAverageChange': -1.1970997,
#     'fiftyDayAverageChangePercent': -0.16518328,
#     'twoHundredDayAverage': 7.6907,
#     'twoHundredDayAverageChange': -1.6406999,
#     'twoHundredDayAverageChangePercent': -0.21333557,
#     'marketCap': 496623328,
#     'forwardPE': -19.51613,
#     'priceToBook': 3.4991326,
#     'sourceInterval': 15,
#     'exchangeDataDelayedBy': 0,
#     'exchangeTimezoneName': 'America/New_York',
#     'exchangeTimezoneShortName': 'EST',
#     'gmtOffSetMilliseconds': -18000000,
#     'esgPopulated': False,
#     'tradeable': False,
#     'cryptoTradeable': False,
#     'displayName': 'Anavex Life Sciences',
#     'symbol': 'AVXL'}],
#   'useRecords': False,
#   'predefinedScr': True,
#   'versionId': 0,
#   'creationDate': 1615500072941,
#   'lastUpdated': 1615500072941,
#   'isPremium': False,
#   'iconUrl': 'https://s.yimg.com/cv/apiv2/fin/img/assets/predefined_screeners/analytics.png'}}

# %%
select_count = 10
most_actives_dct = s.get_screeners(['most_actives'], int(select_count))

most_watched_tickers_dict = s.get_screeners(['most_watched_tickers'])

# %%
columns = ['symbol', 'averageAnalystRating', 'regularMarketPrice', 'fiftyTwoWeekRange', 'regularMarketVolume',  'averageDailyVolume10Day', 'averageDailyVolume3Month', 'priceToBook', 'marketCap', 'forwardPE', 'priceEpsCurrentYear', 'bookValue',    ]
day_gainers_dict = s.get_screeners(['day_gainers'], int(select_count))
my_data_list = day_gainers_dict['day_gainers']['quotes']

day_gainers_df = pd.DataFrame(my_data_list, columns=columns)
day_gainers_df.set_index(keys=['symbol'], inplace = True)
day_gainers_df
# Out:
#        averageAnalystRating  regularMarketPrice fiftyTwoWeekRange  \
# symbol
# WIT      4.3 - Underperform               6.280       4.32 - 6.39
# UEC               1.9 - Buy               7.770        2.3 - 7.83
# NXE               1.8 - Buy               7.840       3.49 - 7.84
# KBGGY                   NaN              27.300      21.52 - 27.3
# GTBIF             1.7 - Buy              12.550      6.42 - 12.55
# ATZAF                   NaN              26.135    15.0 - 36.8269
# IDYA       1.4 - Strong Buy              39.740     13.29 - 40.14
# RICFY                   NaN              14.035   11.445 - 14.035
# CCJ               1.7 - Buy              49.920     23.69 - 51.22
# BRZE              1.9 - Buy              53.370     25.76 - 58.67
#
#         regularMarketVolume  averageDailyVolume10Day  \
# symbol
# WIT                15253464                  3972470
# UEC                29244922                  8252430
# NXE                17354272                  6579290
# KBGGY                 17700                     2162
# GTBIF                738177                   403870
# ATZAF                107149                    68107
# IDYA                2833861                  1447340
# RICFY                 31973                     4088
# CCJ                17501541                  5807130
# BRZE                1420149                   745040
#
#         averageDailyVolume3Month  priceToBook    marketCap    forwardPE  \
# symbol
# WIT                      1998839     0.046854  32763326464    22.428572
# UEC                      7740191     4.437464   3053454592   777.000000
# NXE                      5570544     6.457990   4105172992   -71.272730
# KBGGY                        318     0.322344   9604384768          NaN
# GTBIF                     361295     1.739914   3223705856    52.291668
# ATZAF                      30102     3.742661   2838940416          NaN
# IDYA                     1053167     4.585737   2742588416   -16.838985
# RICFY                       3756     1.674022  11564517376          NaN
# CCJ                      5129416     3.544196  22164328448    44.571426
# BRZE                      774111    12.082862   5324601856 -2668.500000
#
#         priceEpsCurrentYear  bookValue
# symbol
# WIT               25.120000    134.032
# UEC                     NaN      1.751
# NXE              -52.266666      1.214
# KBGGY                   NaN     84.692
# GTBIF             69.722220      7.213
# ATZAF                   NaN      6.983
# IDYA             -20.806284      8.666
# RICFY                   NaN      8.384
# CCJ               79.238090     14.085
# BRZE            -205.269240      4.417

# %%
#### 'aggressive_small_caps'
aggressive_small_caps_dict = s.get_screeners(['aggressive_small_caps'])
aggressive_small_caps_data_list = aggressive_small_caps_dict['aggressive_small_caps']['quotes']
columns = ['symbol', 'longName', 'quoteType', 'dividendYield', 'yieldTTM', 'annualReturnNavY3', 'annualReturnNavY5', 'fiftyTwoWeekRange', 
           'regularMarketPrice', 'regularMarketDayRange', 'regularMarketVolume',
          'regularMarketOpen', 'averageDailyVolume3Month', 'averageDailyVolume10Day'
          ]
df_aggressive_small_caps = pd.DataFrame(aggressive_small_caps_data_list, columns=columns)
df_aggressive_small_caps.set_index(keys=['symbol'], inplace = True)
df_aggressive_small_caps
# Out:
#                                     longName quoteType  dividendYield  \
# symbol
# BTCM                      BIT Mining Limited    EQUITY            NaN
# TLRY                     Tilray Brands, Inc.    EQUITY            NaN
# BB                        BlackBerry Limited    EQUITY            NaN
# SOS                              SOS Limited    EQUITY            NaN
# HYZN                       Hyzon Motors Inc.    EQUITY            NaN
# SAVE                   Spirit Airlines, Inc.    EQUITY            NaN
# DOLE                                Dole plc    EQUITY           2.66
# CANO                       Cano Health, Inc.    EQUITY            NaN
# CLNE                Clean Energy Fuels Corp.    EQUITY            NaN
# AG               First Majestic Silver Corp.    EQUITY           0.37
# AHT          Ashford Hospitality Trust, Inc.    EQUITY            NaN
# HUYA                               HUYA Inc.    EQUITY            NaN
# MGNI                           Magnite, Inc.    EQUITY            NaN
# EBON       Ebang International Holdings Inc.    EQUITY            NaN
# MUX                       McEwen Mining Inc.    EQUITY            NaN
# LAZR              Luminar Technologies, Inc.    EQUITY            NaN
# BIG                           Big Lots, Inc.    EQUITY            NaN
# AMWL               American Well Corporation    EQUITY            NaN
# KIRK                        Kirkland's, Inc.    EQUITY            NaN
# GEO                      The GEO Group, Inc.    EQUITY            NaN
# JKS             JinkoSolar Holding Co., Ltd.    EQUITY           4.94
# CCO     Clear Channel Outdoor Holdings, Inc.    EQUITY            NaN
# ETWO            E2open Parent Holdings, Inc.    EQUITY            NaN
# DAN                        Dana Incorporated    EQUITY           3.05
# SHCR                         Sharecare, Inc.    EQUITY            NaN
#
#         yieldTTM  annualReturnNavY3  annualReturnNavY5 fiftyTwoWeekRange  \
# symbol
# BTCM         NaN                NaN                NaN        2.0 - 6.95
# TLRY         NaN                NaN                NaN        1.5 - 3.59
# BB           NaN                NaN                NaN       3.19 - 5.75
# SOS          NaN                NaN                NaN         3.1 - 9.5
# HYZN         NaN                NaN                NaN       0.45 - 2.35
# SAVE         NaN                NaN                NaN      8.68 - 20.99
# DOLE         NaN                NaN                NaN     9.98 - 14.005
# CANO         NaN                NaN                NaN       3.2 - 190.0
# CLNE         NaN                NaN                NaN        3.03 - 6.1
# AG           NaN                NaN                NaN       4.38 - 8.78
# AHT          NaN                NaN                NaN        1.5 - 7.52
# HUYA         NaN                NaN                NaN     2.155 - 6.495
# MGNI         NaN                NaN                NaN      6.28 - 15.73
# EBON         NaN                NaN                NaN       5.3 - 18.94
# MUX          NaN                NaN                NaN       5.39 - 10.0
# LAZR         NaN                NaN                NaN       2.3 - 10.55
# BIG          NaN                NaN                NaN      3.47 - 19.97
# AMWL         NaN                NaN                NaN     0.925 - 4.275
# KIRK         NaN                NaN                NaN        1.4 - 4.06
# GEO          NaN                NaN                NaN      6.94 - 12.42
# JKS          NaN                NaN                NaN     25.15 - 60.44
# CCO          NaN                NaN                NaN       0.99 - 2.14
# ETWO         NaN                NaN                NaN      2.15 - 7.205
# DAN          NaN                NaN                NaN      11.1 - 19.75
# SHCR         NaN                NaN                NaN       0.77 - 2.71
#
#         regularMarketPrice regularMarketDayRange  regularMarketVolume  \
# symbol
# BTCM                4.1500           3.93 - 4.73               400175
# TLRY                1.8700           1.84 - 1.97             29131120
# BB                  3.4000           3.39 - 3.48              5437036
# SOS                 3.8700         3.82 - 4.4031               247097
# HYZN                0.6445         0.6445 - 0.71               381932
# SAVE               14.9700        14.755 - 15.55              3135508
# DOLE               12.0200         11.95 - 12.21               379861
# CANO                3.2100            3.2 - 3.66               261229
# CLNE                3.4100         3.36 - 3.4974              1062153
# AG                  5.6000           5.56 - 5.81              9180732
# AHT                 1.5200             1.5 - 1.6               693553
# HUYA                3.4300          3.395 - 3.54              2004416
# MGNI                9.1500         9.15 - 9.4989               912154
# EBON                9.4800      8.8999 - 11.8556               109622
# MUX                 6.7300           6.68 - 6.99               382100
# LAZR                2.5050             2.5 - 2.9             11799983
# BIG                 6.3800         6.35 - 6.9003               829870
# AMWL                1.1000            1.1 - 1.19               919505
# KIRK                2.7600          2.71 - 2.925               218750
# GEO                10.7200          10.69 - 11.1              1182648
# JKS                30.3900         30.14 - 31.69               708116
# CCO                 1.6700           1.65 - 1.76              1519701
# ETWO                3.6300          3.58 - 3.695              1099081
# DAN                13.1100          13.1 - 13.66               552587
# SHCR                1.0300           1.02 - 1.05               380967
#
#         regularMarketOpen  averageDailyVolume3Month  averageDailyVolume10Day
# symbol
# BTCM                4.580                    212339                   321600
# TLRY                1.930                  18518414                 32795940
# BB                  3.390                   5363052                  6262100
# SOS                 4.380                    191549                   284750
# HYZN                0.703                    608068                   455310
# SAVE               15.350                   5057213                  3397910
# DOLE               12.210                    552442                   414100
# CANO                3.570                    292808                   306830
# CLNE                3.420                   1829852                  1299800
# AG                  5.590                   6250008                  6569210
# AHT                 1.590                    534103                   762820
# HUYA                3.520                   1765681                  1497220
# MGNI                9.230                   1043144                   797420
# EBON               11.180                     68911                   103630
# MUX                 6.820                    470313                   334180
# LAZR                2.880                   7600172                  8103500
# BIG                 6.740                   1500529                  1030990
# AMWL                1.170                   2261227                  1254590
# KIRK                2.900                    145155                   114800
# GEO                11.070                   2402039                  2335250
# JKS                31.350                   1078026                   980930
# CCO                 1.720                   3450300                  2110050
# ETWO                3.610                   2080147                  2098960
# DAN                13.660                   1212070                   913230
# SHCR                1.050                    876737                   657630

# %%
#### 'portfolio_anchors_dict'
portfolio_anchors_dict = s.get_screeners(['portfolio_anchors'])
portfolio_anchors_data_list = portfolio_anchors_dict['portfolio_anchors']['quotes']
columns = ['symbol', 'longName', 'quoteType', 'dividendYield', 'yieldTTM', 'annualReturnNavY3', 'annualReturnNavY5', 'fiftyTwoWeekRange', 
           'regularMarketPrice', 'regularMarketDayRange', 'regularMarketVolume',
          'regularMarketOpen', 'averageDailyVolume3Month', 'averageDailyVolume10Day'
          ]
df_portfolio_anchors = pd.DataFrame(portfolio_anchors_data_list, columns=columns)
df_portfolio_anchors.set_index(keys=['symbol'], inplace = True)
df_portfolio_anchors
# Out:
#                                         longName   quoteType  dividendYield  \
# symbol
# FXAIX                         Fidelity 500 Index  MUTUALFUND           1.45
# FCTDX      Strategic Advisers Fidelity US TtlStk  MUTUALFUND           1.04
# VDADX   Vanguard Dividend Appreciation Index Adm  MUTUALFUND           1.86
# FSKAX           Fidelity Total Market Index Fund  MUTUALFUND           1.41
# VPMAX                      Vanguard PRIMECAP Adm  MUTUALFUND           1.10
# VPMCX                      Vanguard PRIMECAP Inv  MUTUALFUND           1.04
# FALCX          Strategic Advisers Large Cap Fund  MUTUALFUND           1.25
# VDIGX               Vanguard Dividend Growth Inv  MUTUALFUND           1.68
# FRDAX             Franklin Rising Dividends Fund  MUTUALFUND           1.19
# FRDTX             Franklin Rising Dividends Fund  MUTUALFUND           0.22
# FRDPX             Franklin Rising Dividends Fund  MUTUALFUND           0.95
# FRDRX             Franklin Rising Dividends Fund  MUTUALFUND           0.72
# FRISX             Franklin Rising Dividends Fund  MUTUALFUND           1.26
# TRZDX            T. Rowe Price Dividend Growth Z  MUTUALFUND           1.70
# PRDGX              T. Rowe Price Dividend Growth  MUTUALFUND           1.14
# TADGX         T. Rowe Price Dividend Growth Fund  MUTUALFUND           0.91
# PDGIX         T. Rowe Price Dividend Growth Fund  MUTUALFUND           1.26
# FGLGX            Fidelity Series Large Cap Stock  MUTUALFUND           1.77
# VGIAX               Vanguard Growth & Income Adm  MUTUALFUND           1.21
# VQNPX               Vanguard Growth & Income Inv  MUTUALFUND           1.12
# VPCCX                 Vanguard PRIMECAP Core Inv  MUTUALFUND           1.20
# FGIKX                 Fidelity Growth & Income K  MUTUALFUND           1.65
# FGRIX                   Fidelity Growth & Income  MUTUALFUND           1.56
# MRGAX                          MFS Core Equity A  MUTUALFUND           0.64
# MRGKX                         MFS Core Equity R6  MUTUALFUND           0.78
#
#         yieldTTM  annualReturnNavY3  annualReturnNavY5 fiftyTwoWeekRange  \
# symbol
# FXAIX       1.45            1.36473           32.34697    134.1 - 166.06
# FCTDX       1.04           22.18354            0.00000     11.98 - 14.94
# VDADX       1.86           15.46475           -2.03329     39.97 - 46.45
# FSKAX       1.41           12.67376           12.48581     106.8 - 132.3
# VPMAX       1.10           17.24792           -2.00747    130.2 - 165.55
# VPMCX       1.04           17.24792           -2.00747   125.68 - 159.72
# FALCX       1.25           19.31999           -5.81710      9.74 - 11.99
# VDIGX       1.68           12.06275            0.18025     33.42 - 37.59
# FRDAX       1.19           16.69773           -5.00711     81.03 - 91.13
# FRDTX       0.22           16.69773           -5.00711     79.35 - 89.12
# FRDPX       0.95           16.69773           -5.00711     81.13 - 91.21
# FRDRX       0.72           16.69773           -5.00711     80.84 - 90.85
# FRISX       1.26           16.69773           -5.00711     81.02 - 91.12
# TRZDX       1.70           14.07911           -0.92916     62.62 - 70.95
# PRDGX       1.14           14.07911           -0.92916      62.5 - 70.88
# TADGX       0.91           14.07911           -0.92916     62.39 - 70.79
# PDGIX       1.26           14.07911           -0.92916     62.48 - 70.84
# FGLGX       1.77           10.06575           -8.84075     16.69 - 19.78
# VGIAX       1.21           17.94424           -4.70740     78.83 - 96.76
# VQNPX       1.12           17.94424           -4.70740      48.3 - 59.27
# VPCCX       1.20           12.09122           -4.90381     26.74 - 33.06
# FGIKX       1.65            7.98842           -8.91258      47.4 - 55.03
# FGRIX       1.56            7.98842           -8.91258     47.45 - 55.08
# MRGAX       0.64           18.97059           -3.81766     37.86 - 45.58
# MRGKX       0.78           18.97059           -3.81766     40.73 - 49.17
#
#         regularMarketPrice  regularMarketDayRange  regularMarketVolume  \
# symbol
# FXAIX               166.06                    NaN                  NaN
# FCTDX                14.74                    NaN                  NaN
# VDADX                46.28                    NaN                  NaN
# FSKAX               131.66                    NaN                  NaN
# VPMAX               156.73                    NaN                  NaN
# VPMCX               151.31                    NaN                  NaN
# FALCX                11.82                    NaN                  NaN
# VDIGX                37.40                    NaN                  NaN
# FRDAX                88.03                    NaN                  NaN
# FRDTX                86.17                    NaN                  NaN
# FRDPX                88.14                    NaN                  NaN
# FRDRX                87.82                    NaN                  NaN
# FRISX                88.01                    NaN                  NaN
# TRZDX                70.75                    NaN                  NaN
# PRDGX                70.67                    NaN                  NaN
# TADGX                70.57                    NaN                  NaN
# PDGIX                70.63                    NaN                  NaN
# FGLGX                19.55                    NaN                  NaN
# VGIAX                90.80                    NaN                  NaN
# VQNPX                55.65                    NaN                  NaN
# VPCCX                31.80                    NaN                  NaN
# FGIKX                54.03                    NaN                  NaN
# FGRIX                54.09                    NaN                  NaN
# MRGAX                45.43                    NaN                  NaN
# MRGKX                49.01                    NaN                  NaN
#
#         regularMarketOpen  averageDailyVolume3Month  averageDailyVolume10Day
# symbol
# FXAIX                 NaN                       0.0                      0.0
# FCTDX                 NaN                       0.0                      0.0
# VDADX                 NaN                       0.0                      0.0
# FSKAX                 NaN                       0.0                      0.0
# VPMAX                 NaN                       0.0                      0.0
# VPMCX                 NaN                       0.0                      0.0
# FALCX                 NaN                       0.0                      0.0
# VDIGX                 NaN                       0.0                      0.0
# FRDAX                 NaN                       0.0                      0.0
# FRDTX                 NaN                       0.0                      0.0
# FRDPX                 NaN                       0.0                      0.0
# FRDRX                 NaN                       0.0                      0.0
# FRISX                 NaN                       0.0                      0.0
# TRZDX                 NaN                       NaN                      NaN
# PRDGX                 NaN                       0.0                      0.0
# TADGX                 NaN                       0.0                      0.0
# PDGIX                 NaN                       0.0                      0.0
# FGLGX                 NaN                       0.0                      0.0
# VGIAX                 NaN                       0.0                      0.0
# VQNPX                 NaN                       0.0                      0.0
# VPCCX                 NaN                       0.0                      0.0
# FGIKX                 NaN                       0.0                      0.0
# FGRIX                 NaN                       0.0                      0.0
# MRGAX                 NaN                       0.0                      0.0
# MRGKX                 NaN                       0.0                      0.0

# %%
#### 'most_watched_tickers'
most_watched_tickers_data_list = most_watched_tickers_dict['most_watched_tickers']['quotes']
columns = ['symbol', 'fiftyTwoWeekRange', 'regularMarketPrice', 'regularMarketDayRange', 'regularMarketVolume',
          'regularMarketOpen', 'averageDailyVolume3Month', 'averageDailyVolume10Day', 'averageAnalystRating'
          ]
df_most_watched_tickers = pd.DataFrame(most_watched_tickers_data_list, columns=columns)
df_most_watched_tickers.set_index(keys=['symbol'], inplace = True)
df_most_watched_tickers
# Out:
#        fiftyTwoWeekRange  regularMarketPrice regularMarketDayRange  \
# symbol
# AAPL     133.77 - 199.62              185.92       185.19 - 186.74
# MSFT     230.68 - 390.68              388.47      384.65 - 388.675
# GE         75.67 - 130.8              129.79        129.18 - 130.8
# CSCO       45.56 - 58.19               50.34       50.295 - 50.815
# INTC       24.73 - 51.28               47.12     46.6131 - 47.5986
# AMZN      88.12 - 157.17              154.62        154.01 - 156.2
# T          13.43 - 21.53               16.48        16.325 - 16.62
# DIS       78.73 - 118.18               90.35         89.65 - 90.83
# PFE        25.76 - 46.74               28.70         28.44 - 28.94
# BAC         24.96 - 37.0               32.80         31.96 - 33.19
# GOOG      88.86 - 146.66              144.24     143.36 - 144.7399
# JNJ      144.95 - 175.97              162.39       161.69 - 162.47
# XOM        97.48 - 120.7               99.95      99.1703 - 100.65
# WMT      136.09 - 169.94              161.32      160.38 - 161.545
# VZ          30.14 - 42.0               38.56         38.17 - 38.77
# TSLA     124.31 - 299.29              218.89     217.1501 - 225.34
# F           9.63 - 15.42               11.46         11.41 - 11.77
# C          38.17 - 54.75               52.62         51.27 - 53.85
# KO         51.55 - 64.99               60.39         59.87 - 60.46
# META     132.14 - 377.06              374.49       369.59 - 377.06
# PG       135.83 - 158.38              150.60        149.89 - 151.3
# HD        274.26 - 361.0              355.71       353.43 - 358.53
# IBM      120.55 - 166.34              165.80      162.355 - 165.98
# NVDA     167.31 - 553.46              547.10      543.3008 - 549.7
# MCD      245.73 - 299.35              293.47       292.84 - 295.75
#
#         regularMarketVolume  regularMarketOpen  averageDailyVolume3Month  \
# symbol
# AAPL               40477782            186.060                  53996137
# MSFT               21661153            385.490                  26360763
# GE                  4501735            130.600                   4709390
# CSCO               18785708             50.500                  19676762
# INTC               27587902             47.600                  40082629
# AMZN               40484155            155.390                  50951424
# T                  32658909             16.340                  37829734
# DIS                11919448             89.650                  12534093
# PFE                30373486             28.460                  41180180
# BAC                74344294             32.250                  46349795
# GOOG               13998729            144.340                  22146742
# JNJ                 4496942            161.840                   6952721
# XOM                18041683            100.140                  21170836
# WMT                 4542989            161.370                   7716426
# VZ                 18774830             38.190                  22524245
# TSLA              123043812            220.080                 118624803
# F                  55030084             11.650                  54834334
# C                  37907972             52.300                  19062272
# KO                 13218008             60.080                  14591632
# META               19310046            370.155                  18138860
# PG                  5684834            150.950                   6912673
# HD                  1956284            358.530                   3527839
# IBM                 4958261            162.970                   4228795
# NVDA               35299360            546.200                  43384708
# MCD                 1714818            295.460                   3089827
#
#         averageDailyVolume10Day averageAnalystRating
# symbol
# AAPL                   55617120            2.2 - Buy
# MSFT                   22792830            1.7 - Buy
# GE                      3964410            1.9 - Buy
# CSCO                   17413800           2.6 - Hold
# INTC                   35602950           2.9 - Hold
# AMZN                   46224300            1.7 - Buy
# T                      37374150           2.6 - Hold
# DIS                    11189590            2.1 - Buy
# PFE                    39834520            2.5 - Buy
# BAC                    43729620            2.5 - Buy
# GOOG                   17293860            1.7 - Buy
# JNJ                     6184870            2.3 - Buy
# XOM                    19487370            2.2 - Buy
# WMT                     6577860            1.8 - Buy
# VZ                     23348860           2.6 - Hold
# TSLA                  102362420           2.8 - Hold
# F                      49014650           2.7 - Hold
# C                      22479580            2.5 - Buy
# KO                     12499650            2.0 - Buy
# META                   16146680            1.8 - Buy
# PG                      7157570            2.2 - Buy
# HD                      3745540            2.2 - Buy
# IBM                     3548940           2.6 - Hold
# NVDA                   47405870            1.7 - Buy
# MCD                     2905770            1.9 - Buy

# %%
most_actives_data_list = most_actives_dct['most_actives']['quotes']
columns = ['symbol', 'regularMarketPrice', 'fiftyTwoWeekRange', 'fiftyDayAverage', 'twoHundredDayAverage', 'marketCap', 'bookValue', 'sharesOutstanding' ,'averageDailyVolume10Day', 'averageDailyVolume3Month', 'customPriceAlertConfidence', 'priceHint', 'messageBoardId']
df_most_actives = pd.DataFrame(most_actives_data_list, columns=columns)
df_most_actives.set_index(keys=['symbol'], inplace = True)
df_most_actives
# Out:
#         regularMarketPrice fiftyTwoWeekRange  fiftyDayAverage  \
# symbol
# MARA                18.980       5.13 - 31.3          16.5658
# TSLA               218.890   124.31 - 299.29         237.5632
# AAL                 13.210     10.86 - 19.08          13.1070
# BAC                 32.800      24.96 - 37.0          31.1498
# LCID                 3.005      2.97 - 17.81           4.2084
# F                   11.460      9.63 - 15.42          11.0512
# SOFI                 7.890       4.45 - 11.7           8.1521
# NIO                  7.170       7.0 - 16.18           7.8142
# AMD                146.560    67.27 - 151.05         129.1166
# RIOT                11.730      5.16 - 20.65          13.6691
#
#         twoHundredDayAverage     marketCap  bookValue  sharesOutstanding  \
# symbol
# MARA               12.523700    4225422336      4.853          222624992
# TSLA              231.337550  696151179264     16.818         3178919936
# AAL                14.228750    8633276416     -7.859          653540992
# BAC                29.279650  259120005120     32.646         7900000256
# LCID                5.946350    6879737344      2.361         2289430016
# F                  12.232900   45873807360     11.058         3932100096
# SOFI                7.762225    7574076416      5.276          958742976
# NIO                 9.137750   15199395840      9.052         2079970048
# AMD               111.453800  236848283648     34.037         1615500032
# RIOT               12.417200    2424497152      6.830          206515008
#
#         averageDailyVolume10Day  averageDailyVolume3Month  \
# symbol
# MARA                  122235900                  65941678
# TSLA                  102362420                 118624803
# AAL                    40747370                  36463659
# BAC                    43729620                  46349795
# LCID                   39240110                  34459108
# F                      49014650                  54834334
# SOFI                   42919950                  43371308
# NIO                    56957990                  53845988
# AMD                    62472330                  58277545
# RIOT                   39623910                  30364680
#
#        customPriceAlertConfidence  priceHint   messageBoardId
# symbol
# MARA                          LOW          2  finmb_158387416
# TSLA                         HIGH          2   finmb_27444752
# AAL                          HIGH          2     finmb_168569
# BAC                           LOW          2      finmb_19049
# LCID                         HIGH          4   finmb_83747444
# F                             LOW          2     finmb_106335
# SOFI                         HIGH          2  finmb_141582707
# NIO                           LOW          2  finmb_311626862
# AMD                          HIGH          2     finmb_168864
# RIOT                          LOW          2    finmb_1532998

# %%
industry = 'undervalued_growth_stocks'
columns = ['symbol', 'averageAnalystRating', 'regularMarketPrice', 'fiftyTwoWeekRange', 'regularMarketVolume',  'averageDailyVolume10Day', 'averageDailyVolume3Month', 'priceToBook', 'marketCap', 'forwardPE', 'priceEpsCurrentYear', 'bookValue',    ]
my_dict = industry + '_dict'
my_data_list = industry + '_data_list'
my_df = 'df_' + industry
my_dict = s.get_screeners([industry])
my_data_list = my_dict[industry]['quotes']

undervalued_growth_stocks_df = pd.DataFrame(my_data_list, columns=columns)
undervalued_growth_stocks_df.set_index(keys=['symbol'], inplace = True)
undervalued_growth_stocks_df
# Out:
#        averageAnalystRating  regularMarketPrice fiftyTwoWeekRange  \
# symbol
# SWN               2.3 - Buy                7.01       4.57 - 7.69
# SLB               1.8 - Buy               49.95     42.73 - 62.12
# DAL               1.6 - Buy               38.47      30.6 - 49.81
# BMY              2.7 - Hold               50.31     48.25 - 75.18
# LYG        1.0 - Strong Buy                2.28       1.88 - 2.63
# AEO              2.8 - Hold               20.89      9.95 - 21.68
# HAL               1.7 - Buy               34.48     27.84 - 43.85
# EQT               2.2 - Buy               37.82     28.11 - 45.23
# VTRS             2.7 - Hold               11.68      8.74 - 12.49
# NYCB              2.1 - Buy               10.00      5.81 - 14.22
# BTI               2.0 - Buy               30.14     28.35 - 39.08
# VLO               2.1 - Buy              131.50    104.18 - 152.2
# ING              2.7 - Hold               14.09      11.0 - 15.22
# ALSN             2.7 - Hold               56.96     41.43 - 61.53
# PYPL              2.4 - Buy               61.00    50.25 - 88.625
# CNHI              2.4 - Buy               11.49      9.77 - 17.98
# DOLE              2.2 - Buy               12.02     9.98 - 14.005
# NOV               2.2 - Buy               19.98     14.05 - 24.83
# FNB               1.9 - Buy               13.29     10.09 - 14.68
# CIG               2.5 - Buy                2.46       1.92 - 2.75
# VOD        1.5 - Strong Buy                8.66      8.11 - 12.53
# TS                2.0 - Buy               32.31      24.69 - 38.0
# IBN        1.5 - Strong Buy               24.07     19.34 - 25.04
# STLA              1.8 - Buy               22.30     14.98 - 23.66
# UA                2.0 - Buy                7.60     5.86 - 11.415
#
#         regularMarketVolume  averageDailyVolume10Day  \
# symbol
# SWN                36824896                 31156630
# SLB                12732772                 11974400
# DAL                42272150                 13617190
# BMY                11461710                 15217240
# LYG                 7714021                  7029130
# AEO                 3623672                  5143330
# HAL                 6783380                  6330010
# EQT                 4357238                  5668110
# VTRS                8912971                 13070590
# NYCB                6023718                  7283530
# BTI                 3971170                  4730660
# VLO                 3276282                  2662740
# ING                 2566530                  2644190
# ALSN                 516820                   644610
# PYPL                9282572                 14782310
# CNHI               12209128                 15760150
# DOLE                 379861                   414100
# NOV                 5096430                  3154210
# FNB                 1487536                  1804940
# CIG                 1186674                  1867950
# VOD                 6125372                  4968240
# TS                  2174733                  2079180
# IBN                 5834711                  4972960
# STLA                4461310                  3805370
# UA                  2652478                  2672320
#
#         averageDailyVolume3Month  priceToBook     marketCap  forwardPE  \
# symbol
# SWN                     22066503     1.180930    7721234432   7.619566
# SLB                      9412216     3.667670   71351582720  15.322086
# DAL                     10181695     2.239623   24754022400   5.088624
# BMY                     15111573     3.528793  102368772096   7.634295
# LYG                      8094339     4.989059   36531757056        NaN
# AEO                      5097763     2.373864    4126568704  13.221519
# HAL                      6689385     3.372787   30861393920  11.015974
# EQT                      5421211     1.095375   15556576256  13.131944
# VTRS                     9430409     0.671535   14012145664   4.171429
# NYCB                     9749618     0.688753    7224880128   7.633588
# BTI                      4733922     0.951419   67405398016   7.591939
# VLO                      3070031     1.723573   44769566720   9.050241
# ING                      3263652     0.954284   47196569600   6.741627
# ALSN                      637727     9.138456    5097048576   8.172167
# PYPL                    15960170     3.337345   65772032000  12.151395
# CNHI                    14210008     1.914362   14801647616   7.509804
# DOLE                      552442     0.926040    1141046656   9.317830
# NOV                      3235080     1.425615    7870661632  11.684210
# FNB                      1848765     0.824084    4768837120   9.293707
# CIG                      3136981     0.221602    5938587648  41.000000
# VOD                      6535063     3.872987   23450152960  11.394737
# TS                       2142831     2.350160   18841061376   7.899756
# IBN                      5392354     0.072642   84938457088  16.832169
# STLA                     5836939     0.905878   67317678080   5.492611
# UA                       3440922     1.592290    3401402624  12.881356
#
#         priceEpsCurrentYear  bookValue
# symbol
# SWN               10.953126      5.936
# SLB               18.500000     13.619
# DAL                5.945905     17.177
# BMY                7.312500     14.257
# LYG                     NaN      0.457
# AEO               14.921429      8.800
# HAL               12.270463     10.223
# EQT               16.301725     34.527
# VTRS               3.959322     17.393
# NYCB               7.352941     14.519
# BTI                     NaN     31.679
# VLO                5.343356     76.295
# ING                6.073276     14.765
# ALSN               8.207493      6.233
# PYPL              13.495575     18.278
# CNHI               6.680232      6.002
# DOLE              10.543860     12.980
# NOV               14.170213     14.015
# FNB                8.686275     16.127
# CIG                     NaN     11.101
# VOD                     NaN      2.236
# TS                 5.698413     13.748
# IBN               18.097744    331.350
# STLA                    NaN     24.617
# UA                15.510203      4.773

# %%
industry = 'aerospace_defense'
columns = ['symbol', 'averageAnalystRating', 'regularMarketPrice', 'fiftyTwoWeekRange', 'regularMarketVolume',  'averageDailyVolume10Day', 'averageDailyVolume3Month', 'priceToBook', 'marketCap', 'forwardPE', 'priceEpsCurrentYear', 'bookValue',    ]
my_dict = industry + '_dict'
my_data_list = industry + '_data_list'
my_df = 'df_' + industry
my_dict = s.get_screeners([industry])
my_data_list = my_dict[industry]['quotes']

aerospace_defense_df = pd.DataFrame(my_data_list, columns=columns)
aerospace_defense_df.set_index(keys=['symbol'], inplace = True)
aerospace_defense_df
# Out:
#        averageAnalystRating  regularMarketPrice fiftyTwoWeekRange  \
# symbol
# BA                1.8 - Buy              217.70   176.25 - 267.54
# RTX              2.8 - Hold               86.33    68.56 - 104.91
# LMT              2.7 - Hold              463.18    393.77 - 508.1
# NOC              2.6 - Hold              481.08   414.56 - 496.89
# GD                2.1 - Buy              254.81   202.35 - 261.39
# TDG               2.0 - Buy             1032.83  659.59 - 1033.81
# LHX               2.2 - Buy              207.80   160.25 - 219.31
# HWM               2.0 - Buy               55.54      38.17 - 55.9
# HEI-A                   NaN              136.08   121.43 - 150.42
# HEI               2.2 - Buy              172.86    153.63 - 191.0
# AXON              1.9 - Buy              250.69    168.3 - 260.69
# TXT               2.4 - Buy               79.38     61.27 - 81.59
# HII              2.6 - Hold              254.68   188.51 - 261.42
# ESLT             3.0 - Hold              206.64   162.01 - 225.22
# CW         1.3 - Strong Buy              222.50   156.76 - 224.74
# WWD              2.6 - Hold              139.45     88.3 - 140.73
# BWXT              2.1 - Buy               79.96     55.47 - 81.66
# CAE               2.0 - Buy               21.00     18.89 - 25.04
# HXL               2.5 - Buy               71.73     58.81 - 79.08
# DRS               1.6 - Buy               19.35      10.8 - 20.95
# MOG-A             2.3 - Buy              142.15    87.84 - 147.91
# MOG-B                   NaN              140.22    86.92 - 145.48
# AVAV              1.7 - Buy              126.80    81.04 - 143.99
# ERJ               1.9 - Buy               17.89     12.11 - 20.13
# SPR               2.4 - Buy               27.20     14.65 - 38.55
#
#         regularMarketVolume  averageDailyVolume10Day  \
# symbol
# BA                 11285521                 12313480
# RTX                 5277301                  6835220
# LMT                  966475                   887150
# NOC                  701359                   624400
# GD                  1107546                  1123630
# TDG                  146182                   211250
# LHX                 1049640                  1102360
# HWM                 2259184                  2711950
# HEI-A                503962                   505200
# HEI                  337119                   293860
# AXON                 485081                   423470
# TXT                 1029624                  1009020
# HII                  204778                   242200
# ESLT                   6636                    17870
# CW                   106482                   148530
# WWD                  254811                   285980
# BWXT                 486550                   540370
# CAE                  254379                   288240
# HXL                  314627                   377440
# DRS                  354267                   678490
# MOG-A                 52260                    89780
# MOG-B                    52                       70
# AVAV                 134485                   218900
# ERJ                  900926                   877870
# SPR                 3922456                  5772200
#
#         averageDailyVolume3Month  priceToBook     marketCap   forwardPE  \
# symbol
# BA                       6943739    -7.868011  131703496704   61.671387
# RTX                      9784813     1.796296  124133908480   17.873707
# LMT                      1203157    12.336005  114914500608   19.021765
# NOC                       726154     4.556631   72543494144   19.879337
# GD                       1133926     3.478112   69536882688   18.694790
# TDG                       222650   -28.791290   57130057728   27.601015
# LHX                      1316359     2.114604   39386411008   15.790274
# HWM                      2430663     5.994603   22868262912   25.712963
# HEI-A                     284637     5.979173   20826361856   32.869568
# HEI                       333013     7.595237   20826345472   42.264057
# AXON                      438434    12.349261   18794907648   60.995132
# TXT                      1236496     2.203714   15558876160   13.454237
# HII                       274337     2.713952   10116781056   15.435151
# ESLT                       27755     3.224417    9208002560   31.309092
# CW                        176526     3.896058    8508666880   22.117296
# WWD                       349603     4.028949    8375101952   23.436975
# BWXT                      531408     8.391227    7317363200   25.877024
# CAE                       333339     1.442704    6759059968   19.626167
# HXL                       486237     3.664181    6033303552   28.923388
# DRS                      1103785     2.261571    5076859392   23.035715
# MOG-A                     141306     2.769983    4787441152   17.680347
# MOG-B                         63     2.732375    4787433472         NaN
# AVAV                      287065     4.465890    3567530752   38.541035
# ERJ                      1096632     1.030174    3285641472   14.086614
# SPR                      4398734    -3.332925    3155907328  108.800000
#
#         priceEpsCurrentYear  bookValue
# symbol
# BA               -38.736656    -27.669
# RTX               18.932018     48.060
# LMT               18.661564     37.547
# NOC               21.100000    105.578
# GD                22.629662     73.261
# TDG               31.976160    -35.873
# LHX               16.839546     98.269
# HWM               31.202248      9.265
# HEI-A             38.991405     22.759
# HEI               50.104347     22.759
# AXON              64.777780     20.300
# TXT               14.380434     36.021
# HII               17.539944     93.841
# ESLT              31.500000     64.086
# CW                24.316940     57.109
# WWD               27.343138     34.612
# BWXT              27.197279      9.529
# CAE               23.595507     14.556
# HXL               38.154260     19.576
# DRS               26.875000      8.556
# MOG-A             20.691412     51.318
# MOG-B                   NaN     51.318
# AVAV              46.446888     28.393
# ERJ               26.308823     17.366
# SPR               -7.391305     -8.161

# %%
industry = 'undervalued_large_caps'
columns = ['symbol', 'averageAnalystRating', 'regularMarketPrice', 'fiftyTwoWeekRange', 'regularMarketVolume',  'averageDailyVolume10Day', 'averageDailyVolume3Month', 'priceToBook', 'marketCap', 'forwardPE', 'priceEpsCurrentYear', 'bookValue',    ]
my_dict = industry + '_dict'
my_data_list = industry + '_data_list'
my_df = 'df_' + industry
my_dict = s.get_screeners([industry])
my_data_list = my_dict[industry]['quotes']

undervalued_large_caps_df = pd.DataFrame(my_data_list, columns=columns)
undervalued_large_caps_df.set_index(keys=['symbol'], inplace = True)
undervalued_large_caps_df
# Out:
#        averageAnalystRating  regularMarketPrice fiftyTwoWeekRange  \
# symbol
# F                2.7 - Hold               11.46      9.63 - 15.42
# ITUB             2.6 - Hold                6.85       4.24 - 7.05
# UAL               2.0 - Buy               39.78     33.68 - 58.23
# VALE              2.2 - Buy               14.77     12.22 - 19.31
# MRO               2.2 - Buy               23.40     20.57 - 29.85
# OXY               2.5 - Buy               58.06     55.12 - 67.93
# HBAN              2.4 - Buy               12.52      9.13 - 15.62
# UMC              3.0 - Hold                7.95       6.71 - 8.97
# SLB               1.8 - Buy               49.95     42.73 - 62.12
# DAL               1.6 - Buy               38.47      30.6 - 49.81
# HST               1.9 - Buy               19.75     14.51 - 20.39
# DVN               2.2 - Buy               42.77     42.59 - 66.96
# CVE               1.9 - Buy               15.61     14.97 - 21.37
# BP                2.2 - Buy               34.86     33.62 - 41.38
# LYG        1.0 - Strong Buy                2.28       1.88 - 2.63
# SUZ               2.0 - Buy               11.02     7.46 - 11.595
# BKR               1.9 - Buy               31.52     26.12 - 37.58
# SU                2.3 - Buy               32.78     27.59 - 35.51
# GFI              2.8 - Hold               13.25      8.89 - 17.78
# HAL               1.7 - Buy               34.48     27.84 - 43.85
# EQT               2.2 - Buy               37.82     28.11 - 45.23
# RF                2.5 - Buy               18.28     13.72 - 24.33
# VTRS             2.7 - Hold               11.68      8.74 - 12.49
# BNTX              2.4 - Buy              103.57     88.0 - 147.68
# MT                2.0 - Buy               26.65      21.3 - 32.49
#
#         regularMarketVolume  averageDailyVolume10Day  \
# symbol
# F                  55030084                 49014650
# ITUB               11127178                 13667050
# UAL                26572445                  9972310
# VALE               15323050                 15219570
# MRO                11788733                  9690000
# OXY                11245966                  8848790
# HBAN               16912017                 16704320
# UMC                 3104787                  6164830
# SLB                12732772                 11974400
# DAL                42272150                 13617190
# HST                 7340083                  6279930
# DVN                12749746                  8945300
# CVE                12644039                  9642570
# BP                  9355217                  8399980
# LYG                 7714021                  7029130
# SUZ                  794208                   883830
# BKR                12546220                  7525010
# SU                  2867570                  4300780
# GFI                 7429786                  5563070
# HAL                 6783380                  6330010
# EQT                 4357238                  5668110
# RF                 11575179                  8543190
# VTRS                8912971                 13070590
# BNTX                 368249                   795920
# MT                  1296952                  1354400
#
#         averageDailyVolume3Month  priceToBook    marketCap  forwardPE  \
# symbol
# F                       54834334     1.036354  45873807360   7.253164
# ITUB                    14390226     0.365665  67155345408   8.456790
# UAL                      8619790     1.473879  13051698176   4.139438
# VALE                    20707265     1.672896  63508791296   5.702703
# MRO                      9784359     1.229831  13694779392   7.335423
# OXY                      9608270     2.423711  50952351744  13.856802
# HBAN                    16059342     1.133237  18129963008  10.262295
# UMC                      6428472     0.284264  20129320960  12.045454
# SLB                      9412216     3.667670  71351582720  15.322086
# DAL                     10181695     2.239623  24754022400   5.088624
# HST                      6858106     2.027929  14137246720  21.010640
# DVN                      8898345     2.355436  27402739712   7.477273
# CVE                      9656522     1.040250  29652443136   6.968750
# BP                       8376757     8.282252  99541344256   7.354431
# LYG                      8094339     4.989059  36531757056        NaN
# SUZ                      1363109     0.340228  14208637952   8.609376
# BKR                      7079850     2.080253  31947411456  15.527094
# SU                       4823777     1.018487  42450755584   7.823389
# GFI                      4761952     2.767335  11839418368  55.208336
# HAL                      6689385     3.372787  30861393920  11.015974
# EQT                      5421211     1.095375  15556576256  13.131944
# RF                       9660459     1.187862  17001589760   9.326530
# VTRS                     9430409     0.671535  14012145664   4.171429
# BNTX                      723308     1.239261  24622524416  46.236607
# MT                       2036624     0.403073  21892894720   6.300236
#
#         priceEpsCurrentYear  bookValue
# symbol
# F                  6.741176     11.058
# ITUB               9.383561     18.733
# UAL                4.022245     26.990
# VALE               6.564444      8.829
# MRO                8.830188     19.027
# OXY               15.002584     23.955
# HBAN               9.205883     11.048
# UMC               10.743243     27.967
# SLB               18.500000     13.619
# DAL                5.945905     17.177
# HST               19.362745      9.739
# DVN                7.464223     18.158
# CVE                8.971264     15.006
# BP                 7.143443      4.209
# LYG                     NaN      0.457
# SUZ                5.769634     32.390
# BKR               20.205130     15.152
# SU                 8.426735     32.185
# GFI                     NaN      4.788
# HAL               12.270463     10.223
# EQT               16.301725     34.527
# RF                 8.423964     15.389
# VTRS               3.959322     17.393
# BNTX              22.036171     83.574
# MT                 7.528249     66.117

# %%
industry = 'upside_breakout_stocks_daily'
columns = ['symbol', 'averageAnalystRating', 'regularMarketPrice', 'fiftyTwoWeekRange', 'regularMarketVolume',  'averageDailyVolume10Day', 'averageDailyVolume3Month', 'priceToBook', 'marketCap', 'forwardPE', 'priceEpsCurrentYear', 'bookValue',    ]
my_dict = industry + '_dict'
my_data_list = industry + '_data_list'
my_df = 'df_' + industry
my_dict = s.get_screeners([industry])
my_data_list = my_dict[industry]['quotes']

upside_breakout_stocks_daily_df = pd.DataFrame(my_data_list, columns=columns)
upside_breakout_stocks_daily_df.set_index(keys=['symbol'], inplace = True)
upside_breakout_stocks_daily_df
# Out:
#        averageAnalystRating  regularMarketPrice fiftyTwoWeekRange  \
# symbol
# CNSL             3.0 - Hold                4.56        2.1 - 4.79
# IBM              2.6 - Hold              165.80   120.55 - 166.34
# EOS                     NaN               18.81       15.3 - 18.9
# UCBIO                   NaN               23.58   15.375 - 25.926
#
#         regularMarketVolume  averageDailyVolume10Day  \
# symbol
# CNSL                1931062                   987530
# IBM                 4958261                  3548940
# EOS                   71262                    90610
# UCBIO                 12248                     7100
#
#         averageDailyVolume3Month  priceToBook     marketCap  forwardPE  \
# symbol
# CNSL                      710303     1.116006  5.298355e+08  -3.590551
# IBM                      4228795     6.559323  1.513951e+11  18.340708
# EOS                        85427     1.010856  9.839021e+08        NaN
# UCBIO                       6975     0.906888           NaN        NaN
#
#         priceEpsCurrentYear  bookValue
# symbol
# CNSL              -3.768595      4.086
# IBM               19.123415     25.277
# EOS                     NaN     18.608
# UCBIO                   NaN     26.001

# %%
industry = 'uranium'
columns = ['symbol', 'averageAnalystRating', 'regularMarketPrice', 'fiftyTwoWeekRange', 'regularMarketVolume',  'averageDailyVolume10Day', 'averageDailyVolume3Month', 'priceToBook', 'marketCap', 'forwardPE', 'priceEpsCurrentYear', 'bookValue',    ]
my_dict = industry + '_dict'
my_data_list = industry + '_data_list'
my_df = 'df_' + industry
my_dict = s.get_screeners([industry])
my_data_list = my_dict[industry]['quotes']

uranium_df = pd.DataFrame(my_data_list, columns=columns)
uranium_df.set_index(keys=['symbol'], inplace = True)
uranium_df
# Out:
#        averageAnalystRating  regularMarketPrice fiftyTwoWeekRange  \
# symbol
# CCJ               1.7 - Buy               49.92     23.69 - 51.22
# NXE               1.8 - Buy                7.84       3.49 - 7.84
#
#         regularMarketVolume  averageDailyVolume10Day  \
# symbol
# CCJ                17501541                  5807130
# NXE                17354272                  6579290
#
#         averageDailyVolume3Month  priceToBook    marketCap  forwardPE  \
# symbol
# CCJ                      5129416     3.544196  22164328448  44.571426
# NXE                      5570544     6.457990   4105172992 -71.272730
#
#         priceEpsCurrentYear  bookValue
# symbol
# CCJ               79.238090     14.085
# NXE              -52.266666      1.214

# %%
##'top_options_open_interest'
from datetime import datetime

# Function to convert Unix timestamp to formatted date
def convert_unix_to_date(timestamp):
    date_time = datetime.utcfromtimestamp(timestamp)
    formatted_date = date_time.strftime('%Y-%m-%d')
    return formatted_date

industry = 'top_options_open_interest'
columns = ['symbol', 'optionsType', 'strike', 'expireDate', 'openInterest', 'regularMarketPrice', 'fiftyTwoWeekRange', 'regularMarketVolume',
           'priceHint']
my_dict = s.get_screeners([industry])
my_data_list = my_dict[industry]['quotes']

top_options_open_interest_df = pd.DataFrame(my_data_list, columns=columns)
top_options_open_interest_df.set_index(keys=['symbol'], inplace = True)

top_options_open_interest_df['expireDate'] = top_options_open_interest_df['expireDate'].apply(convert_unix_to_date)
top_options_open_interest_df
# Out:
#                     optionsType  strike  expireDate  openInterest  \
# symbol
# PANW240119P00400000         Put   400.0  2024-01-19         15242
# SPX271217P04000000          Put  4000.0  2027-12-17             0
# SPX271217C05000000         Call  5000.0  2027-12-17             0
# SPX271217P05000000          Put  5000.0  2027-12-17             0
#
#                      regularMarketPrice fiftyTwoWeekRange  \
# symbol
# PANW240119P00400000               81.90     27.37 - 27.37
# SPX271217P04000000               257.07   257.07 - 257.07
# SPX271217C05000000               800.63   800.63 - 800.63
# SPX271217P05000000               520.26   520.26 - 520.26
#
#                      regularMarketVolume  priceHint
# symbol
# PANW240119P00400000                    5          2
# SPX271217P04000000                     1          2
# SPX271217C05000000                     1          2
# SPX271217P05000000                     1          2

# %%
industry = 'net_net_strategy'
columns = ['symbol','regularMarketPrice', 'fiftyTwoWeekRange', 'regularMarketVolume',  'averageDailyVolume10Day', 'averageDailyVolume3Month', 'priceToBook', 'marketCap', 'bookValue']
my_dict = industry + '_dict'
my_data_list = industry + '_data_list'
my_df = 'df_' + industry
my_dict = s.get_screeners([industry])
my_data_list = my_dict[industry]['quotes']

net_net_strategy_df = pd.DataFrame(my_data_list, columns=columns)
net_net_strategy_df.set_index(keys=['symbol'], inplace = True)
net_net_strategy_df
# Out:
#         regularMarketPrice fiftyTwoWeekRange  regularMarketVolume  \
# symbol
# GVLMY              0.00001   1.0E-5 - 1.0E-4                20000
# ITTOY             13.50000      10.7 - 15.76                  698
# PTKFF              0.10235  0.10235 - 0.1512                  650
# GRVY              73.10000     45.12 - 82.48                14540
# GUNGF             17.00000     15.535 - 19.8                  500
# SILDF              7.48000       5.34 - 7.48                 1666
# KSPHF             22.88000     18.81 - 22.88                  882
# HROEY             11.59000     10.58 - 14.08                   28
# JGCCY             23.29000      20.45 - 30.0                   58
# TAIPY             14.77000      8.88 - 15.52                  705
# KOTMY             15.52000      14.39 - 20.3                 9579
# TOAGF              9.47000       8.38 - 9.47                 1566
# KOTMF             15.91500     14.76 - 19.27                   74
# FENG               1.45000        1.1 - 4.14                22326
# POGHF             29.07500     27.63 - 36.52                    2
# JFU                3.13000       1.49 - 5.51                 2339
# THDDY             11.41000       9.82 - 12.3                  207
# SHMDF            155.00000   131.77 - 183.93                 1000
# SMNNY             15.66500     12.85 - 18.65                60740
# NPPNY              8.96000      8.51 - 13.14                    3
# CSIOY             88.70250    76.15 - 106.03                   47
# SGIOY             12.59000      10.1 - 12.84               516589
# SQNXF             38.40000       32.6 - 50.3                  300
# TSUKY             56.01000      37.69 - 57.4                    5
# MSSMY              8.84000      6.92 - 13.11                61540
#
#         averageDailyVolume10Day  averageDailyVolume3Month  priceToBook  \
# symbol
# GVLMY                         0                         0     0.000526
# ITTOY                       400                      1373     0.010241
# PTKFF                        70                       593          NaN
# GRVY                      20540                     19678     0.001147
# GUNGF                       638                        94     0.008053
# SILDF                       185                        27     0.003464
# KSPHF                        98                        31     0.005223
# HROEY                       118                       477     0.001091
# JGCCY                       990                       432     0.013931
# TAIPY                      2030                     58024     0.001456
# KOTMY                     10630                     17752     0.007383
# TOAGF                       174                        48     0.005327
# KOTMF                       135                       316     0.007570
# FENG                      15850                     10490     0.014404
# POGHF                        23                        66     0.008886
# JFU                        3990                      6211     0.010266
# THDDY                        87                        49     0.002875
# SHMDF                       130                       157     0.016983
# SMNNY                     66780                    197324     0.001716
# NPPNY                       184                       106     0.002854
# CSIOY                        90                       116     0.092318
# SGIOY                    139380                    102345     0.003032
# SQNXF                        60                       160     0.014372
# TSUKY                       130                       331     0.013262
# MSSMY                    223960                     46129     0.007499
#
#           marketCap  bookValue
# symbol
# GVLMY        147725      0.019
# ITTOY           162   1318.266
# PTKFF    4738896896        NaN
# GRVY      507964576  63738.773
# GUNGF    1018194624   2110.937
# SILDF     401365568   2159.053
# KSPHF    1017045696   4380.544
# HROEY    4193760512  10625.696
# JGCCY    2943204096   1671.837
# TAIPY    4872652800  10143.340
# KOTMY    4776668160   2102.253
# TOAGF    1106569472   1777.589
# KOTMF    4898239488   2102.253
# FENG       17619386    100.665
# POGHF    1146991360   3272.138
# JFU        36850432    304.876
# THDDY    1198848640   3968.759
# SHMDF   14074820608   9126.603
# SMNNY   14093174784   9126.603
# NPPNY    2419432704   3139.677
# CSIOY    2056026368    960.837
# SGIOY   14621145088   4151.907
# SQNXF    4825344000   2671.791
# TSUKY    5720188928   4223.389
# MSSMY    4976318464   1178.812

# %%
##'morningstar_five_star_stocks'
industry = 'morningstar_five_star_stocks'
columns = ['symbol','morningstarCurrentRating', 'morningstarRatingChange', 'morningstarStewardshipRating',
           'morningstarFairValue', 'regularMarketPrice', 'dividendYield', 'regularMarketVolume',  'averageDailyVolume10Day',
           'averageDailyVolume3Month', 'priceToBook', 'marketCap', 'bookValue', 'longName']
my_dict = industry + '_dict'
my_data_list = industry + '_data_list'
my_df = 'df_' + industry
my_dict = s.get_screeners([industry])
my_data_list = my_dict[industry]['quotes']

morningstar_five_star_stocks_df = pd.DataFrame(my_data_list, columns=columns)
morningstar_five_star_stocks_df.set_index(keys=['symbol'], inplace = True)
morningstar_five_star_stocks_df
# Out:
#         morningstarCurrentRating morningstarRatingChange  \
# symbol
# TCEHY                          5                 Upgrade
# RHHBY                          5                 Upgrade
# BABA                           5                 Upgrade
# PFE                            5                 Upgrade
#
#        morningstarStewardshipRating  morningstarFairValue  regularMarketPrice  \
# symbol
# TCEHY                     Exemplary                  90.0               36.93
# RHHBY                     Exemplary                  59.0               36.97
# BABA                      Exemplary                 128.0               71.84
# PFE                        Standard                  42.0               28.70
#
#         dividendYield  regularMarketVolume  averageDailyVolume10Day  \
# symbol
# TCEHY            0.83              1558572                  2929670
# RHHBY            3.46              1374797                  1506360
# BABA             1.39             16147285                 19756060
# PFE              5.85             30373486                 39834520
#
#         averageDailyVolume3Month  priceToBook     marketCap  bookValue  \
# symbol
# TCEHY                    2818126     0.454204  348736290816     81.307
# RHHBY                    2087888     1.113554  237234634752     33.200
# BABA                    18789229     0.176116  180482899968    407.914
# PFE                     41180180     1.671617  162051981312     17.169
#
#                              longName
# symbol
# TCEHY        Tencent Holdings Limited
# RHHBY                Roche Holding AG
# BABA    Alibaba Group Holding Limited
# PFE                       Pfizer Inc.

# %%
##'latest_analyst_upgraded_stocks'
industry = 'latest_analyst_upgraded_stocks'
columns = ['ticker', 'marketCap', 'analystFirm', 'ratingDate', 'averageRating', 'averagePriceTarget' ,'ratingPrior' 
           ,'ratingCurrent', 'fiftyTwoWeekRange', 'dayVolume' ]
my_dict = industry + '_dict'
my_data_list = industry + '_data_list'
my_df = 'df_' + industry
my_dict = s.get_screeners([industry])
my_data_list = my_dict[industry]['records']

latest_analyst_upgraded_df = pd.DataFrame(my_data_list, columns=columns)
latest_analyst_upgraded_df.set_index(keys=['ticker'], inplace = True)
latest_analyst_upgraded_df
# Out:
#            marketCap     analystFirm  ratingDate averageRating  \
# ticker
# VVV     4.541746e+09  Morgan Stanley  01/16/2024           Buy
# DG      2.955308e+10  Morgan Stanley  01/16/2024           Buy
# WDC     1.621377e+10   Deutsche Bank  01/16/2024           Buy
# TGT     6.505279e+10  Morgan Stanley  01/16/2024           Buy
#
#         averagePriceTarget   ratingPrior ratingCurrent fiftyTwoWeekRange  \
# ticker
# VVV                  39.78  Equal-Weight    Overweight     29.15 - 39.67
# DG                  140.25  Equal-Weight    Overweight   101.09 - 239.71
# WDC                  53.16          Hold           Buy     31.97 - 53.21
# TGT                 149.19  Equal-Weight    Overweight   102.93 - 181.70
#
#         dayVolume
# ticker
# VVV        822644
# DG        1874001
# WDC       2819332
# TGT       2236556

# %%
#### ''analyst_strong_buy_stocks'
industry = 'analyst_strong_buy_stocks'
columns = ['ticker','companyName', 'price','fiftyTwoWeekRange', 'ratingPrior','ratingCurrent','ratingAction','priceTargetPrior',
          'priceTargetCurrent','averageRating', ]
my_dict = industry + '_dict'
my_data_list = industry + '_data_list'
my_df = 'df_' + industry
my_dict = s.get_screeners([industry])
my_data_list = my_dict[industry]['records']

analyst_strong_buy_stocks_df = pd.DataFrame(my_data_list, columns=columns)
analyst_strong_buy_stocks_df.set_index(keys=['ticker'], inplace = True)
analyst_strong_buy_stocks_df
# Out:
#                                companyName  price fiftyTwoWeekRange  \
# ticker
# APLS         Apellis Pharmaceuticals, Inc.  70.23     19.83 - 94.75
# AMK     AssetMark Financial Holdings, Inc.  30.12     22.92 - 33.00
# ALHC            Alignment Healthcare, Inc.   7.83      4.88 - 13.05
# FUSN           Fusion Pharmaceuticals Inc.   9.01      2.31 - 10.43
#
#        ratingPrior ratingCurrent ratingAction  priceTargetPrior  \
# ticker
# APLS    Strong Buy    Strong Buy    Maintains              67.0
# AMK     Strong Buy    Strong Buy    Maintains              36.0
# ALHC    Strong Buy    Strong Buy    Maintains              10.0
# FUSN    Strong Buy    Strong Buy    Maintains              15.0
#
#         priceTargetCurrent averageRating
# ticker
# APLS                 106.0           Buy
# AMK                   38.0           Buy
# ALHC                  12.0           Buy
# FUSN                  16.0           Buy

# %%
#### 'stocks_most_bought_by_private_equity'
industry = 'stocks_most_bought_by_private_equity'
columns = ['ticker','companyName', 'price', 'averageRating','fiftyTwoWeekRange','industry','marketCap', 'dayVolume','numOfInstitutionalHolders',
           'numOfInstitutionalBuyers', 'numOfSharesBoughtByInstitutions', 'percentOfSharesOutHeldByInstitutions',
          'lastReportDate',]
my_dict = industry + '_dict'
my_data_list = industry + '_data_list'
my_df = 'df_' + industry
my_dict = s.get_screeners([industry])
my_data_list = my_dict[industry]['records']

stocks_most_bought_PE_df = pd.DataFrame(my_data_list, columns=columns)
stocks_most_bought_PE_df.set_index(keys=['ticker'], inplace = True)
stocks_most_bought_PE_df
# Out:
#                     companyName  price averageRating fiftyTwoWeekRange  \
# ticker
# BIRK    Birkenstock Holding plc  47.88           Buy     35.83 - 52.12
# ODD            Oddity Tech Ltd.  43.02           Buy     24.12 - 56.00
# KVUE                Kenvue Inc.  21.51           Buy     17.82 - 27.80
# SPWR       SunPower Corporation   3.25          Hold      3.23 - 19.32
#
#                              industry     marketCap  dayVolume  \
# ticker
# BIRK           Footwear & Accessories  8.993109e+09    1668949
# ODD           Software—Infrastructure  2.443859e+09     911594
# KVUE    Household & Personal Products  4.119165e+10   16986452
# SPWR                            Solar  5.699232e+08   12253615
#
#         numOfInstitutionalHolders  numOfInstitutionalBuyers  \
# ticker
# BIRK                           19                        19
# ODD                            77                        76
# KVUE                          467                       430
# SPWR                          213                       106
#
#         numOfSharesBoughtByInstitutions  percentOfSharesOutHeldByInstitutions  \
# ticker
# BIRK                          159310371                             84.863408
# ODD                            31477976                             80.026841
# KVUE                         1287783937                             87.887547
# SPWR                          101268647                            104.450302
#
#        lastReportDate
# ticker
# BIRK       2023-12-31
# ODD        2023-12-31
# KVUE       2023-12-31
# SPWR       2023-12-31

# %%
### 'most_shorted_stocks
industry = 'most_shorted_stocks'
columns = ['symbol','customPriceAlertConfidence','averageAnalystRating','regularMarketPrice','fiftyTwoWeekRange','sharesOutstanding','fiftyTwoWeekLow','fiftyTwoWeekHigh',
           'regularMarketVolume',  'averageDailyVolume10Day', 'averageDailyVolume3Month', 
           'marketCap', 'bookValue', 'longName']
my_dict = industry + '_dict'
my_data_list = industry + '_data_list'
my_df = 'df_' + industry
my_dict = s.get_screeners([industry])
my_data_list = my_dict[industry]['quotes']

most_shorted_df = pd.DataFrame(my_data_list, columns=columns)
most_shorted_df.set_index(keys=['symbol'], inplace = True)
most_shorted_df
# Out:
#        customPriceAlertConfidence averageAnalystRating  regularMarketPrice  \
# symbol
# SNES                          LOW            2.0 - Buy                1.09
# SMFL                          LOW           3.0 - Hold                1.67
# FWBI                          LOW            2.0 - Buy                4.05
# NVAX                         HIGH           2.7 - Hold                4.58
# CING                          LOW            2.5 - Buy                7.07
# BYND                         HIGH   3.6 - Underperform                7.57
# RILY                          LOW                  NaN               23.17
# UPST                         HIGH   3.6 - Underperform               31.95
# CVNA                          LOW           3.2 - Hold               42.78
# SAVA                          LOW            2.0 - Buy               26.24
# AI                            LOW           3.0 - Hold               26.21
# NOVA                          LOW            2.0 - Buy               11.87
# BLNK                          LOW           2.6 - Hold                2.54
# ABR                           LOW           2.7 - Hold               14.71
# TRUP                          LOW           2.6 - Hold               28.29
# MULN                          LOW                  NaN               11.03
# BMEA                         HIGH            1.9 - Buy               15.21
# EBIXQ                         LOW     1.0 - Strong Buy                2.16
# STEM                          LOW           2.6 - Hold                3.30
# FSR                           LOW           3.2 - Hold                1.03
# PLUG                          LOW           2.7 - Hold                3.44
# MVIS                          LOW           3.0 - Hold                2.43
# POL                           LOW           3.0 - Hold                8.64
# KSS                           LOW           2.9 - Hold               26.12
# MPW                           LOW           3.1 - Hold                3.43
#
#        fiftyTwoWeekRange  sharesOutstanding  fiftyTwoWeekLow  \
# symbol
# SNES       0.52 - 80.952             753599            0.520
# SMFL       0.325 - 126.0             796666            0.325
# FWBI        2.75 - 149.8             674998            2.750
# NVAX         4.53 - 13.7          118790000            4.530
# CING          1.9 - 38.6            1450170            1.900
# BYND        5.58 - 22.87           64540900            5.580
# RILY       16.65 - 60.72           30582900           16.650
# UPST       11.93 - 72.58           85057296           11.930
# CVNA       6.042 - 62.59           84500000            6.042
# SAVA       12.32 - 38.53           42236900           12.320
# AI         12.43 - 48.87          116365000           12.430
# NOVA       7.615 - 24.56          122416000            7.615
# BLNK         2.22 - 15.4           67408000            2.220
# ABR         10.1 - 17.74          188502000           10.100
# TRUP       18.45 - 69.15           41545200           18.450
# MULN      6.95 - 10125.0            4130980            6.950
# BMEA       7.305 - 43.69           35705800            7.305
# EBIXQ       0.49 - 32.87           30901400            0.490
# STEM        2.33 - 11.36          155896000            2.330
# FSR          0.98 - 8.66          218200992            0.980
# PLUG        3.22 - 18.88          605502016            3.220
# MVIS          1.82 - 8.2          189986000            1.820
# POL          1.06 - 42.9            2109350            1.060
# KSS        17.68 - 35.77          110712000           17.680
# MPW          3.31 - 14.0          599000000            3.310
#
#         fiftyTwoWeekHigh  regularMarketVolume  averageDailyVolume10Day  \
# symbol
# SNES              80.952               352148                  2519030
# SMFL             126.000               201743                  1608680
# FWBI             149.800                78724                  1192500
# NVAX              13.700              6288148                 10060720
# CING              38.600               166305                   709840
# BYND              22.870              1712812                  2398020
# RILY              60.720              1262902                   996090
# UPST              72.580              8460271                  9307400
# CVNA              62.590              5230025                  5693320
# SAVA              38.530              1069202                   991950
# AI                48.870              5600819                  7441410
# NOVA              24.560              4239741                  3921400
# BLNK              15.400              6335292                  9956480
# ABR               17.740              3557883                  3596730
# TRUP              69.150               298569                   527630
# MULN           10125.000               642700                  1314500
# BMEA              43.690               690646                   894190
# EBIXQ             32.870               794834                  2363130
# STEM              11.360              3309260                  3596120
# FSR                8.660             19248409                 44452480
# PLUG              18.880             32102031                 30835000
# MVIS               8.200              1062165                  1886550
# POL               42.900               221938                  2988740
# KSS               35.770              6823425                  5205790
# MPW               14.000             22639162                 39145010
#
#         averageDailyVolume3Month   marketCap  bookValue  \
# symbol
# SNES                     2242088      829028     10.085
# SMFL                     2923277     1330432      1.507
# FWBI                      692233     2733742      4.871
# NVAX                     7425580   544058176     -5.713
# CING                     1510198    10260267     -0.111
# BYND                     3056655   488574624     -5.630
# RILY                     1344470   708605824     13.530
# UPST                     9209668  2717580800      7.536
# CVNA                     8722336  7597727744      2.974
# SAVA                     1377259  1108296192      3.682
# AI                       8955345  3141661440      7.603
# NOVA                     5882668  1453077888     12.727
# BLNK                     7014622   171216320      3.275
# ABR                      4947419  2772864512     13.109
# TRUP                      753349  1175313792      6.954
# MULN                     1397704    45564708    300.047
# BMEA                     1268726   543442624      5.592
# EBIXQ                    3299055    66747028        NaN
# STEM                     4436877   514456800      2.905
# FSR                     22888681   361072672      0.986
# PLUG                    36054980  2089001856      5.797
# MVIS                     2271629   461665984      0.518
# POL                      3198374    18224784     25.773
# KSS                      5719649  2891797504     33.793
# MPW                     19149726  2054569984     13.843
#
#                                  longName
# symbol
# SNES                      SenesTech, Inc.
# SMFL                 Smart for Life, Inc.
# FWBI           First Wave BioPharma, Inc.
# NVAX                        Novavax, Inc.
# CING                       Cingulate Inc.
# BYND                    Beyond Meat, Inc.
# RILY             B. Riley Financial, Inc.
# UPST               Upstart Holdings, Inc.
# CVNA                          Carvana Co.
# SAVA               Cassava Sciences, Inc.
# AI                            C3.ai, Inc.
# NOVA    Sunnova Energy International Inc.
# BLNK                   Blink Charging Co.
# ABR              Arbor Realty Trust, Inc.
# TRUP                      Trupanion, Inc.
# MULN              Mullen Automotive, Inc.
# BMEA                  Biomea Fusion, Inc.
# EBIXQ                          Ebix, Inc.
# STEM                           Stem, Inc.
# FSR                           Fisker Inc.
# PLUG                      Plug Power Inc.
# MVIS                    MicroVision, Inc.
# POL                     Polished.com Inc.
# KSS                    Kohl's Corporation
# MPW        Medical Properties Trust, Inc.

# %%
import os
from datetime import datetime
end_date  = "2024-01-13"
formatted_end_date = datetime.strptime(end_date, "%Y-%m-%d").strftime("%Y%m%d")
file_name_suffix = '_yquery_data.xlsx'
full_file_name = f"{formatted_end_date}_{file_name_suffix}"
folder_path = r"C:\Users\pythonProject\data\data_produced\yquerry_screens"
excel_file_path = os.path.join(folder_path, full_file_name)      

## day_gainers_df, df_most_actives,df_most_watched_tickers,df_portfolio_anchors, df_aggressive_small_caps, 
## 'aerospace_defense', undervalued_large_caps_df,upside_breakout_stocks_daily, uranium_df , top_options_open_interest_df
## net_net_strategy_df, morningstar_five_star_stocks, latest_analyst_upgraded_df, stocks_most_bought_PE_df,
## analyst_strong_buy_stocks_df
with pd.ExcelWriter(excel_file_path, engine='xlsxwriter') as writer:
    # Write each DataFrame to a different sheet
    day_gainers_df.to_excel(writer, sheet_name='day_gainers', index=True)
    df_most_actives.to_excel(writer, sheet_name='most_actives', index=True)
    df_most_watched_tickers.to_excel(writer, sheet_name='most_watched_tickers', index=True)     
    df_aggressive_small_caps.to_excel(writer, sheet_name='aggressive_small_caps', index=True)  
    upside_breakout_stocks_daily_df.to_excel(writer, sheet_name='upside_breakout_stocks_daily', index=True)
    top_options_open_interest_df.to_excel(writer, sheet_name='top_options_oi', index=True)
    net_net_strategy_df.to_excel(writer, sheet_name='net_net_strategy', index=True)
    morningstar_five_star_stocks_df.to_excel(writer, sheet_name='morningstar_5star_stcks', index=True)
    analyst_strong_buy_stocks_df.to_excel(writer, sheet_name='analyst_strong_buy', index=True)
    latest_analyst_upgraded_df.to_excel(writer, sheet_name='latest_analyst_upgraded', index=True)
    stocks_most_bought_PE_df.to_excel(writer, sheet_name='stocks_most_bought_PE', index=True)
    most_shorted_df.to_excel(writer, sheet_name='most_shorted', index=True)
    uranium_df.to_excel(writer, sheet_name='uranium', index=True)
    aerospace_defense_df.to_excel(writer, sheet_name='aerospace_defense', index=True) 
    df_portfolio_anchors.to_excel(writer, sheet_name='portfolio_anchors', index=True) 
    undervalued_growth_stocks_df.to_excel(writer, sheet_name='undervalued_growth_stocks', index=True) 
    undervalued_large_caps_df.to_excel(writer, sheet_name='undervalued_large_caps', index=True)
