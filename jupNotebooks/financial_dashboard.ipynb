# %%
from financetoolkit import Toolkit, Discovery
import pandas as pd
from datetime import datetime
API_KEY = "DZvlZlf0Q0sDAwwwh59Z90CVB05FjQlS"

# %%
####Cumulative returns
ticker = ["AAPL","SPY"]
# Initialize the Toolkit with company tickers
companies = Toolkit(
    ticker, api_key=API_KEY, start_date="2010-01-01"
)
# Out:
# Please note that the benchmark ticker (SPY) is also included in the tickers. Therefore, this ticker will be removed from the tickers list.

# %%
# Plot the Cumulative Returns
companies.get_historical_data(period="quarterly")["Cumulative Return"].plot(
    figsize=(15, 5),
    title="Cumulative Returns of Apple against benchmark",
    grid=True,
    linestyle="-",
    linewidth=2,
    colormap="plasma",
    xlabel="Date",
    ylabel="Cumulative Return",
)
# Out:
# Obtaining historical data: 100%|█████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  4.40it/s]
# <Axes: title={'center': 'Cumulative Returns of Apple against benchmark'}, xlabel='Date', ylabel='Cumulative Return'>

# %%
##### Discovery
# Initialize the Discovery module
discovery = Discovery(api_key=API_KEY)

# %%
# search ticker
#discovery.search_instruments("Apple")

# %%
# Screener
screen = discovery.get_stock_screener(
    market_cap_higher=20000000,
    market_cap_lower=200000000000,
    price_higher=50,
    price_lower=200,
    beta_higher=1,
    beta_lower=1.5,
    volume_higher=100000,
    volume_lower=2000000,
    dividend_higher=5,
    dividend_lower=20,
    is_etf=False,
)

# %%
screen.sort_values(by= 'Dividend', ascending=False)
# Out:
#                                             Name   Market Cap  \
# Symbol
# TBK                      Triumph Financial, Inc.   1356377088
# RXN             Zurn Water Solutions Corporation  11435746500
# CTC-A.TO      Canadian Tire Corporation, Limited   7770746750
# WHR                        Whirlpool Corporation   6281658614
# BAP                               Credicorp Ltd.  13752863652
# CPA                          Copa Holdings, S.A.   4275971960
# PNC       The PNC Financial Services Group, Inc.  62603044960
# GFC.PA                                    Gecina   6911498884
# DRI                     Darden Restaurants, Inc.  18661779650
# PRU                   Prudential Financial, Inc.  41539890000
# CBRL      Cracker Barrel Old Country Store, Inc.   1425976653
# ARE        Alexandria Real Estate Equities, Inc.  21794523520
# LYB               LyondellBasell Industries N.V.  34003519940
#
#                       Sector                            Industry      Beta  \
# Symbol
# TBK       Financial Services                    Banks - Regional  1.132027
# RXN                Utilities                     Regulated Water  1.383597
# CTC-A.TO   Consumer Cyclical                    Specialty Retail  1.370000
# WHR        Consumer Cyclical  Furnishings, Fixtures & Appliances  1.474000
# BAP       Financial Services                    Banks - Regional  1.097000
# CPA              Industrials   Airlines, Airports & Air Services  1.383000
# PNC       Financial Services                    Banks - Regional  1.154000
# GFC.PA           Real Estate                       REIT - Office  1.051000
# DRI        Consumer Cyclical                         Restaurants  1.257000
# PRU       Financial Services                    Insurance - Life  1.348000
# CBRL       Consumer Cyclical                         Restaurants  1.431000
# ARE              Real Estate                       REIT - Office  1.063000
# LYB          Basic Materials               Chemicals - Specialty  1.199000
#
#            Price  Dividend   Volume                 Exchange Exchange Code  \
# Symbol
# TBK        58.74    17.810   179571     NASDAQ Global Select        NASDAQ
# RXN        64.95    11.571  1305057  New York Stock Exchange          NYSE
# CTC-A.TO  133.86     7.000   273887   Toronto Stock Exchange           TSX
# WHR       115.34     7.000   667328  New York Stock Exchange          NYSE
# BAP       172.92     6.770   166313  New York Stock Exchange          NYSE
# CPA       101.74     6.440   190432  New York Stock Exchange          NYSE
# PNC       157.37     6.200  1668106  New York Stock Exchange          NYSE
# GFC.PA     93.55     5.300   138595                    Paris      EURONEXT
# DRI       156.35     5.240  1207020  New York Stock Exchange          NYSE
# PRU       115.71     5.200   771808  New York Stock Exchange          NYSE
# CBRL       64.23     5.200   841543     NASDAQ Global Select        NASDAQ
# ARE       124.58     5.080   551070  New York Stock Exchange          NYSE
# LYB       104.78     5.000  1081619  New York Stock Exchange          NYSE
#
#          Country  isFund
# Symbol
# TBK           US   False
# RXN           US   False
# CTC-A.TO      CA   False
# WHR           US   False
# BAP           PE   False
# CPA           PA   False
# PNC           US   False
# GFC.PA        FR   False
# DRI           US   False
# PRU           US   False
# CBRL          US   False
# ARE           US   False
# LYB           US   False

# %%
display(discovery.get_biggest_gainers().sort_values(by='Change',ascending=False).head(10))

display(discovery.get_biggest_losers().sort_values(by='Change',ascending=False).head(10))

display(discovery.get_most_active_stocks().sort_values(by='Change',ascending=False).head(10))
# Out:
#                                    Name  Change  Price  Change %
# Symbol
# DXYZ               Destiny Tech100 Inc.  25.660  59.20   76.5057
# ROOT                         Root, Inc.  11.970  82.90   16.8758
# ZOOZ    ZOOZ Power Ltd. Ordinary Shares   4.100   4.10   14.5251
# BTTR         Better Choice Company Inc.   3.465   7.74   81.0526
# GRIN    Grindrod Shipping Holdings Ltd.   3.130  13.65   29.7528
# MDIA               MediaCo Holding Inc.   2.480   3.88  177.1429
# GCTS    GCT Semiconductor Holding, Inc.   2.430   8.16   42.4084
# XXII           22nd Century Group, Inc.   2.080   3.56  140.5405
# SWVL                Swvl Holdings Corp.   1.870  17.19   12.2063
# NPCE                    NeuroPace, Inc.   1.780  14.48   14.0157
#                           Name  Change    Price  Change %
# Symbol
# NUTX        Nutex Health, Inc. -0.0110  0.07860  -12.2768
# USDP           USD Partners LP -0.0214  0.11258  -15.9663
# MARK     Remark Holdings, Inc. -0.0234  0.17490  -11.8003
# SLNA    Selina Hospitality PLC -0.0249  0.05510  -31.1250
# OTRK              Ontrak, Inc. -0.0507  0.33930  -13.0000
# VHAI    Vocodia Holdings Corp. -0.0510  0.39700  -11.3839
# CYAN     Cyanotech Corporation -0.0601  0.29000  -17.1665
# VLCN              Volcon, Inc. -0.0640  0.32610  -16.4061
# WLGS    WANG & LEE GROUP, Inc. -0.0647  0.51030  -11.2522
# CUEN              Cuentas Inc. -0.0650  0.28500  -18.5714
#                                                Name  Change   Price  Change %
# Symbol
# NVDA                             NVIDIA Corporation   21.03  880.08    2.4481
# SPY                          SPDR S&P 500 ETF Trust    5.36  518.43    1.0447
# QQQ                               Invesco QQQ Trust    5.13  440.47    1.1784
# AMZN                               Amazon.com, Inc.    5.07  185.07    2.8167
# AMD                    Advanced Micro Devices, Inc.    4.59  170.42    2.7679
# MDIA                           MediaCo Holding Inc.    2.48    3.88  177.1429
# XXII                       22nd Century Group, Inc.    2.08    3.56  140.5405
# TQQQ                         ProShares UltraPro QQQ    2.04   59.86    3.5282
# SOXL    Direxion Daily Semiconductor Bull 3X Shares    1.25   43.62    2.9502
# GDX                          VanEck Gold Miners ETF    1.06   33.84    3.2337

# %%
tickers = discovery.get_stock_screener(
    market_cap_higher=1000000,
    market_cap_lower=200000000000,
    price_higher=100,
    price_lower=200,
    beta_higher=1,
    beta_lower=1.5,
    volume_higher=100000,
    volume_lower=2000000,
    dividend_higher=1,
    dividend_lower=2,
    is_etf=False,
).index.tolist()

companies = Toolkit(tickers=tickers, api_key=API_KEY)

companies.get_historical_data()
# Out:
# Obtaining historical data: 100%|███████████████████████████████████████████████████████| 28/28 [00:10<00:00,  2.67it/s]
#              Open                                                          \
#              ROST    AME    XYL    RJF   STLD   NTAP    WLK   JBHT    RPM
# date
# 2014-04-09   35.9   50.9  36.21  34.72  18.63  37.02  64.53  72.53  41.57
# 2014-04-10  35.63  50.81  37.12  34.88  18.71  37.43  65.77  72.84  42.43
# 2014-04-11   34.8  49.58  35.97  33.27  18.35   36.2  63.25  71.75   41.3
# 2014-04-14  34.78  50.89  35.45  33.28  18.56  36.28  63.05  73.61   41.2
# 2014-04-15  34.81  50.75  35.12  32.99  18.78   37.0  62.52  74.83  41.75
# ...           ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2024-04-01 146.43 182.99 129.25  128.2  149.0 104.73 152.91 196.95 118.93
# 2024-04-02 144.39 180.73 128.76 128.35 149.01 104.21 153.82 195.69 117.58
# 2024-04-03 143.68 180.38 127.68 128.62 147.76 104.33 155.87 194.76 116.67
# 2024-04-04 142.95 182.36 129.69  130.7  148.6 107.41 159.02 197.52 115.57
# 2024-04-05 140.14 180.64 127.41 127.88 146.15 105.35 156.79 194.52 112.06
#
#                    ... Cumulative Return                                     \
#              TFII  ...              OLED    MSA    AIT   UFPI   HLNE   WTFC
# date               ...
# 2014-04-09   22.3  ...               1.0    1.0    1.0    1.0    NaN    1.0
# 2014-04-10  22.25  ...            0.9613 0.9911 0.9849 0.9666    NaN 0.9719
# 2014-04-11  21.78  ...            0.9551 0.9847 0.9756 0.9595    NaN 0.9744
# 2014-04-14  21.73  ...            0.9602 0.9928 0.9778 0.9583    NaN 0.9798
# 2014-04-15  21.73  ...            0.9691 1.0004  0.977 0.9428    NaN 0.9746
# ...           ...  ...               ...    ...    ...    ...    ...    ...
# 2024-04-01  160.3  ...            5.7055 4.0587 4.7712 7.1454 7.1157 2.5145
# 2024-04-02 158.12  ...             5.639 4.0551 4.6982 7.0572  7.071 2.4626
# 2024-04-03 157.56  ...            5.6253 4.0787  4.768 7.2431 7.2379 2.4501
# 2024-04-04  158.3  ...            5.5763 4.0546 4.7438 7.0447 7.0934 2.4406
# 2024-04-05 157.62  ...            5.5852 4.1414 4.7893 7.0805 7.2104 2.4572
#
#
#               CHH    AWI   MATX Benchmark
# date
# 2014-04-09    1.0    1.0    1.0       1.0
# 2014-04-10 0.9781 0.9852 0.9869     0.979
# 2014-04-11 0.9721 0.9868 0.9803    0.9702
# 2014-04-14 0.9771 0.9941  1.004    0.9778
# 2014-04-15 0.9832 0.9907  1.004    0.9846
# ...           ...    ...    ...       ...
# 2024-04-01 3.0493 2.4274 5.6261    3.3397
# 2024-04-02 2.9539 2.3713 5.4255    3.3185
# 2024-04-03 2.9307 2.4138 5.6104    3.3221
# 2024-04-04 2.9749 2.3715 5.5634    3.2815
# 2024-04-05 3.0111 2.3961 5.6301    3.3158
#
# [2515 rows x 336 columns]

# %%
### Ratios
Tickers = ['RIVN', 'SPCE', 'ACHR', 'JOBY']
companies_growth = Toolkit(tickers=Tickers, api_key=API_KEY)
ratios_df = companies_growth.ratios.collect_all_ratios()
# Out:
# Obtaining financial statements:  33%|█████████████████▎                                  | 1/3 [00:01<00:03,  1.52s/it]
# You have reached the rate limit of your subscription. This resulted in no data for RIVN, SPCE, ACHR, JOBY
# If you use the Free plan, consider upgrading your plan. You can get 15% off by using the following affiliate link which also supports the project: https://www.jeroenbouma.com/fmp
# No data found for the following tickers: RIVN, SPCE, ACHR, JOBY
# Obtaining financial statements:  67%|██████████████████████████████████▋                 | 2/3 [00:03<00:01,  1.54s/it]
# You have reached the rate limit of your subscription. This resulted in no data for RIVN, SPCE, ACHR, JOBY
# If you use the Free plan, consider upgrading your plan. You can get 15% off by using the following affiliate link which also supports the project: https://www.jeroenbouma.com/fmp
# No data found for the following tickers: RIVN, SPCE, ACHR, JOBY
# Obtaining financial statements: 100%|████████████████████████████████████████████████████| 3/3 [00:04<00:00,  1.54s/it]
# You have reached the rate limit of your subscription. This resulted in no data for RIVN, SPCE, ACHR, JOBY
# If you use the Free plan, consider upgrading your plan. You can get 15% off by using the following affiliate link which also supports the project: https://www.jeroenbouma.com/fmp
# No data found for the following tickers: RIVN, SPCE, ACHR, JOBY
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 4
#       2 Tickers = ['RIVN', 'SPCE', 'ACHR', 'JOBY']
#       3 companies_growth = Toolkit(tickers=Tickers, api_key=API_KEY)
# ----> 4 ratios_df = companies_growth.ratios.collect_all_ratios()
#
# File C:\Users\pthon\anaconda3\envs\ta_env\lib\site-packages\financetoolkit\toolkit_controller.py:539, in Toolkit.ratios(self)
#     532             self.get_cash_flow_statement(progress_bar=False)
#     534 if (
#     535     self._balance_sheet_statement.empty
#     536     and self._income_statement.empty
#     537     and self._cash_flow_statement.empty
#     538 ):
# --> 539     raise ValueError(
#     540         "The datasets could not be populated and therefore the Ratios class cannot be initialized. "
#     541         "This is usually because you have reached the API limit or entered an invalid API key."
#     542     )
#     544 if not self._start_date:
#     545     self._start_date = (
#     546         f"{self._balance_sheet_statement.columns[0].year - 5}-01-01"
#     547     )
#
# ValueError: The datasets could not be populated and therefore the Ratios class cannot be initialized. This is usually because you have reached the API limit or entered an invalid API key.

# %%
display(ratios_df)
# Out:
#                                            2018        2019         2020  \
# AGCO Days of Inventory Outstanding          NaN         NaN     104.2964
#      Days of Sales Outstanding              NaN         NaN      33.0406
#      Operating Cycle                        NaN         NaN     137.3369
#      Days of Accounts Payable Outstanding   NaN         NaN      45.5439
#      Cash Conversion Cycle                  NaN         NaN       91.793
# ...                                         ...         ...          ...
# XYL  EV-to-EBIT                             NaN     31.3928      52.3737
#      EV-to-EBITDA                           NaN     15.9607      25.4146
#      EV-to-Operating-Cash-Flow              NaN     18.0724      23.0088
#      Tangible Asset Value                   NaN 128000000.0  122000000.0
#      Net Current Asset Value                NaN 949000000.0 1567000000.0
#
#                                                   2021         2022  \
# AGCO Days of Inventory Outstanding             97.3241      109.374
#      Days of Sales Outstanding                 30.2711      31.9203
#      Operating Cycle                          127.5952     141.2943
#      Days of Accounts Payable Outstanding      41.1914      46.5909
#      Cash Conversion Cycle                     86.4038      94.7034
# ...                                                ...          ...
# XYL  EV-to-EBIT                                37.9053      42.2652
#      EV-to-EBITDA                              26.5835      27.4668
#      EV-to-Operating-Cash-Flow                 41.3576      34.7482
#      Tangible Asset Value                  434000000.0  784000000.0
#      Net Current Asset Value              1769000000.0 1422000000.0
#
#                                                   2023
# AGCO Days of Inventory Outstanding            113.3556
#      Days of Sales Outstanding                 35.7924
#      Operating Cycle                           149.148
#      Days of Accounts Payable Outstanding       44.324
#      Cash Conversion Cycle                     104.824
# ...                                                ...
# XYL  EV-to-EBIT                                37.1598
#      EV-to-EBITDA                              22.6576
#      EV-to-Operating-Cash-Flow                  31.699
#      Tangible Asset Value                 2589000000.0
#      Net Current Asset Value              1679000000.0
#
# [1809 rows x 6 columns]

# %%
# !pip install trendln
# Out:
# Collecting trendln
#   Downloading trendln-0.1.10.tar.gz (23 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy>=1.15 in c:\users\pthon\anaconda3\envs\ta_env\lib\site-packages (from trendln) (1.26.3)
# Collecting findiff>=0.7.0 (from trendln)
#   Downloading findiff-0.10.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting scikit-image>=0.14.0 (from trendln)
#   Downloading scikit_image-0.22.0-cp310-cp310-win_amd64.whl.metadata (13 kB)
# Requirement already satisfied: pandas>=0.23.1 in c:\users\pthon\anaconda3\envs\ta_env\lib\site-packages (from trendln) (2.2.1)
# Requirement already satisfied: matplotlib>=2.2.4 in c:\users\pthon\anaconda3\envs\ta_env\lib\site-packages (from trendln) (3.8.0)
# Requirement already satisfied: scipy in c:\users\pthon\anaconda3\envs\ta_env\lib\site-packages (from findiff>=0.7.0->trendln) (1.11.4)
# Requirement already satisfied: sympy in c:\users\pthon\anaconda3\envs\ta_env\lib\site-packages (from findiff>=0.7.0->trendln) (1.12)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\pthon\anaconda3\envs\ta_env\lib\site-packages (from matplotlib>=2.2.4->trendln) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\pthon\anaconda3\envs\ta_env\lib\site-packages (from matplotlib>=2.2.4->trendln) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\pthon\anaconda3\envs\ta_env\lib\site-packages (from matplotlib>=2.2.4->trendln) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\pthon\anaconda3\envs\ta_env\lib\site-packages (from matplotlib>=2.2.4->trendln) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\pthon\anaconda3\envs\ta_env\lib\site-packages (from matplotlib>=2.2.4->trendln) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\pthon\anaconda3\envs\ta_env\lib\site-packages (from matplotlib>=2.2.4->trendln) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\pthon\anaconda3\envs\ta_env\lib\site-packages (from matplotlib>=2.2.4->trendln) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\pthon\anaconda3\envs\ta_env\lib\site-packages (from matplotlib>=2.2.4->trendln) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\pthon\anaconda3\envs\ta_env\lib\site-packages (from pandas>=0.23.1->trendln) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\pthon\anaconda3\envs\ta_env\lib\site-packages (from pandas>=0.23.1->trendln) (2023.3)
# Requirement already satisfied: networkx>=2.8 in c:\users\pthon\anaconda3\envs\ta_env\lib\site-packages (from scikit-image>=0.14.0->trendln) (3.2.1)
# Collecting imageio>=2.27 (from scikit-image>=0.14.0->trendln)
#   Downloading imageio-2.34.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting tifffile>=2022.8.12 (from scikit-image>=0.14.0->trendln)
#   Downloading tifffile-2024.2.12-py3-none-any.whl.metadata (31 kB)
# Collecting lazy_loader>=0.3 (from scikit-image>=0.14.0->trendln)
#   Downloading lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: six>=1.5 in c:\users\pthon\anaconda3\envs\ta_env\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.2.4->trendln) (1.16.0)
# Requirement already satisfied: mpmath>=0.19 in c:\users\pthon\anaconda3\envs\ta_env\lib\site-packages (from sympy->findiff>=0.7.0->trendln) (1.3.0)
# Downloading findiff-0.10.0-py3-none-any.whl (33 kB)
# Downloading scikit_image-0.22.0-cp310-cp310-win_amd64.whl (24.5 MB)
#    ---------------------------------------- 0.0/24.5 MB ? eta -:--:--
#    ---------------------------------------- 0.1/24.5 MB 2.4 MB/s eta 0:00:11
#    ---------------------------------------- 0.3/24.5 MB 2.9 MB/s eta 0:00:09
#     --------------------------------------- 0.5/24.5 MB 3.3 MB/s eta 0:00:08
#    - -------------------------------------- 0.7/24.5 MB 3.6 MB/s eta 0:00:07
#    - -------------------------------------- 0.9/24.5 MB 4.0 MB/s eta 0:00:06
#    -- ------------------------------------- 1.3/24.5 MB 4.4 MB/s eta 0:00:06
#    -- ------------------------------------- 1.5/24.5 MB 4.5 MB/s eta 0:00:06
#    -- ------------------------------------- 1.8/24.5 MB 4.8 MB/s eta 0:00:05
#    --- ------------------------------------ 2.1/24.5 MB 5.0 MB/s eta 0:00:05
#    --- ------------------------------------ 2.2/24.5 MB 4.9 MB/s eta 0:00:05
#    --- ------------------------------------ 2.4/24.5 MB 4.8 MB/s eta 0:00:05
#    --- ------------------------------------ 2.4/24.5 MB 4.8 MB/s eta 0:00:05
#    ---- ----------------------------------- 2.9/24.5 MB 4.8 MB/s eta 0:00:05
#    ----- ---------------------------------- 3.4/24.5 MB 5.2 MB/s eta 0:00:05
#    ------ --------------------------------- 3.7/24.5 MB 5.3 MB/s eta 0:00:04
#    ------ --------------------------------- 4.0/24.5 MB 5.3 MB/s eta 0:00:04
#    ------ --------------------------------- 4.3/24.5 MB 5.3 MB/s eta 0:00:04
#    ------- -------------------------------- 4.5/24.5 MB 5.3 MB/s eta 0:00:04
#    ------- -------------------------------- 4.6/24.5 MB 5.3 MB/s eta 0:00:04
#    ------- -------------------------------- 4.8/24.5 MB 5.1 MB/s eta 0:00:04
#    -------- ------------------------------- 5.1/24.5 MB 5.1 MB/s eta 0:00:04
#    -------- ------------------------------- 5.3/24.5 MB 5.1 MB/s eta 0:00:04
#    -------- ------------------------------- 5.4/24.5 MB 5.1 MB/s eta 0:00:04
#    -------- ------------------------------- 5.4/24.5 MB 5.1 MB/s eta 0:00:04
#    ---------- ----------------------------- 6.1/24.5 MB 5.2 MB/s eta 0:00:04
#    ---------- ----------------------------- 6.4/24.5 MB 5.3 MB/s eta 0:00:04
#    ----------- ---------------------------- 6.8/24.5 MB 5.3 MB/s eta 0:00:04
#    ----------- ---------------------------- 7.0/24.5 MB 5.3 MB/s eta 0:00:04
#    ----------- ---------------------------- 7.2/24.5 MB 5.3 MB/s eta 0:00:04
#    ------------ --------------------------- 7.5/24.5 MB 5.3 MB/s eta 0:00:04
#    ------------ --------------------------- 7.7/24.5 MB 5.3 MB/s eta 0:00:04
#    ------------- -------------------------- 8.0/24.5 MB 5.4 MB/s eta 0:00:04
#    ------------- -------------------------- 8.3/24.5 MB 5.4 MB/s eta 0:00:04
#    -------------- ------------------------- 8.6/24.5 MB 5.4 MB/s eta 0:00:03
#    -------------- ------------------------- 8.9/24.5 MB 5.4 MB/s eta 0:00:03
#    -------------- ------------------------- 9.1/24.5 MB 5.4 MB/s eta 0:00:03
#    --------------- ------------------------ 9.4/24.5 MB 5.4 MB/s eta 0:00:03
#    --------------- ------------------------ 9.7/24.5 MB 5.4 MB/s eta 0:00:03
#    ---------------- ----------------------- 10.0/24.5 MB 5.5 MB/s eta 0:00:03
#    ---------------- ----------------------- 10.3/24.5 MB 5.6 MB/s eta 0:00:03
#    ----------------- ---------------------- 10.6/24.5 MB 5.7 MB/s eta 0:00:03
#    ----------------- ---------------------- 10.8/24.5 MB 5.7 MB/s eta 0:00:03
#    ------------------ --------------------- 11.1/24.5 MB 5.7 MB/s eta 0:00:03
#    ------------------ --------------------- 11.4/24.5 MB 5.7 MB/s eta 0:00:03
#    ------------------- -------------------- 11.6/24.5 MB 5.7 MB/s eta 0:00:03
#    ------------------- -------------------- 11.9/24.5 MB 5.6 MB/s eta 0:00:03
#    ------------------- -------------------- 12.0/24.5 MB 5.6 MB/s eta 0:00:03
#    ------------------- -------------------- 12.2/24.5 MB 5.6 MB/s eta 0:00:03
#    -------------------- ------------------- 12.5/24.5 MB 5.6 MB/s eta 0:00:03
#    -------------------- ------------------- 12.7/24.5 MB 5.9 MB/s eta 0:00:02
#    --------------------- ------------------ 13.0/24.5 MB 5.7 MB/s eta 0:00:02
#    --------------------- ------------------ 13.3/24.5 MB 5.6 MB/s eta 0:00:02
#    ---------------------- ----------------- 13.5/24.5 MB 5.5 MB/s eta 0:00:02
#    ---------------------- ----------------- 13.8/24.5 MB 5.5 MB/s eta 0:00:02
#    ---------------------- ----------------- 14.1/24.5 MB 5.6 MB/s eta 0:00:02
#    ----------------------- ---------------- 14.2/24.5 MB 5.5 MB/s eta 0:00:02
#    ----------------------- ---------------- 14.4/24.5 MB 5.5 MB/s eta 0:00:02
#    ------------------------ --------------- 14.8/24.5 MB 5.5 MB/s eta 0:00:02
#    ------------------------ --------------- 15.1/24.5 MB 5.6 MB/s eta 0:00:02
#    ------------------------- -------------- 15.4/24.5 MB 5.7 MB/s eta 0:00:02
#    ------------------------- -------------- 15.7/24.5 MB 5.8 MB/s eta 0:00:02
#    -------------------------- ------------- 16.0/24.5 MB 5.7 MB/s eta 0:00:02
#    -------------------------- ------------- 16.2/24.5 MB 5.6 MB/s eta 0:00:02
#    -------------------------- ------------- 16.5/24.5 MB 5.6 MB/s eta 0:00:02
#    --------------------------- ------------ 16.8/24.5 MB 5.6 MB/s eta 0:00:02
#    --------------------------- ------------ 17.1/24.5 MB 5.6 MB/s eta 0:00:02
#    ---------------------------- ----------- 17.4/24.5 MB 5.6 MB/s eta 0:00:02
#    ---------------------------- ----------- 17.6/24.5 MB 5.6 MB/s eta 0:00:02
#    ----------------------------- ---------- 18.0/24.5 MB 5.7 MB/s eta 0:00:02
#    ----------------------------- ---------- 18.2/24.5 MB 5.6 MB/s eta 0:00:02
#    ----------------------------- ---------- 18.4/24.5 MB 5.6 MB/s eta 0:00:02
#    ----------------------------- ---------- 18.4/24.5 MB 5.6 MB/s eta 0:00:02
#    ------------------------------ --------- 18.8/24.5 MB 5.6 MB/s eta 0:00:02
#    ------------------------------- -------- 19.0/24.5 MB 5.5 MB/s eta 0:00:02
#    ------------------------------- -------- 19.3/24.5 MB 5.5 MB/s eta 0:00:01
#    ------------------------------- -------- 19.5/24.5 MB 5.5 MB/s eta 0:00:01
#    -------------------------------- ------- 19.7/24.5 MB 5.5 MB/s eta 0:00:01
#    -------------------------------- ------- 19.9/24.5 MB 5.4 MB/s eta 0:00:01
#    -------------------------------- ------- 20.2/24.5 MB 5.4 MB/s eta 0:00:01
#    --------------------------------- ------ 20.5/24.5 MB 5.4 MB/s eta 0:00:01
#    --------------------------------- ------ 20.6/24.5 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 21.0/24.5 MB 5.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 21.1/24.5 MB 5.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 21.5/24.5 MB 5.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 21.6/24.5 MB 5.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 21.8/24.5 MB 5.3 MB/s eta 0:00:01
#    ------------------------------------ --- 22.1/24.5 MB 5.3 MB/s eta 0:00:01
#    ------------------------------------ --- 22.4/24.5 MB 5.4 MB/s eta 0:00:01
#    ------------------------------------ --- 22.6/24.5 MB 5.4 MB/s eta 0:00:01
#    ------------------------------------- -- 22.8/24.5 MB 5.3 MB/s eta 0:00:01
#    ------------------------------------- -- 23.1/24.5 MB 5.3 MB/s eta 0:00:01
#    -------------------------------------- - 23.3/24.5 MB 5.3 MB/s eta 0:00:01
#    -------------------------------------- - 23.7/24.5 MB 5.4 MB/s eta 0:00:01
#    -------------------------------------- - 23.8/24.5 MB 5.4 MB/s eta 0:00:01
#    ---------------------------------------  24.1/24.5 MB 5.4 MB/s eta 0:00:01
#    ---------------------------------------  24.4/24.5 MB 5.4 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  24.5/24.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------- 24.5/24.5 MB 1.1 MB/s eta 0:00:00
# Downloading imageio-2.34.0-py3-none-any.whl (313 kB)
#    ---------------------------------------- 0.0/313.4 kB ? eta -:--:--
#    ------------------------------------ --- 286.7/313.4 kB 8.9 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  307.2/313.4 kB 6.3 MB/s eta 0:00:01
#    --------------------------------------- 313.4/313.4 kB 92.4 kB/s eta 0:00:00
# Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Downloading tifffile-2024.2.12-py3-none-any.whl (224 kB)
#    ---------------------------------------- 0.0/224.5 kB ? eta -:--:--
#    -------------------------------------- - 215.0/224.5 kB ? eta -:--:--
#    -------------------------------------- - 215.0/224.5 kB ? eta -:--:--
#    -------------------------------------- - 215.0/224.5 kB ? eta -:--:--
#    -------------------------------------- - 215.0/224.5 kB ? eta -:--:--
#    -------------------------------------- - 215.0/224.5 kB ? eta -:--:--
#    -------------------------------------- - 215.0/224.5 kB ? eta -:--:--
#    -------------------------------------- - 215.0/224.5 kB ? eta -:--:--
#    -------------------------------------- - 215.0/224.5 kB ? eta -:--:--
#    -------------------------------------- - 215.0/224.5 kB ? eta -:--:--
#    -------------------------------------- - 215.0/224.5 kB ? eta -:--:--
#    -------------------------------------- - 215.0/224.5 kB ? eta -:--:--
#    -------------------------------------- - 215.0/224.5 kB ? eta -:--:--
#    -------------------------------------- - 215.0/224.5 kB ? eta -:--:--
#    -------------------------------------- - 215.0/224.5 kB ? eta -:--:--
#    -------------------------------------- - 215.0/224.5 kB ? eta -:--:--
#    -------------------------------------- - 215.0/224.5 kB ? eta -:--:--
#    -------------------------------------- - 215.0/224.5 kB ? eta -:--:--
#    -------------------------------------- - 215.0/224.5 kB ? eta -:--:--
#    -------------------------------------- - 215.0/224.5 kB ? eta -:--:--
#    -------------------------------------- - 215.0/224.5 kB ? eta -:--:--
#    -------------------------------------- - 215.0/224.5 kB ? eta -:--:--
#    -------------------------------------- - 215.0/224.5 kB ? eta -:--:--
#    -------------------------------------- - 215.0/224.5 kB ? eta -:--:--
#    -------------------------------------- - 215.0/224.5 kB ? eta -:--:--
#    -------------------------------------- - 215.0/224.5 kB ? eta -:--:--
#    -------------------------------------- - 215.0/224.5 kB ? eta -:--:--
#    -------------------------------------- - 215.0/224.5 kB ? eta -:--:--
#    -------------------------------------- - 215.0/224.5 kB ? eta -:--:--
#    -------------------------------------- - 215.0/224.5 kB ? eta -:--:--
#    -------------------------------------- - 215.0/224.5 kB ? eta -:--:--
#    -------------------------------------- - 215.0/224.5 kB ? eta -:--:--
#    -------------------------------------- - 215.0/224.5 kB ? eta -:--:--
#    -------------------------------------- - 215.0/224.5 kB ? eta -:--:--
#    -------------------------------------- - 215.0/224.5 kB ? eta -:--:--
#    -------------------------------------- - 215.0/224.5 kB ? eta -:--:--
#    -------------------------------------- - 215.0/224.5 kB ? eta -:--:--
#    -------------------------------------- - 215.0/224.5 kB ? eta -:--:--
#    -------------------------------------- - 215.0/224.5 kB ? eta -:--:--
#    -------------------------------------- - 215.0/224.5 kB ? eta -:--:--
#    -------------------------------------- - 215.0/224.5 kB ? eta -:--:--
#    -------------------------------------- - 215.0/224.5 kB ? eta -:--:--
#    -------------------------------------- - 215.0/224.5 kB ? eta -:--:--
#    -------------------------------------- 224.5/224.5 kB 103.8 kB/s eta 0:00:00
# Building wheels for collected packages: trendln
#   Building wheel for trendln (setup.py): started
#   Building wheel for trendln (setup.py): finished with status 'done'
#   Created wheel for trendln: filename=trendln-0.1.10-py2.py3-none-any.whl size=19549 sha256=5c25f9a2f7b3ae15748d0665643a9dfe64b6cdf5104d03a0d9ff0c374fff078d
#   Stored in directory: c:\users\mayank dangwal\appdata\local\pip\cache\wheels\63\c1\3e\a8426a920ca13888e84dd1d67afceedad007377ae008eb9c16
# Successfully built trendln
# Installing collected packages: tifffile, lazy_loader, imageio, scikit-image, findiff, trendln
# Successfully installed findiff-0.10.0 imageio-2.34.0 lazy_loader-0.4 scikit-image-0.22.0 tifffile-2024.2.12 trendln-0.1.10

# %%
import trendln
# this will serve as an example for security or index closing prices, or low and high prices
import yfinance as yf # requires yfinance - pip install yfinance
tick = yf.Ticker('^GSPC') # S&P500
hist = tick.history(period="max", rounding=True)
h = hist[-1000:].Close
mins, maxs = trendln.calc_support_resistance(h)
minimaIdxs, pmin, mintrend, minwindows = trendln.calc_support_resistance((hist[-1000:].Low, None)) #support only
mins, maxs = trendln.calc_support_resistance((hist[-1000:].Low, hist[-1000:].High))
(minimaIdxs, pmin, mintrend, minwindows), (maximaIdxs, pmax, maxtrend, maxwindows) = mins, maxs
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 7
#       5 hist = tick.history(period="max", rounding=True)
#       6 h = hist[-1000:].Close
# ----> 7 mins, maxs = trendln.calc_support_resistance(h)
#       8 minimaIdxs, pmin, mintrend, minwindows = trendln.calc_support_resistance((hist[-1000:].Low, None)) #support only
#       9 mins, maxs = trendln.calc_support_resistance((hist[-1000:].Low, hist[-1000:].High))
#
# File C:\Users\pthon\anaconda3\envs\ta_env\lib\site-packages\trendln\__init__.py:737, in calc_support_resistance(h, extmethod, method, window, errpct, hough_scale, hough_prob_iter, sortError, accuracy)
#     735     trendmethod = prob_hough
#     736 else: raise ValueError('method must be one of METHOD_NCUBED, METHOD_NSQUREDLOGN, METHOD_HOUGHPOINTS, METHOD_HOUGHLINES, METHOD_PROBHOUGH')
# --> 737 extremaIdxs = get_extrema(h, extmethod, accuracy)
#     738 divide = list(reversed(range(len_h, -window, -window)))
#     739 rem, divide[0] = window - len_h % window, 0
#
# File C:\Users\pthon\anaconda3\envs\ta_env\lib\site-packages\trendln\__init__.py:456, in get_extrema(h, extmethod, accuracy)
#     454 else: raise ValueError('extmethod must be METHOD_NAIVE, METHOD_NAIVECONSEC, METHOD_NUMDIFF')
#     455 if hmin is None and hmax is None:
# --> 456     minFunc, maxFunc, numdiff_extrema = get_minmax(h)
#     457     return numdiff_extrema(minFunc), numdiff_extrema(maxFunc)
#     458 if not hmin is None:
#
# File C:\Users\pthon\anaconda3\envs\ta_env\lib\site-packages\trendln\__init__.py:442, in get_extrema.<locals>.get_minmax(h)
#     440 def get_minmax(h):
#     441     clarr = np.asarray(h, dtype=np.float64)
# --> 442     mom, momacc = d_dx(clarr), d2_dx2(clarr)
#     443     #print(mom[-10:], momacc[-10:])
#     444     #numerical derivative will yield prominent extrema points only
#     445     def numdiff_extrema(func):
#
# File C:\Users\pthon\anaconda3\envs\ta_env\lib\site-packages\findiff\operators.py:79, in FinDiff.__call__(self, rhs, *args, **kwargs)
#      78 def __call__(self, rhs, *args, **kwargs):
# ---> 79     return self.apply(rhs, *args, **kwargs)
#
# File C:\Users\pthon\anaconda3\envs\ta_env\lib\site-packages\findiff\operators.py:94, in FinDiff.apply(self, rhs, *args, **kwargs)
#      92     else:
#      93         args = self.coords,
# ---> 94 return self.pds(rhs, *args, **kwargs)
#
# File C:\Users\pthon\anaconda3\envs\ta_env\lib\site-packages\findiff\diff.py:217, in LinearMap.__call__(self, rhs, *args, **kwargs)
#     216 def __call__(self, rhs, *args, **kwargs):
# --> 217     return self.apply(rhs, *args, **kwargs)
#
# File C:\Users\pthon\anaconda3\envs\ta_env\lib\site-packages\findiff\diff.py:276, in Diff.apply(self, u, *args, **kwargs)
#     273 if isinstance(h, np.ndarray):
#     274     return self.diff_non_uni(u, h, **kwargs)
# --> 276 return self.diff(u, h, acc)
#
# File C:\Users\pthon\anaconda3\envs\ta_env\lib\site-packages\findiff\diff.py:288, in Diff.diff(self, y, h, acc)
#     279 """The core function to take a partial derivative on a uniform grid.
#     280
#     281     Central coefficients will be used whenever possible. Backward or forward
#    (...)
#     284     for the high index boundary.
#     285 """
#     287 dim = self.axis
# --> 288 coefs = coefficients(self.order, acc)
#     289 deriv = self.order
#     291 try:
#
# File C:\Users\pthon\anaconda3\envs\ta_env\lib\site-packages\findiff\coefs.py:63, in coefficients(deriv, acc, offsets, symbolic, analytic_inv)
#      60 if acc is None:
#      61     raise ValueError('either acc or offsets has to be given')
# ---> 63 _validate_acc(acc)
#      64 ret = {}
#      66 # Determine central coefficients
#
# File C:\Users\pthon\anaconda3\envs\ta_env\lib\site-packages\findiff\coefs.py:288, in _validate_acc(acc)
#     286 def _validate_acc(acc):
#     287     if acc % 2 == 1 or acc <= 0:
# --> 288         raise ValueError('Accuracy order acc must be positive EVEN integer')
#
# ValueError: Accuracy order acc must be positive EVEN integer

# %%
# Out:
# Requirement already satisfied: pytz in c:\users\pthon\anaconda3\envs\ta_env\lib\site-packages (2023.3.post1)
