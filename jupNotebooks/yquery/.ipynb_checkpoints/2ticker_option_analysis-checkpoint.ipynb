# %%
import pandas as pd
import os
import yfinance as yf
from yahooquery import Ticker
from yahooquery import Screener
from datetime import datetime
s = Screener()

data_path = r'C:\Users\pythonProject\data\data_produced\yquerry_screens\options'
today = datetime.today().strftime('%Y%m%d')
file_name = data_path + f"\\{today}_option_analysis_2tickers.csv"
#excel_file_path = os.path.join(data_path, scr_file_name)

# %%
stocklist = ['FSR', 'RIVN']
fsr_future_price = 10
rivn_future_price = 30

# %%
t = Ticker(stocklist, asynchronous=True)
option_df = t.option_chain

# %%
"""
next , fetch latest prices for the stocks in the screen data list

"""

def fetch_latest_prices(tickers):
    error_list = []
    stock_data = pd.DataFrame()  # Initialize an empty DataFrame

    for ticker in tickers:
        try:
            data = yf.download(ticker, period="1d", interval="1m")
            latest_price = data["Close"].iloc[-1]
            stock_data = pd.concat([stock_data, pd.DataFrame({"Ticker": ticker, "Latest_Price": latest_price}, index=[0])])
        except Exception as e:
            print(f"Error fetching price for {ticker}: {e}")
            error_list.append(ticker)
    
    stock_data = stock_data.sort_values(by="Ticker")
    return stock_data, error_list

# Example usage:
#tickers = ["AAPL", "GOOG", "MSFT", "INVALID"]  # Replace with your list of tickers
stock_data, error_list = fetch_latest_prices(stocklist)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
option_df = option_df.reset_index(level=['optionType'], drop=False).reset_index(level=['expiration'], drop=False)
# Out:
#        expiration optionType      contractSymbol  strike currency  lastPrice  \
# symbol
# FSR    2024-01-26      calls  FSR240126C00000500     0.5      USD       0.24
# FSR    2024-01-26      calls  FSR240126C00001000     1.0      USD       0.01
#
#         change  percentChange  volume  openInterest   bid   ask contractSize  \
# symbol
# FSR      -0.09     -27.272732    44.0           234  0.22  0.25      REGULAR
# FSR      -0.01     -50.000000   629.0         19928  0.00  0.01      REGULAR
#
#              lastTradeDate  impliedVolatility  inTheMoney
# symbol
# FSR    2024-01-25 15:41:00           3.750001        True
# FSR    2024-01-25 15:44:42           2.750003       False

# %%
stock_data.set_index('Ticker', inplace=True)

# %%
temp_df = option_df.copy()

# %%
#temp_df = temp_df.join(stock_data)
temp_df.index
# Out:
# Index(['FSR', 'FSR', 'FSR', 'FSR', 'FSR', 'FSR', 'FSR', 'FSR', 'FSR', 'FSR',
#        ...
#        'RIVN', 'RIVN', 'RIVN', 'RIVN', 'RIVN', 'RIVN', 'RIVN', 'RIVN', 'RIVN',
#        'RIVN'],
#       dtype='object', name='symbol', length=903)

# %%
import numpy as np 
temp_df["break_even"] = temp_df["strike"] + temp_df["lastPrice"]
temp_df["futurePrice"] = np.where(temp_df.index == "FSR",
                                    fsr_future_price - temp_df["strike"],
                                    rivn_future_price - temp_df["strike"])
temp_df["return"] = round((temp_df["futurePrice"] - temp_df["lastPrice"]) / temp_df["lastPrice"] , 2)
temp_df.to_csv(file_name)
# Out:
#        expiration optionType       contractSymbol  strike currency  lastPrice  \
# symbol
# FSR    2024-01-26      calls   FSR240126C00000500     0.5      USD       0.24
# FSR    2024-01-26      calls   FSR240126C00001000     1.0      USD       0.01
# FSR    2024-01-26      calls   FSR240126C00001500     1.5      USD       0.01
# FSR    2024-01-26      calls   FSR240126C00002000     2.0      USD       0.01
# FSR    2024-01-26      calls   FSR240126C00002500     2.5      USD       0.01
# ...           ...        ...                  ...     ...      ...        ...
# RIVN   2026-01-16       puts  RIVN260116P00030000    30.0      USD      15.35
# RIVN   2026-01-16       puts  RIVN260116P00032500    32.5      USD      17.67
# RIVN   2026-01-16       puts  RIVN260116P00035000    35.0      USD      20.00
# RIVN   2026-01-16       puts  RIVN260116P00037500    37.5      USD      20.40
# RIVN   2026-01-16       puts  RIVN260116P00040000    40.0      USD      25.00
#
#         change  percentChange  volume  openInterest    bid    ask  \
# symbol
# FSR      -0.09     -27.272732    44.0           234   0.22   0.25
# FSR      -0.01     -50.000000   629.0         19928   0.00   0.01
# FSR       0.00       0.000000     3.0         13628   0.00   0.01
# FSR       0.00       0.000000     3.0          6304   0.00   0.01
# FSR       0.00       0.000000     3.0          1299   0.00   0.01
# ...        ...            ...     ...           ...    ...    ...
# RIVN      0.00       0.000000    60.0            85  15.90  17.50
# RIVN      0.00       0.000000     1.0             4  18.30  18.95
# RIVN      0.00       0.000000    20.0           543  20.95  21.15
# RIVN      0.00       0.000000     0.0             1  20.00  21.35
# RIVN      0.00       0.000000    50.0            80  24.80  25.80
#
#        contractSize       lastTradeDate  impliedVolatility  inTheMoney  \
# symbol
# FSR         REGULAR 2024-01-25 15:41:00           3.750001        True
# FSR         REGULAR 2024-01-25 15:44:42           2.750003       False
# FSR         REGULAR 2024-01-25 15:02:57           5.000004       False
# FSR         REGULAR 2024-01-24 16:00:05           6.500002       False
# FSR         REGULAR 2024-01-22 16:22:28           7.750000       False
# ...             ...                 ...                ...         ...
# RIVN        REGULAR 2024-01-23 15:31:07           0.534917        True
# RIVN        REGULAR 2024-01-24 17:26:25           0.528813        True
# RIVN        REGULAR 2024-01-24 19:47:27           0.506841        True
# RIVN        REGULAR 2023-12-11 20:40:46           0.000010        True
# RIVN        REGULAR 2024-01-24 20:49:35           0.482427        True
#
#         break_even  futurePrice  return
# symbol
# FSR           0.74          9.5   38.58
# FSR           1.01          9.0  899.00
# FSR           1.51          8.5  849.00
# FSR           2.01          8.0  799.00
# FSR           2.51          7.5  749.00
# ...            ...          ...     ...
# RIVN         45.35          0.0   -1.00
# RIVN         50.17         -2.5   -1.14
# RIVN         55.00         -5.0   -1.25
# RIVN         57.90         -7.5   -1.37
# RIVN         65.00        -10.0   -1.40
#
# [903 rows x 19 columns]
