# %%
from yahooquery import Screener
import pandas as pd
s = Screener()

# %%
industry = 'day_gainers'
columns = ['symbol', 'averageAnalystRating', 'regularMarketPrice', 'fiftyTwoWeekRange', 'regularMarketVolume',  'averageDailyVolume10Day', 'averageDailyVolume3Month', 'priceToBook', 'marketCap', 'forwardPE', 'priceEpsCurrentYear', 'bookValue',    ]
my_dict = industry + '_dict'
my_data_list = industry + '_data_list'
my_df = 'df_' + industry
my_dict = s.get_screeners([industry])
my_data_list = my_dict[industry]['quotes']

day_gainers_df = pd.DataFrame(my_data_list, columns=columns)
day_gainers_df.set_index(keys=['symbol'], inplace = True)
day_gainers_df
# Out:
#        averageAnalystRating  regularMarketPrice  fiftyTwoWeekRange  \
# symbol
# WIT      4.3 - Underperform               6.280        4.32 - 6.39
# UEC               1.9 - Buy               7.770         2.3 - 7.83
# NXE               1.8 - Buy               7.840        3.49 - 7.84
# KBGGY                   NaN              27.300       21.52 - 27.3
# GTBIF             1.7 - Buy              12.550       6.42 - 12.55
# ATZAF                   NaN              26.135     15.0 - 36.8269
# IDYA       1.4 - Strong Buy              39.740      13.29 - 40.14
# RICFY                   NaN              14.035    11.445 - 14.035
# CCJ               1.7 - Buy              49.920      23.69 - 51.22
# BRZE              1.9 - Buy              53.370      25.76 - 58.67
# SRUUF                   NaN              23.960       10.65 - 24.0
# APLS              1.9 - Buy              70.230      19.83 - 94.75
# GFI              2.8 - Hold              13.250       8.89 - 17.78
# BKKLY                   NaN              21.775      20.13 - 25.77
# RCRUY                   NaN               8.540        4.83 - 8.62
# SQNNY                   NaN              19.866       16.03 - 26.5
# TDC               2.1 - Buy              47.870      32.33 - 57.73
# PAAS              1.9 - Buy              15.490      13.13 - 19.85
# FRCOY            3.0 - Hold              26.732  19.163334 - 27.18
# EGO               2.4 - Buy              12.720       8.12 - 13.71
# SBSW             2.8 - Hold               5.140        4.0 - 12.01
# HMY      4.0 - Underperform               5.870        2.93 - 6.58
# KGC               2.4 - Buy               5.890         3.4 - 6.34
# OR               3.3 - Hold              14.500      11.24 - 17.96
# ATAT       1.4 - Strong Buy              17.840        14.8 - 29.4
#
#         regularMarketVolume  averageDailyVolume10Day  \
# symbol
# WIT                15204959                  3972470
# UEC                29105980                  8252430
# NXE                17251357                  6579290
# KBGGY                 17700                     2162
# GTBIF                664310                   403870
# ATZAF                 43236                    68107
# IDYA                2740683                  1447340
# RICFY                 31973                     4088
# CCJ                17354881                  5807130
# BRZE                1306816                   745040
# SRUUF               1092723                  1080200
# APLS                2402638                  2259490
# GFI                 7176191                  5563070
# BKKLY                 51185                     9680
# RCRUY                186065                   169850
# SQNNY                 17123                     2049
# TDC                 1286783                   829060
# PAAS                3525414                  2822450
# FRCOY                 30241                    42920
# EGO                 1176497                  1300280
# SBSW                7827511                  4834210
# HMY                 3464482                  3667300
# KGC                12223479                 11703840
# OR                   856724                   632350
# ATAT                 304637                   470180
#
#         averageDailyVolume3Month  priceToBook    marketCap    forwardPE  \
# symbol
# WIT                      1993041     0.046854  32763326464    22.428572
# UEC                      7703791     4.437464   3053454592   777.000000
# NXE                      5538862     6.457990   4102499840   -71.272730
# KBGGY                        313     0.322344   9604384768          NaN
# GTBIF                     364111     1.739914   3005662464    52.291668
# ATZAF                      29750     3.742661   2879031552          NaN
# IDYA                     1048296     4.585737   2742588416   -16.838985
# RICFY                       3756     1.674022  11564517376          NaN
# CCJ                      5110248     3.544196  21710606336    44.571426
# BRZE                      780083    12.082862   5328588800 -2668.500000
# SRUUF                     642414          NaN   5956551680          NaN
# APLS                     2261579    35.795110   8322255360   -43.621120
# GFI                      4774309     2.767335  11839418368    55.208336
# BKKLY                       4629     0.078704   8313019904          NaN
# RCRUY                     541459     0.006772  66832334848          NaN
# SQNNY                        530     0.007435   4757052416          NaN
# TDC                       870146    38.418938   4681686016    20.113443
# PAAS                     3237346     1.164399   5656699904    20.653334
# FRCOY                      31583     0.004356  82309169152          NaN
# EGO                      1817135     0.754986   2584869376    19.272726
# SBSW                     6126119     0.150007   3637279744    20.560000
# HMY                      4692611     0.104376   3639018240    11.979591
# KGC                     13536480     1.193274   7231152640    17.323528
# OR                        940574     1.544854   2691431936    34.523810
# ATAT                      489775     1.360793   2454694912    15.118645
#
#         priceEpsCurrentYear  bookValue
# symbol
# WIT               25.120000    134.032
# UEC                     NaN      1.751
# NXE              -52.266666      1.214
# KBGGY                   NaN     84.692
# GTBIF             69.722220      7.213
# ATZAF                   NaN      6.983
# IDYA             -20.806284      8.666
# RICFY                   NaN      8.384
# CCJ               79.238090     14.085
# BRZE            -205.269240      4.417
# SRUUF                   NaN        NaN
# APLS             -15.435164      1.962
# GFI                     NaN      4.788
# BKKLY                   NaN    276.669
# RCRUY                   NaN   1261.118
# SQNNY                   NaN   2671.791
# TDC               23.698019      1.246
# PAAS              64.541664     13.303
# FRCOY                   NaN   6137.086
# EGO               24.000002     16.848
# SBSW                    NaN     34.265
# HMY                     NaN     56.239
# KGC               14.365853      4.936
# OR                31.521738      9.386
# ATAT              20.272728     13.110

# %%
# Out:
# 'C:\\Users\\pythonProject\\MyJupyterNotebooks\\data\\20240113__yquery_data.xlsx'
